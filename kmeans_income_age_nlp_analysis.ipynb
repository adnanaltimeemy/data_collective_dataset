# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data-income-age-group.csv")

print(df.head())
print(df.info())
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000
# <class 'pandas.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       22 non-null     str
#  1   Age        22 non-null     int64
#  2   Income($)  22 non-null     int64
# dtypes: int64(2), str(1)
# memory usage: 775.0 bytes
# None

# %%
# Drop missing values
df = df.dropna()

# Example: ensure numeric columns exist
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Income($)'], dtype='str')

# %%
set(['income', 'age']) - set(df.columns)
# Out:
# {'age', 'income'}

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Income($)'], dtype='str')

# %%
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
print(df.columns)
print(df.head())
print(df.dtypes)
# Out:
# Index(['Name', 'Age', 'Income($)'], dtype='str')
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000
# Name           str
# Age          int64
# Income($)    int64
# dtype: object
