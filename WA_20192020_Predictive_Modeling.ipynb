# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("WA_20192020_RawData.csv")

# View basic info
print(df.head())
print(df.info())
print(df.describe())
# Out:
#   2019-2020 Washington State Counties PIT Homeless Counts  ...        Unnamed: 11
# 0                                                NaN       ...                NaN
# 1                                             County       ...  2020_homelessarea
# 2                                       Adams County       ...                  0
# 3                                      Asotin County       ...                  0
# 4                                      Benton County       ...                  0
#
# [5 rows x 12 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 12 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   2019-2020 Washington State Counties PIT Homeless Counts  40 non-null     str
#  1   Unnamed: 1                                               42 non-null     str
#  2   Unnamed: 2                                               41 non-null     str
#  3   Unnamed: 3                                               41 non-null     str
#  4   Unnamed: 4                                               41 non-null     str
#  5   Unnamed: 5                                               40 non-null     str
#  6   Unnamed: 6                                               40 non-null     str
#  7   Unnamed: 7                                               40 non-null     str
#  8   Unnamed: 8                                               40 non-null     str
#  9   Unnamed: 9                                               40 non-null     str
#  10  Unnamed: 10                                              40 non-null     str
#  11  Unnamed: 11                                              40 non-null     str
# dtypes: str(12)
# memory usage: 6.6 KB
# None
#        2019-2020 Washington State Counties PIT Homeless Counts  ... Unnamed: 11
# count                                                  40       ...          40
# unique                                                 40       ...           4
# top                                                County       ...           0
# freq                                                    1       ...          31
#
# [4 rows x 12 columns]

# %%
# Check missing values
print(df.isnull().sum())

# Drop rows with missing values (simple approach)
df = df.dropna()
# Out:
# 2019-2020 Washington State Counties PIT Homeless Counts    4
# Unnamed: 1                                                 2
# Unnamed: 2                                                 3
# Unnamed: 3                                                 3
# Unnamed: 4                                                 3
# Unnamed: 5                                                 4
# Unnamed: 6                                                 4
# Unnamed: 7                                                 4
# Unnamed: 8                                                 4
# Unnamed: 9                                                 4
# Unnamed: 10                                                4
# Unnamed: 11                                                4
# dtype: int64

# %%
print(df.dtypes)
# Out:
# 2019-2020 Washington State Counties PIT Homeless Counts    int64
# Unnamed: 1                                                 int64
# Unnamed: 2                                                 int64
# Unnamed: 3                                                 int64
# Unnamed: 4                                                 int64
# Unnamed: 5                                                 int64
# Unnamed: 6                                                 int64
# Unnamed: 7                                                 int64
# Unnamed: 8                                                 int64
# Unnamed: 9                                                 int64
# Unnamed: 10                                                int64
# Unnamed: 11                                                int64
# dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['2019-2020 Washington State Counties PIT Homeless Counts', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']

# %%
df.head()
df.columns
# Out:
# Index(['2019-2020 Washington State Counties PIT Homeless Counts', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['2019-2020 Washington State Counties PIT Homeless Counts', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['2019-2020 Washington State Counties PIT Homeless Counts', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='str')

# %%
print("X_train exists:", 'X_train' in globals())
print("rf_model fitted:", hasattr(rf_model, "feature_importances_"))
# Out:
# X_train exists: False
# rf_model fitted: False
