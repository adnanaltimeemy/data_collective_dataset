# %%
# Movies Watched Dataset - NLP + KMeans Clustering
# ------------------------------------------------

# Import Libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# NLP Libraries
import re
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Machine Learning Libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score


# Download NLP resources

nltk.download('punkt')
nltk.download('stopwords')


# ---------------------------------------
# Load Dataset
# ---------------------------------------

df = pd.read_csv("Movies Watched.csv")

# Display first rows

df.head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#              Name   "Year"  "Date Watched"
# 0        Superman     2025      2025-08-16
# 1      The Rookie     2002      2025-01-10
# 2       Elemental     2023      2024-08-19
# 3  Dune: Part Two     2024      2024-03-17
# 4          Barbie     2023      2024-03-14

# %%
# Dataset information

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 791 entries, 0 to 790
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             791 non-null    str
#  1    "Year"          791 non-null    int64
#  2    "Date Watched"  216 non-null    str
# dtypes: int64(1), str(2)
# memory usage: 33.9 KB

# %%
# Display column names

df.columns
# Out:
# Index(['Name', ' "Year"', ' "Date Watched"'], dtype='str')

# %%
df.columns
# Out:
# Index(['Name', ' "Year"', ' "Date Watched"'], dtype='str')

# %%
# Dataset shape

df.shape
# Out:
# (791, 3)

# %%
df.to_csv(
    "Movies_Watched_KMeans_Clusters.csv",
    index=False
)
