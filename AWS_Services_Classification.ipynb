# %%
# Data handling
import pandas as pd
import numpy as np

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Evaluation
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
# Load AWS services dataset

df = pd.read_csv("aws_services.csv")

# Display first rows
df.head()
# Out:
#    service_id                        name                  prefix  \
# 0           1      AWS Account Management                 account
# 1           2  AWS Action Recommendations  action-recommendations
# 2           3                AWS Activate                activate
# 3           4                 AWS Amplify                 amplify
# 4           5           AWS Amplify Admin          amplifybackend
#
#                                        reference_url
# 0  https://docs.aws.amazon.com/service-authorizat...
# 1  https://docs.aws.amazon.com/service-authorizat...
# 2  https://docs.aws.amazon.com/service-authorizat...
# 3  https://docs.aws.amazon.com/service-authorizat...
# 4  https://docs.aws.amazon.com/service-authorizat...

# %%
# Dataset information

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   service_id     471 non-null    int64
#  1   name           471 non-null    str
#  2   prefix         471 non-null    str
#  3   reference_url  471 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 75.7 KB

# %%
# Display column names

df.columns
# Out:
# Index(['service_id', 'name', 'prefix', 'reference_url'], dtype='str')

# %%
df = df.drop_duplicates()

df.shape
# Out:
# (471, 4)

# %%
df.select_dtypes(include="object").columns
# Out:
# /var/folders/88/w4w1n8l12kd_z42_6mrnndmw0000gn/T/ipykernel_93507/1196084386.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include="object").columns
# Index(['name', 'prefix', 'reference_url'], dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['service_id', 'name', 'prefix', 'reference_url']

# %%
print(df.columns.tolist())
# Out:
# ['service_id', 'name', 'prefix', 'reference_url']
