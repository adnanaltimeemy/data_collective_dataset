# %%
import pandas as pd
import numpy as np

import re
import string

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("oecd-new.csv")

df.head()
# Out:
#            country  gdp_per_capita  life_satisfaction
# 0           Russia         9054.91                6.0
# 1           Turkey         9437.37                5.6
# 2          Hungary        12239.89                4.9
# 3           Poland        12495.33                5.8
# 4  Slovak Republic        15991.73                6.1

# %%
print(df.info())
print(df.columns)
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            29 non-null     str
#  1   gdp_per_capita     29 non-null     float64
#  2   life_satisfaction  29 non-null     float64
# dtypes: float64(2), str(1)
# memory usage: 1.0 KB
# None
# Index(['country', 'gdp_per_capita', 'life_satisfaction'], dtype='str')
# country              0
# gdp_per_capita       0
# life_satisfaction    0
# dtype: int64

# %%
print(df.head())
# Out:
#            country  gdp_per_capita  life_satisfaction
# 0           Russia         9054.91                6.0
# 1           Turkey         9437.37                5.6
# 2          Hungary        12239.89                4.9
# 3           Poland        12495.33                5.8
# 4  Slovak Republic        15991.73                6.1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            29 non-null     str
#  1   gdp_per_capita     29 non-null     float64
#  2   life_satisfaction  29 non-null     float64
# dtypes: float64(2), str(1)
# memory usage: 1.0 KB

# %%
print(df.columns.tolist())
# Out:
# ['country', 'gdp_per_capita', 'life_satisfaction']

# %%
df.head()
df.columns
# Out:
# Index(['country', 'gdp_per_capita', 'life_satisfaction'], dtype='str')
