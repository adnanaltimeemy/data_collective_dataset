# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("realData.csv")

# Preview data
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    landmark                         process+migration  \
# 0  landmark                         process+migration
# 1  landmark                         process+migration
# 2  landmark                         process+migration
# 3  landmark  communicating+sequential+process+(+csp+)
# 4  landmark  communicating+sequential+process+(+csp+)
#
#   Disclosed is a computer implemented method and computer program product to prioritize paging-in pages in a remote paging device. An arrival machine receives checkpoint data from a departure machine. The arrival machine restarts at least one process corresponding to the checkpoint data. The arrival machine determines whether a page associated with the process is pinned. The arrival machine associates the page to the remote paging device, responsive to a determination that the page is pinned. The arrival machine touches the page.  \
# 0  A technique includes determining at least one ...
# 1  A method of seismic shot-record migration incl...
# 2  Method for efficient computation of wave equat...
# 3  A method for providing guidance to a user as t...
# 4  A cubesat communications system includes an on...
#
#     Mapped offsets preset ahead of process migration  \
# 0  Determining an elastic model for a geologic re...
# 1  System and method of seismic shot-record migra...
# 2  Efficient computation of wave equation migrati...
# 3  Guidance for image capture at different locations
# 4  Processor system for control of modular autono...
#
#         https://www.google.com/patents/US20100095074
# 0       https://www.google.com/patents/US20130185032
# 1           https://www.google.com/patents/US5544126
# 2      https://www.google.com/patents/WO2011152928A1
# 3               https://google.com/patents/US8405740
# 4  http://www.google.com/patents/WO2016190915A2?c...
# <class 'pandas.DataFrame'>
# RangeIndex: 1164 entries, 0 to 1163
# Data columns (total 5 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 --------------  -----
#  0   landmark                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1164 non-null   str
#  1   process+migration                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1164 non-null   str
#  2   Disclosed is a computer implemented method and computer program product to prioritize paging-in pages in a remote paging device. An arrival machine receives checkpoint data from a departure machine. The arrival machine restarts at least one process corresponding to the checkpoint data. The arrival machine determines whether a page associated with the process is pinned. The arrival machine associates the page to the remote paging device, responsive to a determination that the page is pinned. The arrival machine touches the page.  1164 non-null   str
#  3   Mapped offsets preset ahead of process migration                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1164 non-null   str
#  4   https://www.google.com/patents/US20100095074                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1164 non-null   str
# dtypes: str(5)
# memory usage: 1.0 MB
# None
#             landmark         process+migration  \
# count           1164                      1164
# unique            10                        40
# top     architecture  inter+-+pe+communication
# freq             182                        64
#
#        Disclosed is a computer implemented method and computer program product to prioritize paging-in pages in a remote paging device. An arrival machine receives checkpoint data from a departure machine. The arrival machine restarts at least one process corresponding to the checkpoint data. The arrival machine determines whether a page associated with the process is pinned. The arrival machine associates the page to the remote paging device, responsive to a determination that the page is pinned. The arrival machine touches the page.  \
# count                                                1164
# unique                                                903
# top     The routing protocol was designed for VANET in...
# freq                                                   12
#
#          Mapped offsets preset ahead of process migration  \
# count                                                1164
# unique                                                902
# top     Junction Adaptive Reactive Routing (JARR) Prot...
# freq                                                   12
#
#         https://www.google.com/patents/US20100095074
# count                                           1164
# unique                                           909
# top     https://www.google.com/patents/US20130282263
# freq                                              12

# %%
# Example: assume last column is target
target_column = df.columns[-1]

X = df.drop(columns=[target_column])
y = df[target_column]

# %%
num_cols = X.select_dtypes(include="number").columns
X[num_cols] = X[num_cols].fillna(X[num_cols].mean())

# %%
print(X.shape, y.shape)
print(X.isna().sum().sum())
print(y.isna().sum())
# Out:
# (1164, 4) (1164,)
# 0
# 0

# %%
df.head()
# Out:
#    landmark                         process+migration  \
# 0  landmark                         process+migration
# 1  landmark                         process+migration
# 2  landmark                         process+migration
# 3  landmark  communicating+sequential+process+(+csp+)
# 4  landmark  communicating+sequential+process+(+csp+)
#
#   Disclosed is a computer implemented method and computer program product to prioritize paging-in pages in a remote paging device. An arrival machine receives checkpoint data from a departure machine. The arrival machine restarts at least one process corresponding to the checkpoint data. The arrival machine determines whether a page associated with the process is pinned. The arrival machine associates the page to the remote paging device, responsive to a determination that the page is pinned. The arrival machine touches the page.  \
# 0  A technique includes determining at least one ...
# 1  A method of seismic shot-record migration incl...
# 2  Method for efficient computation of wave equat...
# 3  A method for providing guidance to a user as t...
# 4  A cubesat communications system includes an on...
#
#     Mapped offsets preset ahead of process migration  \
# 0  Determining an elastic model for a geologic re...
# 1  System and method of seismic shot-record migra...
# 2  Efficient computation of wave equation migrati...
# 3  Guidance for image capture at different locations
# 4  Processor system for control of modular autono...
#
#         https://www.google.com/patents/US20100095074
# 0       https://www.google.com/patents/US20130185032
# 1           https://www.google.com/patents/US5544126
# 2      https://www.google.com/patents/WO2011152928A1
# 3               https://google.com/patents/US8405740
# 4  http://www.google.com/patents/WO2016190915A2?c...

# %%
X.dtypes
X.head()
# Out:
#    landmark                         process+migration  \
# 0  landmark                         process+migration
# 1  landmark                         process+migration
# 2  landmark                         process+migration
# 3  landmark  communicating+sequential+process+(+csp+)
# 4  landmark  communicating+sequential+process+(+csp+)
#
#   Disclosed is a computer implemented method and computer program product to prioritize paging-in pages in a remote paging device. An arrival machine receives checkpoint data from a departure machine. The arrival machine restarts at least one process corresponding to the checkpoint data. The arrival machine determines whether a page associated with the process is pinned. The arrival machine associates the page to the remote paging device, responsive to a determination that the page is pinned. The arrival machine touches the page.  \
# 0  A technique includes determining at least one ...
# 1  A method of seismic shot-record migration incl...
# 2  Method for efficient computation of wave equat...
# 3  A method for providing guidance to a user as t...
# 4  A cubesat communications system includes an on...
#
#     Mapped offsets preset ahead of process migration
# 0  Determining an elastic model for a geologic re...
# 1  System and method of seismic shot-record migra...
# 2  Efficient computation of wave equation migrati...
# 3  Guidance for image capture at different locations
# 4  Processor system for control of modular autono...

# %%
df.head()
# Out:
#    landmark                         process+migration  \
# 0  landmark                         process+migration
# 1  landmark                         process+migration
# 2  landmark                         process+migration
# 3  landmark  communicating+sequential+process+(+csp+)
# 4  landmark  communicating+sequential+process+(+csp+)
#
#   Disclosed is a computer implemented method and computer program product to prioritize paging-in pages in a remote paging device. An arrival machine receives checkpoint data from a departure machine. The arrival machine restarts at least one process corresponding to the checkpoint data. The arrival machine determines whether a page associated with the process is pinned. The arrival machine associates the page to the remote paging device, responsive to a determination that the page is pinned. The arrival machine touches the page.  \
# 0  A technique includes determining at least one ...
# 1  A method of seismic shot-record migration incl...
# 2  Method for efficient computation of wave equat...
# 3  A method for providing guidance to a user as t...
# 4  A cubesat communications system includes an on...
#
#     Mapped offsets preset ahead of process migration  \
# 0  Determining an elastic model for a geologic re...
# 1  System and method of seismic shot-record migra...
# 2  Efficient computation of wave equation migrati...
# 3  Guidance for image capture at different locations
# 4  Processor system for control of modular autono...
#
#         https://www.google.com/patents/US20100095074
# 0       https://www.google.com/patents/US20130185032
# 1           https://www.google.com/patents/US5544126
# 2      https://www.google.com/patents/WO2011152928A1
# 3               https://google.com/patents/US8405740
# 4  http://www.google.com/patents/WO2016190915A2?c...
