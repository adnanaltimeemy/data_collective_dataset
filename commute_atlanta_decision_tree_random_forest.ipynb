# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("CommuteAtlanta.csv")

df.head()
# Out:
#       City  Age  Distance  Time Sex
# 0  Atlanta   19        10    15   M
# 1  Atlanta   55        45    60   M
# 2  Atlanta   48        12    45   M
# 3  Atlanta   45         4    10   F
# 4  Atlanta   48        15    30   F

# %%
print(df.shape)
print(df.info())
print(df.describe())

# Check missing values
print(df.isnull().sum())
# Out:
# (500, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   City      500 non-null    str
#  1   Age       500 non-null    int64
#  2   Distance  500 non-null    int64
#  3   Time      500 non-null    int64
#  4   Sex       500 non-null    str
# dtypes: int64(3), str(2)
# memory usage: 23.6 KB
# None
#               Age    Distance        Time
# count  500.000000  500.000000  500.000000
# mean    40.242000   18.156000   29.110000
# std     12.082193   13.798277   20.718311
# min     16.000000    0.000000    1.000000
# 25%     31.000000    8.000000   15.000000
# 50%     40.000000   15.000000   25.000000
# 75%     49.000000   25.000000   40.000000
# max     85.000000  101.000000  181.000000
# City        0
# Age         0
# Distance    0
# Time        0
# Sex         0
# dtype: int64

# %%
df = df.dropna()  # simple approach; you can improve later

# %%
df.columns = df.columns.str.strip()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   City      500 non-null    str
#  1   Age       500 non-null    int64
#  2   Distance  500 non-null    int64
#  3   Time      500 non-null    int64
#  4   Sex       500 non-null    str
# dtypes: int64(3), str(2)
# memory usage: 23.6 KB

# %%
df.columns.tolist()
# Out:
# ['City', 'Age', 'Distance', 'Time', 'Sex']

# %%
print(df.columns.tolist())
# Out:
# ['City', 'Age', 'Distance', 'Time', 'Sex']

# %%
df.columns.tolist()
# Out:
# ['City', 'Age', 'Distance', 'Time', 'Sex']

# %%
df.columns.tolist()
# Out:
# ['City', 'Age', 'Distance', 'Time', 'Sex']

# %%
df.columns.tolist()
# Out:
# ['City', 'Age', 'Distance', 'Time', 'Sex']
