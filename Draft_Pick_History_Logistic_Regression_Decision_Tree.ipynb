# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Draft Pick History.csv")

df.head()
# Out:
#    season   lg  overall_pick  round   tm        player  player_id  \
# 0    2025  NBA           1.0    1.0  DAL  Cooper Flagg  flaggco01
# 1    2025  NBA           2.0    1.0  SAS  Dylan Harper  harpedy01
# 2    2025  NBA           3.0    1.0  PHI  VJ Edgecombe  edgecvj01
# 3    2025  NBA           4.0    1.0  CHO  Kon Knueppel  knuepko01
# 4    2025  NBA           5.0    1.0  UTA    Ace Bailey  baileac01
#
#               college
# 0                Duke
# 1  Rutgers University
# 2              Baylor
# 3                Duke
# 4  Rutgers University

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# (8383, 8)
# <class 'pandas.DataFrame'>
# RangeIndex: 8383 entries, 0 to 8382
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   season        8383 non-null   int64
#  1   lg            8383 non-null   str
#  2   overall_pick  7955 non-null   float64
#  3   round         8366 non-null   float64
#  4   tm            8383 non-null   str
#  5   player        8383 non-null   str
#  6   player_id     8383 non-null   str
#  7   college       7943 non-null   str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 841.8 KB
# None
#             season  overall_pick        round
# count  8383.000000   7955.000000  8366.000000
# mean   1979.993916     71.248649     4.890031
# std      19.508634     56.969625     3.849854
# min    1947.000000      1.000000     1.000000
# 25%    1967.000000     26.000000     2.000000
# 50%    1978.000000     53.000000     4.000000
# 75%    1990.000000    106.000000     7.000000
# max    2025.000000    239.000000    21.000000
# season            0
# lg                0
# overall_pick    428
# round            17
# tm                0
# player            0
# player_id         0
# college         440
# dtype: int64

# %%
# Fill numeric missing values with median
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

imputer = SimpleImputer(strategy='median')
df[num_cols] = imputer.fit_transform(df[num_cols])

# %%
for col in cat_cols:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
print(df.columns.tolist())
# Out:
# ['season', 'lg', 'overall_pick', 'round', 'tm', 'player', 'player_id', 'college']

# %%
print(df.columns.tolist())
# Out:
# ['season', 'lg', 'overall_pick', 'round', 'tm', 'player', 'player_id', 'college']

# %%
print(df.columns.tolist())
# Out:
# ['season', 'lg', 'overall_pick', 'round', 'tm', 'player', 'player_id', 'college']
