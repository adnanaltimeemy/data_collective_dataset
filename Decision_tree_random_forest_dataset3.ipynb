# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("dataset3.csv")

df.head()
# Out:
#    idResource                                             refUrl
# 0       66445  http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 1       66446  http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 2       66447  http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 3       66448  http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 4       66451  http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (28961, 2)
# <class 'pandas.DataFrame'>
# RangeIndex: 28961 entries, 0 to 28960
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   idResource  28961 non-null  int64
#  1   refUrl      28961 non-null  str
# dtypes: int64(1), str(1)
# memory usage: 2.6 MB
# None
# idResource    0
# refUrl        0
# dtype: int64

# %%
df = df.fillna({
    **{col: df[col].mean() for col in df.select_dtypes(include=np.number).columns},
    **{col: df[col].mode().iloc[0] for col in df.select_dtypes(include=["object", "string"]).columns}
})

# %%
print(df.columns)
# Out:
# Index(['idResource', 'refUrl'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['idResource', 'refUrl'], dtype='str')

# %%
print(df["refUrl"].head(20))
# Out:
# 0     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 1     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 2     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 3     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 4     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 5     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 6     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 7     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 8     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 9     http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 10    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 11    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 12    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 13    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 14    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 15    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 16    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 17    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 18    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# 19    http://eol.jsc.nasa.gov/SearchPhotos/photo.pl?...
# Name: refUrl, dtype: str

# %%
print(df.columns)
# Out:
# Index(['idResource', 'refUrl'], dtype='str')
