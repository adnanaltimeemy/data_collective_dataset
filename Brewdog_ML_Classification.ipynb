# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Brewdog.csv")

df.head()
# Out:
#       site  ...                                                web
# 0  Brewdog  ...    https://untappd.com/v/brewdog-sheffield/1429187
# 1  Brewdog  ...   https://untappd.com/v/brewdog-upminster/11670911
# 2  Brewdog  ...    https://untappd.com/v/brewdog-waterloo/11470925
# 3  Brewdog  ...  https://untappd.com/v/seething-lane-tap-a-brew...
# 4  Brewdog  ...        https://untappd.com/v/brewdog-camden/137251
#
# [5 rows x 9 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe())

print(df.isnull().sum())
# Out:
# (90, 9)
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   site     90 non-null     str
#  1   lat      90 non-null     float64
#  2   lng      90 non-null     float64
#  3   zip      0 non-null      float64
#  4   name     90 non-null     str
#  5   address  90 non-null     str
#  6   phone    90 non-null     str
#  7   email    90 non-null     str
#  8   web      90 non-null     str
# dtypes: float64(3), str(6)
# memory usage: 20.3 KB
# None
#              lat         lng  zip
# count  90.000000   90.000000  0.0
# mean   49.046661    8.459911  NaN
# std    12.877917   29.070061  NaN
# min   -37.736700   -8.479370  NaN
# 25%    51.456342   -2.245435  NaN
# 50%    51.526460   -1.030267  NaN
# 75%    53.717681   -0.109298  NaN
# max    57.369644  144.968500  NaN
# site        0
# lat         0
# lng         0
# zip        90
# name        0
# address     0
# phone       0
# email       0
# web         0
# dtype: int64

# %%
# Drop duplicates if any
df = df.drop_duplicates()

# Fill missing values (simple approach)
df = df.fillna(df.median(numeric_only=True))

# %%
categorical_cols = df.select_dtypes(include=['object', 'string']).columns
print(categorical_cols)
# Out:
# Index([], dtype='str')

# %%
print([col for col in df.columns])
# Out:
# ['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email', 'web']

# %%
df.head()
df.columns
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
print(df.dtypes)
print(df.head())
# Out:
# site         int64
# lat        float64
# lng        float64
# zip        float64
# name         int64
# address      int64
# phone        int64
# email        int64
# web          int64
# dtype: object
#    site        lat       lng  zip  name  address  phone  email  web
# 0     0  53.379600 -1.477110  NaN    74        6     12     65   55
# 1     0  51.556780  0.249802  NaN    85       25     47     77   65
# 2     0  51.502976 -0.115233  NaN    87       76     74     78   66
# 3     0  51.509990 -0.079450  NaN    72       15     58     63   74
# 4     0  51.538300 -0.140923  NaN    15       11     61     14   12
