# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
import pandas as pd

df = pd.read_csv(
    "COCOMO-81.csv",
    engine="python",        # more flexible parser
    on_bad_lines="skip"     # skips malformed rows
)

print(df.head())
# Out:
#               COCOMO-81 Dataset Description
# 0             =============================
# 1                             Dataset Name:
# 2  COCOMO-81 (Constructive Cost Model 1981)
# 3                                 Overview:
# 4                                 ---------

# %%
print(df.shape)
print(df.info())
print(df.describe())

# Check missing values
print(df.isnull().sum())
# Out:
# (58, 1)
# <class 'pandas.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 1 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   COCOMO-81 Dataset Description  58 non-null     str
# dtypes: str(1)
# memory usage: 2.7 KB
# None
#        COCOMO-81 Dataset Description
# count                             58
# unique                            57
# top         ------------------------
# freq                               2
# COCOMO-81 Dataset Description    0
# dtype: int64

# %%
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 1 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   COCOMO-81 Dataset Description  58 non-null     str
# dtypes: str(1)
# memory usage: 2.7 KB

# %%
print(df.head())
# Out:
#               COCOMO-81 Dataset Description
# 0             =============================
# 1                             Dataset Name:
# 2  COCOMO-81 (Constructive Cost Model 1981)
# 3                                 Overview:
# 4                                 ---------

# %%
print("X exists:", "X" in globals())
print("y exists:", "y" in globals())
# Out:
# X exists: False
# y exists: False

# %%
df.head()
df.columns
# Out:
# Index(['COCOMO-81 Dataset Description'], dtype='str')

# %%
print(hasattr(rf_model, "estimators_"))
# Out:
# False
