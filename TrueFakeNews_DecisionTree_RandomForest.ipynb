# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
true_df = pd.read_csv("True.csv")
fake_df = pd.read_csv("Fake.csv")

# %%
true_df["label"] = 1   # real news
fake_df["label"] = 0   # fake news

# %%
df = pd.concat([true_df, fake_df], axis=0)

# Shuffle dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
print(df.columns)

title_col = "title" if "title" in df.columns else None
text_col = "text" if "text" in df.columns else None

if title_col and text_col:
    df["content"] = df[title_col].fillna("") + " " + df[text_col].fillna("")
else:
    print("Available columns:", df.columns.tolist())
# Out:
# Index(['text', 'subject', 'date', 'label'], dtype='str')
# Available columns: ['text', 'subject', 'date', 'label']

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['text', 'subject', 'date', 'label']
#                                                 text  ... label
# 0  WASHINGTON (Reuters) - The U.S. House of Repre...  ...     1
# 1  (Reuters) - Federal appeals courts in the stat...  ...     1
# 2   SACRAMENTO, Calif. (Reuters) - Laura Russo is...  ...     1
# 3  NEW YORK(Reuters) - In August, a dozen invento...  ...     1
# 4  Hurricane Maria is the worst natural disaster ...  ...     0
#
# [5 rows x 4 columns]

# %%
print(df.columns.tolist())
df.head()
# Out:
# ['text', 'subject', 'date', 'label']
#                                                 text  ... label
# 0  WASHINGTON (Reuters) - The U.S. House of Repre...  ...     1
# 1  (Reuters) - Federal appeals courts in the stat...  ...     1
# 2   SACRAMENTO, Calif. (Reuters) - Laura Russo is...  ...     1
# 3  NEW YORK(Reuters) - In August, a dozen invento...  ...     1
# 4  Hurricane Maria is the worst natural disaster ...  ...     0
#
# [5 rows x 4 columns]

# %%
print('y_test' in globals())
# Out:
# False
