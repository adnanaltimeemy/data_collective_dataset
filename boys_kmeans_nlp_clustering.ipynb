# %%
import pandas as pd
import numpy as np

# NLP
import re
import string
from sklearn.feature_extraction.text import TfidfVectorizer

# ML
from sklearn.cluster import KMeans

# Visualization
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("boys.csv")

df.head()
# Out:
#              band           name  ... jacket_color bottom_color
# 0  The Click Five      Joey Zehr  ...        black        black
# 1  The Click Five     Ben Romans  ...        black        black
# 2  The Click Five  Ethan Mentzer  ...        black        black
# 3  The Click Five      Eric Dill  ...        black        black
# 4  The Click Five      Joe Guese  ...        black        black
#
# [5 rows x 18 columns]

# %%
print(df.columns)
print(df.isnull().sum())
# Out:
# Index(['band', 'name', 'dob', 'hair_color', 'hair_frosted', 'hair_length',
#        'hair_style', 'eyes', 'facial_hair', 'accessories', 'top_style',
#        'bottom_style', 'height', 'skin', 'instrument', 'shirt_color',
#        'jacket_color', 'bottom_color'],
#       dtype='str')
# band              0
# name              0
# dob              43
# hair_color        2
# hair_frosted      3
# hair_length       5
# hair_style        3
# eyes              2
# facial_hair     131
# accessories      95
# top_style         0
# bottom_style      0
# height          115
# skin              0
# instrument      197
# shirt_color       1
# jacket_color    117
# bottom_color      0
# dtype: int64

# %%
print(df.head())
# Out:
#              band           name  ... jacket_color bottom_color
# 0  The Click Five      Joey Zehr  ...        black        black
# 1  The Click Five     Ben Romans  ...        black        black
# 2  The Click Five  Ethan Mentzer  ...        black        black
# 3  The Click Five      Eric Dill  ...        black        black
# 4  The Click Five      Joe Guese  ...        black        black
#
# [5 rows x 18 columns]

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['band', 'name', 'dob', 'hair_color', 'hair_frosted', 'hair_length', 'hair_style', 'eyes', 'facial_hair', 'accessories', 'top_style', 'bottom_style', 'height', 'skin', 'instrument', 'shirt_color', 'jacket_color', 'bottom_color']
#              band           name  ... jacket_color bottom_color
# 0  The Click Five      Joey Zehr  ...        black        black
# 1  The Click Five     Ben Romans  ...        black        black
# 2  The Click Five  Ethan Mentzer  ...        black        black
# 3  The Click Five      Eric Dill  ...        black        black
# 4  The Click Five      Joe Guese  ...        black        black
#
# [5 rows x 18 columns]

# %%
print(df.columns)
df.columns = df.columns.str.strip()
print(df.head())
# Out:
# Index(['band', 'name', 'dob', 'hair_color', 'hair_frosted', 'hair_length',
#        'hair_style', 'eyes', 'facial_hair', 'accessories', 'top_style',
#        'bottom_style', 'height', 'skin', 'instrument', 'shirt_color',
#        'jacket_color', 'bottom_color'],
#       dtype='str')
#              band           name  ... jacket_color bottom_color
# 0  The Click Five      Joey Zehr  ...        black        black
# 1  The Click Five     Ben Romans  ...        black        black
# 2  The Click Five  Ethan Mentzer  ...        black        black
# 3  The Click Five      Eric Dill  ...        black        black
# 4  The Click Five      Joe Guese  ...        black        black
#
# [5 rows x 18 columns]

# %%
if "clean_text" not in df.columns:
    print("Available columns:", df.columns)
# Out:
# Available columns: Index(['band', 'name', 'dob', 'hair_color', 'hair_frosted', 'hair_length',
#        'hair_style', 'eyes', 'facial_hair', 'accessories', 'top_style',
#        'bottom_style', 'height', 'skin', 'instrument', 'shirt_color',
#        'jacket_color', 'bottom_color'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['band', 'name', 'dob', 'hair_color', 'hair_frosted', 'hair_length',
#        'hair_style', 'eyes', 'facial_hair', 'accessories', 'top_style',
#        'bottom_style', 'height', 'skin', 'instrument', 'shirt_color',
#        'jacket_color', 'bottom_color'],
#       dtype='str')

# %%
[c for c in df.columns if "text" in c.lower()]
[c for c in df.columns if "cluster" in c.lower()]
# Out:
# []

# %%
print(hasattr(vectorizer, "vocabulary_"))
# Out:
# False

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 're', 'string', 'TfidfVectorizer', 'KMeans', 'plt', 'PCA', '_i2', 'df', '_2', '_i3', '_i4', '_i5', '_i6', '_i7', 'clean_text', '_i8', '_i9', '_i10', 'vectorizer', '_i11', '_i12', 'k', 'kmeans', '_i13', '_i14', '_14', '_i15', '_i16', '_16', '_i17', '_i18', '_i19', 'pca', '_i20', 'issparse', '_i21'])

# %%
print(df.columns)
# Out:
# Index(['band', 'name', 'dob', 'hair_color', 'hair_frosted', 'hair_length',
#        'hair_style', 'eyes', 'facial_hair', 'accessories', 'top_style',
#        'bottom_style', 'height', 'skin', 'instrument', 'shirt_color',
#        'jacket_color', 'bottom_color'],
#       dtype='str')
