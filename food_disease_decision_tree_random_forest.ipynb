# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("food_disease_dataset2.csv")

# View basic info
print(df.head())
print(df.info())
print(df.describe())
# Out:
#                  food  ...                                     notes
# 0             chicken  ...       Often caused by undercooked poultry
# 1                eggs  ...  Raw or lightly cooked eggs are high risk
# 2                beef  ...  Undercooked ground beef is common source
# 3  unpasteurized_milk  ...        Dangerous for pregnant individuals
# 4           shellfish  ...                   Highly contagious virus
#
# [5 rows x 7 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   food               10 non-null     str
#  1   disease            10 non-null     str
#  2   causative_agent    10 non-null     str
#  3   symptoms           10 non-null     str
#  4   incubation_period  10 non-null     str
#  5   severity           10 non-null     str
#  6   notes              10 non-null     str
# dtypes: str(7)
# memory usage: 1.9 KB
# None
#            food        disease  ...  severity                                notes
# count        10             10  ...        10                                   10
# unique       10              8  ...         5                                   10
# top     chicken  salmonellosis  ...  moderate  Often caused by undercooked poultry
# freq          1              2  ...         4                                    1
#
# [4 rows x 7 columns]

# %%
df = df.dropna()  # or you can use imputation if needed

# %%
print(df.head())
print(df.columns)
# Out:
#                  food  ...                                     notes
# 0             chicken  ...       Often caused by undercooked poultry
# 1                eggs  ...  Raw or lightly cooked eggs are high risk
# 2                beef  ...  Undercooked ground beef is common source
# 3  unpasteurized_milk  ...        Dangerous for pregnant individuals
# 4           shellfish  ...                   Highly contagious virus
#
# [5 rows x 7 columns]
# Index(['food', 'disease', 'causative_agent', 'symptoms', 'incubation_period',
#        'severity', 'notes'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['food', 'disease', 'causative_agent', 'symptoms', 'incubation_period',
#        'severity', 'notes'],
#       dtype='str')

# %%
df.head()
# Out:
#                  food  ...                                     notes
# 0             chicken  ...       Often caused by undercooked poultry
# 1                eggs  ...  Raw or lightly cooked eggs are high risk
# 2                beef  ...  Undercooked ground beef is common source
# 3  unpasteurized_milk  ...        Dangerous for pregnant individuals
# 4           shellfish  ...                   Highly contagious virus
#
# [5 rows x 7 columns]

# %%
print(df.columns)
# Out:
# Index(['food', 'disease', 'causative_agent', 'symptoms', 'incubation_period',
#        'severity', 'notes'],
#       dtype='str')

# %%
print(df.head())
print(df.columns)
print(df.info())
# Out:
#                  food  ...                                     notes
# 0             chicken  ...       Often caused by undercooked poultry
# 1                eggs  ...  Raw or lightly cooked eggs are high risk
# 2                beef  ...  Undercooked ground beef is common source
# 3  unpasteurized_milk  ...        Dangerous for pregnant individuals
# 4           shellfish  ...                   Highly contagious virus
#
# [5 rows x 7 columns]
# Index(['food', 'disease', 'causative_agent', 'symptoms', 'incubation_period',
#        'severity', 'notes'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   food               10 non-null     str
#  1   disease            10 non-null     str
#  2   causative_agent    10 non-null     str
#  3   symptoms           10 non-null     str
#  4   incubation_period  10 non-null     str
#  5   severity           10 non-null     str
#  6   notes              10 non-null     str
# dtypes: str(7)
# memory usage: 1.9 KB
# None

# %%
print('y_test' in globals())
# Out:
# False

# %%
print(rf_model)
# Out:
# RandomForestClassifier(random_state=42)
