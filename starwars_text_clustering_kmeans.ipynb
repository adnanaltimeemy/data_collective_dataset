# %%
# If needed (run once)
# !pip install pandas scikit-learn nltk matplotlib seaborn

import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("starwars.csv")

# Quick look
df.head()
# Out:
#              name  height   mass hair_color   skin_color eye_color  \
# 0  Luke Skywalker   172.0   77.0      blond         fair      blue
# 1           C-3PO   167.0   75.0        NaN         gold    yellow
# 2           R2-D2    96.0   32.0        NaN  white, blue       red
# 3     Darth Vader   202.0  136.0       none        white    yellow
# 4     Leia Organa   150.0   49.0      brown        light     brown
#
#    birth_year     sex     gender homeworld species  \
# 0        19.0    male  masculine  Tatooine   Human
# 1       112.0    none  masculine  Tatooine   Droid
# 2        33.0    none  masculine     Naboo   Droid
# 3        41.9    male  masculine  Tatooine   Human
# 4        19.0  female   feminine  Alderaan   Human
#
#                                                films  \
# 0  A New Hope, The Empire Strikes Back, Return of...
# 1  A New Hope, The Empire Strikes Back, Return of...
# 2  A New Hope, The Empire Strikes Back, Return of...
# 3  A New Hope, The Empire Strikes Back, Return of...
# 4  A New Hope, The Empire Strikes Back, Return of...
#
#                              vehicles                 starships
# 0  Snowspeeder, Imperial Speeder Bike  X-wing, Imperial shuttle
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN           TIE Advanced x1
# 4               Imperial Speeder Bike                       NaN

# %%
print(df.columns)
print(df.info())
# Out:
# Index(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color',
#        'birth_year', 'sex', 'gender', 'homeworld', 'species', 'films',
#        'vehicles', 'starships'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        87 non-null     str
#  1   height      81 non-null     float64
#  2   mass        59 non-null     float64
#  3   hair_color  82 non-null     str
#  4   skin_color  87 non-null     str
#  5   eye_color   87 non-null     str
#  6   birth_year  43 non-null     float64
#  7   sex         83 non-null     str
#  8   gender      83 non-null     str
#  9   homeworld   77 non-null     str
#  10  species     83 non-null     str
#  11  films       87 non-null     str
#  12  vehicles    11 non-null     str
#  13  starships   20 non-null     str
# dtypes: float64(3), str(11)
# memory usage: 18.0 KB
# None

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(df.columns)
# Out:
# Index(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color',
#        'birth_year', 'sex', 'gender', 'homeworld', 'species', 'films',
#        'vehicles', 'starships'],
#       dtype='str')

# %%
import numpy as np

X = np.array([
    [1, 2],
    [1, 4],
    [1, 0],
    [10, 2],
    [10, 4],
    [10, 0]
])

# %%
print(len(df), X.shape[0])
# Out:
# 87 6

# %%
if hasattr(X, "toarray"):
    X = X.toarray()

reduced = pca.fit_transform(X)

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
