# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("anonymized_ids_map.csv")

df.head()
# Out:
#   humanitarian_id  client_id
# 0          h_4884        NaN
# 1          h_5679        NaN
# 2          h_5706        NaN
# 3         h_21849    17850.0
# 4         h_11737    19104.0

# %%
print(df.shape)
print(df.info())
print(df.describe(include='all'))
# Out:
# (11360, 2)
# <class 'pandas.DataFrame'>
# RangeIndex: 11360 entries, 0 to 11359
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   humanitarian_id  8975 non-null   str
#  1   client_id        4779 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 232.5 KB
# None
#        humanitarian_id     client_id
# count             8975   4779.000000
# unique            8975           NaN
# top             h_4884           NaN
# freq                 1           NaN
# mean               NaN  11749.709563
# std                NaN   5030.282653
# min                NaN      1.000000
# 25%                NaN   7470.500000
# 50%                NaN  12520.000000
# 75%                NaN  16158.500000
# max                NaN  19284.000000

# %%
# Example: simple fill strategy (adjust if needed)
df = df.dropna()  # or use fillna methods if preferred

# %%
print(df.columns.tolist())
# Out:
# ['humanitarian_id', 'client_id']

# %%
print(df.columns.tolist())
# Out:
# ['humanitarian_id', 'client_id']

# %%
print(df.head())
print(df.columns)
# Out:
#   humanitarian_id  client_id
# 3         h_21849    17850.0
# 4         h_11737    19104.0
# 5         h_14833    19174.0
# 8         h_23520    10556.0
# 9         h_20969     2124.0
# Index(['humanitarian_id', 'client_id'], dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['humanitarian_id', 'client_id']

# %%
print(df.columns.tolist())
# Out:
# ['humanitarian_id', 'client_id']
