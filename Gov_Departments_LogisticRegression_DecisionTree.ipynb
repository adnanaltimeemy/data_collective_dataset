# %%
df[target_column].median()
# Out:
# np.float64(nan)

# %%
df.head.()
# Out:
#                                        Department Total Value of Contracts  \
# 0  Chemical Safety And Hazard Investigation Board                  $11,100
# 1                       Department Of Agriculture                 $700,081
# 2                          Department Of Commerce             $417,930,779
# 3                           Department Of Defense              $19,052,620
# 4                            Department Of Energy                  $43,435
#
#   Average Value of Contracts  Number of Contracts Small Business (%)  \
# 0                    $11,100                    1               100%
# 1                   $140,016                    5                80%
# 2                 $1,132,604                  369                60%
# 3                   $107,642                  177                74%
# 4                    $21,717                    2                50%
#
#    Women Owned Business? Minority Owned Business? Veteran Owned Business?  \
# ...

# %%
df.columns
# Out:
# Index(['Department', 'Total Value of Contracts', 'Average Value of Contracts',
#        'Number of Contracts', 'Small Business (%)', 'Women Owned Business?',
#        'Minority Owned Business?', 'Veteran Owned Business?',
#        'Nonprofit Organization?'],
#       dtype='str')
