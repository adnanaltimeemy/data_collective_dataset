# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("labeled_books.csv")

# Preview dataset
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  ... availability  price_category
# 0             0           0  ...     In stock         Premium
# 1             1           1  ...     In stock        Standard
# 2             2           2  ...     In stock        Standard
# 3             3           3  ...     In stock        Standard
# 4             4           4  ...     In stock        Standard
#
# [5 rows x 6 columns]

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    5000 non-null   int64
#  1   Unnamed: 0      5000 non-null   int64
#  2   title           5000 non-null   str
#  3   price           5000 non-null   float64
#  4   availability    5000 non-null   str
#  5   price_category  5000 non-null   str
# dtypes: float64(1), int64(2), str(3)
# memory usage: 501.8 KB
# None
#        Unnamed: 0.1   Unnamed: 0        price
# count   5000.000000  5000.000000  5000.000000
# mean    2499.500000  2499.500000    35.174942
# std     1443.520003  1443.520003    14.579948
# min        0.000000     0.000000    10.000000
# 25%     1249.750000  1249.750000    22.110000
# 50%     2499.500000  2499.500000    36.210000
# 75%     3749.250000  3749.250000    47.840000
# max     4999.000000  4999.000000    59.990000
# Unnamed: 0.1      0
# Unnamed: 0        0
# title             0
# price             0
# availability      0
# price_category    0
# dtype: int64

# %%
df = df.dropna()   # simple approach; adjust if needed

# %%
label_encoders = {}

text_cols = df.select_dtypes(include=['object', 'string']).columns

for column in text_cols:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column].astype(str))
    label_encoders[column] = le

# %%
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    5000 non-null   int64
#  1   Unnamed: 0      5000 non-null   int64
#  2   title           5000 non-null   int64
#  3   price           5000 non-null   float64
#  4   availability    5000 non-null   int64
#  5   price_category  5000 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0.1', 'Unnamed: 0', 'title', 'price', 'availability', 'price_category']

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'title', 'price', 'availability',
#        'price_category'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'title', 'price', 'availability',
#        'price_category'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'title', 'price', 'availability',
#        'price_category'],
#       dtype='str')
