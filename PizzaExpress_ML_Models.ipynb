# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("PizzaExpress.csv")

df.head()
# Out:
#            site       lat  ...                               email web
# 0  PizzaExpress  53.39393  ...    Cheadle.Manager@pizzaexpress.com NaN
# 1  PizzaExpress  53.42491  ...   Didsbury.Manager@pizzaexpress.com NaN
# 2  PizzaExpress  53.41220  ...  Stockport.Manager@pizzaexpress.com NaN
# 3  PizzaExpress  53.32537  ...   Wilmslow.Manager@pizzaexpress.com NaN
# 4  PizzaExpress  53.34890  ...    Poynton.Manager@pizzaexpress.com NaN
#
# [5 rows x 9 columns]

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   site     342 non-null    str
#  1   lat      342 non-null    float64
#  2   lng      342 non-null    float64
#  3   zip      342 non-null    str
#  4   name     342 non-null    str
#  5   address  342 non-null    str
#  6   phone    342 non-null    str
#  7   email    342 non-null    str
#  8   web      0 non-null      float64
# dtypes: float64(3), str(6)
# memory usage: 71.4 KB
# None
#               lat         lng  web
# count  342.000000  342.000000  0.0
# mean    52.153705   -1.044436  NaN
# std      1.321920    1.293964  NaN
# min     49.185350   -5.956460  NaN
# 25%     51.407633   -1.777652  NaN
# 50%     51.559820   -0.582942  NaN
# 75%     52.684181   -0.137990  NaN
# max     57.479300    1.291080  NaN
# site         0
# lat          0
# lng          0
# zip          0
# name         0
# address      0
# phone        0
# email        0
# web        342
# dtype: int64

# %%
df = df.dropna()  # simple approach

# %%
[target for target in df.columns if "target" in target.lower()]
# Out:
# []

# %%
[col for col in df.columns if "target" in col.lower()]
# Out:
# []

# %%
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
rf_model = RandomForestClassifier()
# missing rf_model.fit(...)
