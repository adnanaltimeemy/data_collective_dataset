# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("library_books.csv")

df.head()
# Out:
#                                                title  ...           isbn
# 0         Enseñar a investigar : libro del alumnado   ...  9788427132177
# 1                  Las Pseudociencias : ¡vaya timo!   ...  9788492422241
# 2  Bulos científicos : de la tierra plana al coro...  ...  9788441543072
# 3  La Actitud científica : una defensa de la cien...  ...  9788437641317
# 4  Guía del universo para escépticos : cómo descu...  ...  9788449336959
#
# [5 rows x 5 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe(include="all"))
# Out:
# (15228, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 15228 entries, 0 to 15227
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   15228 non-null  str
#  1   author  15228 non-null  str
#  2   tag     15228 non-null  str
#  3   series  9461 non-null   str
#  4   isbn    15228 non-null  str
# dtypes: str(5)
# memory usage: 1.9 MB
# None
#                             title author    tag                   series   isbn
# count                       15228  15228  15228                     9461  15228
# unique                      14818   8465   9787                     7236  14968
# top     Gran geografia universal          N Mar  Lonely Planet. Castellà
# freq                           12   1149     74                       77     83

# %%
df = df.dropna()  # simple approach (you can also impute if needed)

# %%
df = df.astype("object")

# %%
target_col = "target_column"

if target_col in df.columns:
    X = df.drop(target_col, axis=1)
    y = df[target_col]
else:
    print("Column not found. Available columns:", df.columns)
# Out:
# Column not found. Available columns: Index(['title', 'author', 'tag', 'series', 'isbn'], dtype='str')

# %%
df.columns
# Out:
# Index(['title', 'author', 'tag', 'series', 'isbn'], dtype='str')
