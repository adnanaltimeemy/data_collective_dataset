# %%
# Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Load dataset
df = pd.read_csv("submit_SVC_random.csv")

# View data
df.head()
# Out:
#       id       cuisine
# 0  18009         irish
# 1  28583   southern_us
# 2  41580       italian
# 3  29752  cajun_creole
# 4  35687       italian

# %%
print(df.head())
print(df.info())
# Out:
#       id       cuisine
# 0  18009         irish
# 1  28583   southern_us
# 2  41580       italian
# 3  29752  cajun_creole
# 4  35687       italian
# <class 'pandas.DataFrame'>
# RangeIndex: 9944 entries, 0 to 9943
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       9944 non-null   int64
#  1   cuisine  9944 non-null   str
# dtypes: int64(1), str(1)
# memory usage: 227.7 KB
# None

# %%
print(df.columns)
# Out:
# Index(['id', 'cuisine'], dtype='str')

# %%
df.columns
# Out:
# Index(['id', 'cuisine'], dtype='str')

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /Users/adnanaltimeemy
# ['ExplainLikeImCalvin.csv', 'CostaCoffee.ipynb', 'Sycho.ipynb', 'obscure_scifi_books_dataset.csv', 'Hugin_Fm_Base_cleaned.csv', 'Untitled Folder', 'bios.csv', 'Heavenly_Desserts_Manchester_Sales.ipynb', 'world-universities_cleaned.csv', 'pret_menu.csv', 'asos_ocado_dataset.ipynb', 'decision_tree_intro.ipynb', 'checkins_forest_tree.ipynb', 'CHECKOUT.ipynb', 'stress.csv', 'imdb_kmeans_clusters.csv', 'recruiting_costs_kmeans_nlp.ipynb', 'Dailyprices.ipynb', 'DSS.ipynb', 'Predicito.ipynb', 'glass.csv', 'energy_clusters_output.csv', ' penguin_random_house_sales_analysis.ipynb', 'degrees-that-pay-back.csv', 'Patrick.ipynb', 'iso.csv', 'Video Game Sales Data (Clean).csv', 'gala-mode.csv', 'ads_ctr_optimisation_decision_tree_random_forest.ipynb', 'hr-employee-attrition.csv', 'all_pivoted.csv', 'Austin.csv', 'Compare.ipynb', 'WORK assignment ', 'Cod.ipynb', 'muslim_bakery_uk_dataset.ipynb', 'chiquito_taco_bell_uk_dataset.ipynb', 'michael_kors_sales_profit_demographics_analysis.ipynb', 'rvd_nlp_logistic_regression.ipynb', 'manchester_halal_restaurants_sales_demographics.ipynb', 'BreadBasket.csv', 'bitcoin_mining_analysis.ipynb', '.meteostat', 'Miscellaneous.ipynb', 'heroes.csv', 'PizzaHut.csv', 'vw_vs_honda_comparison.csv', 'by_year.csv', 'profit_dataset.csv', 'Enhancement.csv', 'first_decision_tree.ipynb', 'fish_chips_data_insights.ipynb', 'runways_ml_classification.ipynb', 'Date_Clustering_Analysis.ipynb', 'wrestling_ppv_sales.ipynb', 'cybersecurity_books_sales_dataset.csv', 'Machine.Learning.Task.ipynb', 'DFA.ipynb', 'oregon_state_parks_nlp_kmeans.ipynb', 'tracks.csv', 'bmw_vs_toyota_sales_profit_demographics_analysis.ipynb', 'EmployeeAttrition_KMeans_NLP_Result.csv', 'abalone.csv', 'presidents.csv', 'warrior_raw_flapjack_sales_us_20260302.csv', 'nuclear_waste_sites_on_american_campuses_cleaned.csv', 'Biden.ipynb', 'list_of_UFC_scheduled_events.csv', 'oakmaninn_decision_tree_random_forest..ipynb', 'flare.csv', 'IndieGaming_Modeling.ipynb', 'playstation_market_analysis_manchester_uk.ipynb', 'Employee Dataset - AC1.csv', 'theses_ml_classification.ipynb', 'Bulldogs.csv', 'constituents.csv', 'amazon_data.ipynb', 'Shawn.ipynb', 'NASG.ipynb', 'wwwusage.csv', 'salford_hospitality_analysis.csv', 'owid-energy-codebook.csv', 'undefeated_nlp_unsupervised_learning.ipynb', 'Attribute_DataSet_cleaned.csv', 'Used_Car_Price_Data_Cleaned.csv', 'video_games_sales.csv', 'customers-100.csv', 'parks_cleaned.csv', 'introds_spotify.csv', 'groups.csv', 'Stars.csv', 'Vinces.ipynb', 'daily-workout-personal.csv', 'Ellsworth.ipynb', 'pizza_kb.sqlite', 'cleanjokes_ml_models.ipynb', 'UA-ORD.csv', 'DSA Dataset Cleaned.csv', 'miscellaneous.csv', 'boysnames.csv', 'raw_anonymized_data.csv', 'List of best-selling PlayStation 4 video games.csv', 'constellations.csv', 'vive_iron_brew_uk_us_full_dataset.ipynb', 'marketing_spend.csv', '500hits 3.csv', 'Twitter Stock Market Dataset.csv', 'ikea_matalan_kmeans_nlp.ipynb', '500hits.csv', 'bahamas.csv', 'spacex.csv', 'classic-rock-song-list.csv', 'WorldCupPlayers.csv', 'art_data.csv', 'clarks_uk_us_market_analysis.ipynb', 'data-pesticide.csv', 'GearsOfWar_RandomForest_Model.ipynb', 'temp2001_clean.csv', 'Untitled10.ipynb', 'operations_strategy_books_dataset.csv', 'mpg.csv', 'healthcare_usage.csv', 'uk-counties.csv', 'UrbanPubs.csv', 'eng.4.csv', 'Bank_Marketing.csv', 'Curry_Restaurant_Takeaway.ipynb', 'coursetopics_ml_models.ipynb', 'Bass_clustered.csv', 'Hiring_Analysis_Using_NLP_and_KMeans.ipynb', 'git-cheat-sheet.csv', 'pinball_data.csv', 'Elections_FAQs_AAAI2024_UK_cleaned.csv', 'Carsseats.ipynb', 'obscure_scifi_books_sales_profit_demographics.ipynb', 'trending.csv', 'Food.ipynb', 'Merge1.csv', 'dvdtrans.csv', 'toothgrowth.csv', 'Untitled7.ipynb', 'FriedChickenRestaurants.ipynb', 'ft_app.ipynb', 'fraud_det.ipynb', 'chevrolet_uk_sales_analysis.ipynb', 'ABH.ipynb', 'EssentialConstruction.csv', 'biochemist.csv', 'data_viz..ipynb', 'cardatasettrain.csv', 'merge.ipynb', 'Cheap_Meals.csv', 'housing.csv', 'play_off_box_scores_cle ...
