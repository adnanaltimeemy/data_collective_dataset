# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt

# NLP
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# K-Means
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Evaluation
from sklearn.metrics import silhouette_score

# %%
# Load dataset
df = pd.read_csv("bubble_chart_tutorial.csv")

# Display first rows
df.head()
# Out:
#         country  life expectancy  GDP per capita  population  year
# 0       Algeria           72.301     6223.367465  33333216.0  2007
# 1        Angola           42.731     4797.231267  12420476.0  2007
# 2         Benin           56.728     1441.284873   8078314.0  2007
# 3      Botswana           50.728    12569.851770   1639131.0  2007
# 4  Burkina Faso           52.295     1217.032994  14326203.0  2007

# %%
df = df.dropna()

print(df.shape)
# Out:
# (116, 5)

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['country', 'life expectancy', 'GDP per capita', 'population', 'year']
#         country  life expectancy  GDP per capita  population  year
# 0       Algeria           72.301     6223.367465  33333216.0  2007
# 1        Angola           42.731     4797.231267  12420476.0  2007
# 2         Benin           56.728     1441.284873   8078314.0  2007
# 3      Botswana           50.728    12569.851770   1639131.0  2007
# 4  Burkina Faso           52.295     1217.032994  14326203.0  2007

# %%
df.columns.tolist()
# Out:
# ['country', 'life expectancy', 'GDP per capita', 'population', 'year']

# %%
df.to_csv(
    "bubble_chart_kmeans_nlp_results.csv",
    index=False
)
