# %%
# Install if needed
# !pip install pandas numpy scikit-learn nltk matplotlib seaborn wordcloud

import pandas as pd
import numpy as np

import nltk
import re

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load dataset
df = pd.read_csv("asian.csv")

# Display first rows
df.head()
# Out:
#                                                   id  \
# 0               6-Ingredient-Chinese-Chicken-1370750
# 1  Orange-Flavored-Chicken-_Panda-Express-Copy-Ca...
# 2                                Sesame-Beef-1371164
# 3                 Vietnamese-Vermicelli-Bowl-1374692
# 4                       Easy-Pork-Fried-Rice-1365600
#
#                                          recipeName  rating  \
# 0                      6-Ingredient Chinese Chicken       4
# 1  Orange Flavored Chicken (Panda Express Copy Cat)       3
# 2                                       Sesame Beef       4
# 3                        Vietnamese Vermicelli Bowl       4
# 4                              Easy Pork Fried Rice       4
#
#    totalTimeInSeconds         course           cuisine  \
# 0              1500.0  [Main Dishes]  [Chinese, Asian]
# 1              3000.0  [Main Dishes]           [Asian]
# 2              1200.0  [Main Dishes]           [Asian]
# 3              3300.0  [Main Dishes]           [Asian]
# 4              1800.0             []           [Asian]
#
#                                          ingredients
# 0  [minced ginger, garlic chili sauce, hoisin sau...
# 1  [boneless skinless chicken breasts, egg whites...
# 2  [sesame oil, garlic, flank steak, red bell pep...
# 3  [chicken, lemongrass, onions, garlic cloves, k...
# 4  [eggs, smoked ham, shallots, carrots, long-gra...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  605 non-null    str
#  1   recipeName          605 non-null    str
#  2   rating              605 non-null    int64
#  3   totalTimeInSeconds  598 non-null    float64
#  4   course              515 non-null    str
#  5   cuisine             605 non-null    str
#  6   ingredients         605 non-null    str
# dtypes: float64(1), int64(1), str(5)
# memory usage: 167.5 KB

# %%
print(df.columns.tolist())
# Out:
# ['id', 'recipeName', 'rating', 'totalTimeInSeconds', 'course', 'cuisine', 'ingredients']

# %%
df.head()
# Out:
#                                                   id  \
# 0               6-Ingredient-Chinese-Chicken-1370750
# 1  Orange-Flavored-Chicken-_Panda-Express-Copy-Ca...
# 2                                Sesame-Beef-1371164
# 3                 Vietnamese-Vermicelli-Bowl-1374692
# 4                       Easy-Pork-Fried-Rice-1365600
#
#                                          recipeName  rating  \
# 0                      6-Ingredient Chinese Chicken       4
# 1  Orange Flavored Chicken (Panda Express Copy Cat)       3
# 2                                       Sesame Beef       4
# 3                        Vietnamese Vermicelli Bowl       4
# 4                              Easy Pork Fried Rice       4
#
#    totalTimeInSeconds         course           cuisine  \
# 0              1500.0  [Main Dishes]  [Chinese, Asian]
# 1              3000.0  [Main Dishes]           [Asian]
# 2              1200.0  [Main Dishes]           [Asian]
# 3              3300.0  [Main Dishes]           [Asian]
# 4              1800.0             []           [Asian]
#
#                                          ingredients
# 0  [minced ginger, garlic chili sauce, hoisin sau...
# 1  [boneless skinless chicken breasts, egg whites...
# 2  [sesame oil, garlic, flank steak, red bell pep...
# 3  [chicken, lemongrass, onions, garlic cloves, k...
# 4  [eggs, smoked ham, shallots, carrots, long-gra...

# %%
df.to_csv(
    "asian_clustered.csv",
    index=False
)
