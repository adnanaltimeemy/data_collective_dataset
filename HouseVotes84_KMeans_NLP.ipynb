# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt

# Machine learning
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# NLP tools
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Load CSV file
df = pd.read_csv("HouseVotes84.csv")

# Display first rows
df.head()
# Out:
#    Class   V1 V2 V3   V4   V5 V6 V7 V8 V9 V10  V11  V12 V13 V14 V15  V16
# 0      1    n  y  n    y    y  y  n  n  n   y  NaN    y   y   y   n    y
# 1      1    n  y  n    y    y  y  n  n  n   n    n    y   y   y   n  NaN
# 2      0  NaN  y  y  NaN    y  y  n  n  n   n    y    n   y   y   n    n
# 3      0    n  y  y    n  NaN  y  n  n  n   n    y    n   y   n   n    y
# 4      0    y  y  y    n    y  y  n  n  n   n    y  NaN   y   y   y    y

# %%
# Dataset information
df.info()

# Check missing values
df.isnull().sum()

# View columns
df.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Class   435 non-null    int64
#  1   V1      423 non-null    str
#  2   V2      387 non-null    str
#  3   V3      424 non-null    str
#  4   V4      424 non-null    str
#  5   V5      420 non-null    str
#  6   V6      424 non-null    str
#  7   V7      421 non-null    str
#  8   V8      420 non-null    str
#  9   V9      413 non-null    str
#  10  V10     428 non-null    str
#  11  V11     414 non-null    str
#  12  V12     404 non-null    str
#  13  V13     410 non-null    str
#  14  V14     418 non-null    str
#  15  V15     407 non-null    str
#  16  V16     331 non-null    str
# dtypes: int64(1), str(16)
# memory usage: 65.2 KB
# Index(['Class', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['Class', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16'],
#       dtype='str')

# %%
df.head()
# Out:
#    Class   V1 V2 V3   V4   V5 V6 V7 V8 V9 V10  V11  V12 V13 V14 V15  V16
# 0      1    n  y  n    y    y  y  n  n  n   y  NaN    y   y   y   n    y
# 1      1    n  y  n    y    y  y  n  n  n   n    n    y   y   y   n  NaN
# 2      0  NaN  y  y  NaN    y  y  n  n  n   n    y    n   y   y   n    n
# 3      0    n  y  y    n  NaN  y  n  n  n   n    y    n   y   n   n    y
# 4      0    y  y  y    n    y  y  n  n  n   n    y  NaN   y   y   y    y

# %%
df.head()
# Out:
#    Class   V1 V2 V3   V4   V5 V6 V7 V8 V9 V10  V11  V12 V13 V14 V15  V16
# 0      1    n  y  n    y    y  y  n  n  n   y  NaN    y   y   y   n    y
# 1      1    n  y  n    y    y  y  n  n  n   n    n    y   y   y   n  NaN
# 2      0  NaN  y  y  NaN    y  y  n  n  n   n    y    n   y   y   n    n
# 3      0    n  y  y    n  NaN  y  n  n  n   n    y    n   y   n   n    y
# 4      0    y  y  y    n    y  y  n  n  n   n    y  NaN   y   y   y    y

# %%
df.columns
# Out:
# Index(['Class', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16'],
#       dtype='str')
