# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Ingredients.csv")

df.head()
# Out:
#   ing_id       ing_name  ing_weight  ing_meas   ing_price
# 0  ING001    Pizza Base         2000     grams       4.22
# 1  ING002  Tomato Sauce         4500     grams       3.89
# 2  ING003    Mozzarella         2500     grams      14.45
# 3  ING004       Oregano          500     grams       5.99
# 4  ING005  Spicy Salami         3500     grams      37.64

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (42, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ing_id       42 non-null     str
#  1   ing_name     42 non-null     str
#  2   ing_weight   42 non-null     int64
#  3   ing_meas     42 non-null     str
#  4   ing_price    42 non-null     float64
# dtypes: float64(1), int64(1), str(3)
# memory usage: 2.6 KB
# None
# ing_id         0
# ing_name       0
# ing_weight     0
# ing_meas       0
# ing_price      0
# dtype: int64

# %%
df = df.dropna()  # or you can use fillna() depending on dataset

# %%
label_encoders = {}

for column in df.columns:
    if df[column].dtype == 'object':
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column])
        label_encoders[column] = le

# %%
df.columns = df.columns.str.strip().str.lower()
print(df.columns)
# Out:
# Index(['ing_id', 'ing_name', 'ing_weight', 'ing_meas', 'ing_price'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['ing_id', 'ing_name', 'ing_weight', 'ing_meas', 'ing_price'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['ing_id', 'ing_name', 'ing_weight', 'ing_meas', 'ing_price'], dtype='str')

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#    ing_id      ing_name  ing_weight ing_meas  ing_price
# 0  ING001    Pizza Base        2000    grams       4.22
# 1  ING002  Tomato Sauce        4500    grams       3.89
# 2  ING003    Mozzarella        2500    grams      14.45
# 3  ING004       Oregano         500    grams       5.99
# 4  ING005  Spicy Salami        3500    grams      37.64
# ['ing_id', 'ing_name', 'ing_weight', 'ing_meas', 'ing_price']

# %%
print(df.columns)
# Out:
# Index(['ing_id', 'ing_name', 'ing_weight', 'ing_meas', 'ing_price'], dtype='str')
