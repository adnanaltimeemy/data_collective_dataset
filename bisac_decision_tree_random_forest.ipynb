# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("bisac.csv")

df.head()
# Out:
#         Code                                        Description  \
# 0        NaN  Complete BISAC Subject Headings List, 2021 Edi...
# 1  ANT000000                  Antiques & Collectibles / General
# 2  ANT056000              Antiques & Collectibles / Advertising
# 3  ANT001000                Antiques & Collectibles / Americana
# 4  ANT002000                      Antiques & Collectibles / Art
#
#                                              Comment
# 0  Generated on 2022-02-03T17:00:35.308Z from htt...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
print(df.shape)
print(df.info())
print(df.describe())

# Check missing values
print(df.isnull().sum())
# Out:
# (5129, 3)
# <class 'pandas.DataFrame'>
# RangeIndex: 5129 entries, 0 to 5128
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         5128 non-null   str
#  1   Description  5129 non-null   str
#  2   Comment      276 non-null    str
# dtypes: str(3)
# memory usage: 375.4 KB
# None
#              Code                                        Description Comment
# count        5128                                               5129     276
# unique       5128                                               5129     157
# top     ANT000000  Complete BISAC Subject Headings List, 2021 Edi...       *
# freq            1                                                  1      80
# Code              1
# Description       0
# Comment        4853
# dtype: int64

# %%
df = df.dropna()  # or use imputation if needed

# %%
target_column = "target"

# %%
print(df.head())      # if your dataframe is called df
print(df.columns)
# Out:
#           Code                                     Description  \
# 31   ANT036000  Antiques & Collectibles / Radios & Televisions
# 36   ANT043000                Antiques & Collectibles / Sports
# 67   ARC005070                 Architecture / History / Modern
# 68   ARC005080           Architecture / History / Contemporary
# 115  ART067000                                 Art / Forgeries
#
#                                     Comment
# 31               (see also Performing Arts)
# 36   (see also headings under Sports Cards)
# 67              (late 19th Century to 1945)
# 68                                  (1945-)
# 115                                       *
# Index(['Code', 'Description', 'Comment'], dtype='str')

# %%
print(df.head())      # if your dataframe is called df
print(df.columns)
# Out:
#           Code                                     Description  \
# 31   ANT036000  Antiques & Collectibles / Radios & Televisions
# 36   ANT043000                Antiques & Collectibles / Sports
# 67   ARC005070                 Architecture / History / Modern
# 68   ARC005080           Architecture / History / Contemporary
# 115  ART067000                                 Art / Forgeries
#
#                                     Comment
# 31               (see also Performing Arts)
# 36   (see also headings under Sports Cards)
# 67              (late 19th Century to 1945)
# 68                                  (1945-)
# 115                                       *
# Index(['Code', 'Description', 'Comment'], dtype='str')

# %%
print(df.head())      # if your dataframe is called df
print(df.columns)
# Out:
#           Code                                     Description  \
# 31   ANT036000  Antiques & Collectibles / Radios & Televisions
# 36   ANT043000                Antiques & Collectibles / Sports
# 67   ARC005070                 Architecture / History / Modern
# 68   ARC005080           Architecture / History / Contemporary
# 115  ART067000                                 Art / Forgeries
#
#                                     Comment
# 31               (see also Performing Arts)
# 36   (see also headings under Sports Cards)
# 67              (late 19th Century to 1945)
# 68                                  (1945-)
# 115                                       *
# Index(['Code', 'Description', 'Comment'], dtype='str')

# %%
for var in ["X", "y", "X_train", "X_test", "y_train", "y_test", "y_pred_dt", "y_pred_rf"]:
    print(var, var in globals())
# Out:
# X False
# y False
# X_train False
# X_test False
# y_train False
# y_test False
# y_pred_dt False
# y_pred_rf False

# %%
print("Done training Decision Tree and Random Forest models on BISAC dataset.")
# Out:
# Done training Decision Tree and Random Forest models on BISAC dataset.
