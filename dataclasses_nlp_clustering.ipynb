# %%
# !pip install pandas scikit-learn nltk

import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas in ./miniconda3/envs/coding/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: scikit-learn in ./miniconda3/envs/coding/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: nltk in ./miniconda3/envs/coding/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from pandas) (2.4.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click in ./miniconda3/envs/coding/lib/python3.12/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from nltk) (2025.10.23)
# Requirement already satisfied: tqdm in ./miniconda3/envs/coding/lib/python3.12/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("dataclasses.csv")

# Show first rows
df.head()
# Out:
#                                      id  \
# 0  0983ac30-580d-45cc-812c-13c2dba5e192
# 1  b811050c-e71e-4f60-90a8-93dc6251b9f5
# 2  d96ed8a1-826d-4791-8fba-8301c981e03c
# 3  c6899c35-e26b-4deb-b941-b6b329d6f2d5
# 4  64f02959-926b-4952-b6b8-c0ce9c2238ad
#
#                                         dataElements  \
# 0  76b3501c-f490-4697-b973-3cec99c4f39c, 6e7d0525...
# 1  0893b020-8f33-4bd8-b26f-d19008f8bd60, 2c04b5b5...
# 2  c8a8be9c-d769-4d56-8d2a-9354e7775871, ce84efc4...
# 3  cb175a08-f789-49e0-8d5f-85fe90df70da, 15a97525...
# 4  d467ed99-5b60-48ef-b2ef-789b5ef3e44e, 64959a36...
#
#                               description                          name  \
# 0  Genomic variant of concern calls table             GENOMIC_VOC_CALLS
# 1                   Genomic summary table               GENOMIC_SUMMARY
# 2                       Genomic ALF table                   GENOMIC_ALF
# 3                 Genomic mutations table             GENOMIC_MUTATIONS
# 4                      Diagnostic Section  General Clinical Information
#
#    dataElementsCount
# 0                 10
# 1                  5
# 2                 14
# 3                  5
# 4                 18

# %%
print(df.info())
print(df.columns)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2853 non-null   str
#  1   dataElements       2920 non-null   str
#  2   description        2055 non-null   str
#  3   name               2853 non-null   str
#  4   dataElementsCount  2922 non-null   int64
# dtypes: int64(1), str(4)
# memory usage: 5.9 MB
# None
# Index(['id', 'dataElements', 'description', 'name', 'dataElementsCount'], dtype='str')

# %%
stop_words = set(stopwords.words("english"))

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [w for w in tokens if w not in stop_words]
    return " ".join(tokens)

# %%
print(df.columns)
# Out:
# Index(['id', 'dataElements', 'description', 'name', 'dataElementsCount'], dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
print("clean_text" in df.columns)
print("X exists:", "X" in globals())
# Out:
# False
# X exists: False

# %%
print(df.columns)
# Out:
# Index(['id', 'dataElements', 'description', 'name', 'dataElementsCount'], dtype='str')

# %%
df.head()
# Out:
#                                      id  \
# 0  0983ac30-580d-45cc-812c-13c2dba5e192
# 1  b811050c-e71e-4f60-90a8-93dc6251b9f5
# 2  d96ed8a1-826d-4791-8fba-8301c981e03c
# 3  c6899c35-e26b-4deb-b941-b6b329d6f2d5
# 4  64f02959-926b-4952-b6b8-c0ce9c2238ad
#
#                                         dataElements  \
# 0  76b3501c-f490-4697-b973-3cec99c4f39c, 6e7d0525...
# 1  0893b020-8f33-4bd8-b26f-d19008f8bd60, 2c04b5b5...
# 2  c8a8be9c-d769-4d56-8d2a-9354e7775871, ce84efc4...
# 3  cb175a08-f789-49e0-8d5f-85fe90df70da, 15a97525...
# 4  d467ed99-5b60-48ef-b2ef-789b5ef3e44e, 64959a36...
#
#                               description                          name  \
# 0  Genomic variant of concern calls table             GENOMIC_VOC_CALLS
# 1                   Genomic summary table               GENOMIC_SUMMARY
# 2                       Genomic ALF table                   GENOMIC_ALF
# 3                 Genomic mutations table             GENOMIC_MUTATIONS
# 4                      Diagnostic Section  General Clinical Information
#
#    dataElementsCount
# 0                 10
# 1                  5
# 2                 14
# 3                  5
# 4                 18

# %%
df.to_csv("clustered_dataclasses.csv", index=False)
