# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
# Load dataset
df = pd.read_csv("sim_test.csv")

# View first rows
df.head()
# Out:
#          X1        X2  class
# 0  0.979931 -0.452415      2
# 1 -0.123013  0.888393      2
# 2  0.399806 -0.108033      1
# 3  0.778154  0.083574      1
# 4  0.668319 -0.676491      2

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (1000, 3)
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      1000 non-null   float64
#  1   X2      1000 non-null   float64
#  2   class   1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB
# None
# X1       0
# X2       0
# class    0
# dtype: int64

# %%
df[col]
# Out:
# 0      2
# 1      2
# 2      1
# 3      1
# 4      2
#       ..
# 995    2
# 996    1
# 997    1
# 998    1
# 999    1
# Name: class, Length: 1000, dtype: int64

# %%
label_encoders = {}

for col in df.select_dtypes(include='object').columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
print(df.columns.tolist())
# Out:
# ['X1', 'X2', 'class']

# %%
print(df.columns.tolist())
# Out:
# ['X1', 'X2', 'class']

# %%
print(df.columns.tolist())
# Out:
# ['X1', 'X2', 'class']

# %%
print(locals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'DecisionTreeClassifier', 'RandomForestClassifier', 'accuracy_score', 'classification_report', 'confusion_matrix', 'LabelEncoder', '_i2', 'df', '_2', '_i3', '_i4', 'col', '_i5', '_5', '_i6', 'label_encoders', '_i7', '_i8', '_i9', '_i10', '_i11', 'dt_model', '_i12', '_i13', 'rf_model', '_i14'])
