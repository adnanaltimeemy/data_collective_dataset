# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Marstonpubs.csv")

# View dataset
print(df.head())
print(df.info())
# Out:
#           site  ...                                   web
# 0  Marstonpubs  ...  https://www.abbeymeadsswindon.co.uk/
# 1  Marstonpubs  ...     https://www.abbeyvaultspub.co.uk/
# 2  Marstonpubs  ...           https://www.acornpub.co.uk/
# 3  Marstonpubs  ...                                   NaN
# 4  Marstonpubs  ...    https://www.admiralhardypub.co.uk/
#
# [5 rows x 9 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 1441 entries, 0 to 1440
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   site     1441 non-null   str
#  1   lat      1441 non-null   float64
#  2   lng      1441 non-null   float64
#  3   zip      0 non-null      float64
#  4   name     1441 non-null   str
#  5   address  1441 non-null   str
#  6   phone    1425 non-null   str
#  7   email    1434 non-null   str
#  8   web      1033 non-null   str
# dtypes: float64(3), str(6)
# memory usage: 304.9 KB
# None

# %%
# Check missing values
print(df.isnull().sum())

# Fill or drop missing values (example: drop)
df = df.dropna()
# Out:
# site          0
# lat           0
# lng           0
# zip        1441
# name          0
# address       0
# phone        16
# email         7
# web         408
# dtype: int64

# %%
import pandas as pd

for column in df.columns:
    if pd.api.types.is_string_dtype(df[column]) or pd.api.types.is_object_dtype(df[column]):
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column].astype(str))
        label_encoders[column] = le

# %%
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   site     0 non-null      float64
#  1   lat      0 non-null      float64
#  2   lng      0 non-null      float64
#  3   zip      0 non-null      float64
#  4   name     0 non-null      float64
#  5   address  0 non-null      float64
#  6   phone    0 non-null      float64
#  7   email    0 non-null      float64
#  8   web      0 non-null      float64
# dtypes: float64(9)
# memory usage: 132.0 bytes

# %%
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'LabelEncoder', 'DecisionTreeClassifier', 'RandomForestClassifier', 'accuracy_score', 'classification_report', 'confusion_matrix', '_i2', 'df', '_i3', '_i4', 'label_encoders', 'column', 'le', '_i5', '_i6', '_i7', '_i8', '_i9', '_i10', 'dt_model', '_i11', '_i12', 'rf_model', '_i13', '_i14'])

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'LabelEncoder', 'DecisionTreeClassifier', 'RandomForestClassifier', 'accuracy_score', 'classification_report', 'confusion_matrix', '_i2', 'df', '_i3', '_i4', 'label_encoders', 'column', 'le', '_i5', '_i6', '_i7', '_i8', '_i9', '_i10', 'dt_model', '_i11', '_i12', 'rf_model', '_i13', '_i14', '_i15', '_i16'])
