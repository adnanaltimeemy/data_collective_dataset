# %%
import pandas as pd
import numpy as np

# NLP
from sklearn.feature_extraction.text import TfidfVectorizer

# Clustering
from sklearn.cluster import KMeans

# Visualization
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("wings.csv")

# Show basic info
print(df.head())
print(df.info())
# Out:
#                                    id  ...   dish
# 0   Spicy-Maple-Chicken-Wings-1360271  ...  wings
# 1                       Wings-1172591  ...  wings
# 2        Crispy-Buffalo-Wings-1350569  ...  wings
# 3  Honey-Glazed-Chicken-Wings-1378568  ...  wings
# 4         Baked-Chicken-Wings-1367538  ...  wings
#
# [5 rows x 8 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  366 non-null    str
#  1   recipeName          366 non-null    str
#  2   rating              366 non-null    int64
#  3   totalTimeInSeconds  356 non-null    float64
#  4   course              334 non-null    str
#  5   cuisine             47 non-null     str
#  6   ingredients         366 non-null    str
#  7   dish                366 non-null    str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 88.7 KB
# None

# %%
print(df.columns.tolist())
# Out:
# ['id', 'recipeName', 'rating', 'totalTimeInSeconds', 'course', 'cuisine', 'ingredients', 'dish']

# %%
print(df.columns.tolist())
# Out:
# ['id', 'recipeName', 'rating', 'totalTimeInSeconds', 'course', 'cuisine', 'ingredients', 'dish']

# %%
print(df.head())
# Out:
#                                    id  ...   dish
# 0   Spicy-Maple-Chicken-Wings-1360271  ...  wings
# 1                       Wings-1172591  ...  wings
# 2        Crispy-Buffalo-Wings-1350569  ...  wings
# 3  Honey-Glazed-Chicken-Wings-1378568  ...  wings
# 4         Baked-Chicken-Wings-1367538  ...  wings
#
# [5 rows x 8 columns]

# %%
print("cluster" in df.columns)
# Out:
# False

# %%
print(type(df))
print('texts' in globals())
print('X' in globals())
# Out:
# <class 'pandas.DataFrame'>
# False
# False
