# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("street-tree-data-TO.csv")
df.head()
# Out:
#    _id  OBJECTID  STRUCTID  ADDRESS            STREETNAME       CROSSSTREET1  \
# 0    1         1  TO105087      145  ST GEORGE ST TORONTO  PRINCE ARTHUR AVE
# 1   34        35   TO18965      330            CLINTON ST    NANCY POCOCK PL
# 2   37        38   TO16750      161          CHAPLIN CRES          AVENUE RD
# 3   48        49   TO37844     1669          GERRARD ST E    GAINSBOROUGH RD
# 4   64        65   TO16574        9           CHANNEL AVE                NaN
#
#   CROSSSTREET2 SUFFIX  UNIT_NUMBER  TREE_POSITION_NUMBER SITE  WARD  \
# 0  LOWTHER AVE    NaN            0                  30.0  NaN  11.0
# 1   CLINTON PL    NaN            0                  10.0  NaN  11.0
# 2  BRAEMAR AVE    NaN            0                  10.0  NaN  12.0
# 3   WEMBLEY DR    NaN            0                  10.0  NaN  19.0
# 4          NaN    NaN            0                  10.0  NaN  10.0
#
#           BOTANICAL_NAME    COMMON_NAME  DBH_TRUNK  \
# 0  Gleditsia triacanthos   Honey locust       19.0
# 1       Acer platanoides  Maple, Norway       72.0
# 2      Betula papyrifera   Birch, white       45.0
# 3                  Tilia         Linden       61.0
# 4               Fraxinus            Ash       44.0
#
#                                             geometry
# 0  {"type": "Point", "coordinates": [-79.40031615...
# 1  {"type": "Point", "coordinates": [-79.41687449...
# 2  {"type": "Point", "coordinates": [-79.40731236...
# 3  {"type": "Point", "coordinates": [-79.31830349...
# 4  {"type": "Point", "coordinates": [-79.35499777...

# %%
print(df.shape)
print(df.info())
print(df.describe(include='all'))
# Out:
# (51156, 16)
# <class 'pandas.DataFrame'>
# RangeIndex: 51156 entries, 0 to 51155
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   _id                   51156 non-null  int64
#  1   OBJECTID              51156 non-null  int64
#  2   STRUCTID              51156 non-null  str
#  3   ADDRESS               51156 non-null  int64
#  4   STREETNAME            51155 non-null  str
#  5   CROSSSTREET1          49582 non-null  str
#  6   CROSSSTREET2          48656 non-null  str
#  7   SUFFIX                407 non-null    str
#  8   UNIT_NUMBER           51156 non-null  int64
#  9   TREE_POSITION_NUMBER  51152 non-null  float64
#  10  SITE                  2113 non-null   str
#  11  WARD                  51155 non-null  float64
#  12  BOTANICAL_NAME        51156 non-null  str
#  13  COMMON_NAME           51156 non-null  str
#  14  DBH_TRUNK             51155 non-null  float64
#  15  geometry              51156 non-null  str
# dtypes: float64(3), int64(4), str(9)
# memory usage: 13.6 MB
# None
#                   _id       OBJECTID  STRUCTID       ADDRESS  \
# count    51156.000000   51156.000000     51156  51156.000000
# unique            NaN            NaN     51156           NaN
# top               NaN            NaN  TO105087           NaN
# freq              NaN            NaN         1           NaN
# mean    345067.769020  345115.067069       NaN    219.719661
# std     199436.461783  199462.820511       NaN    344.168132
# min          1.000000       1.000000       NaN      1.000000
# 25%     171207.750000  171230.750000       NaN     40.000000
# 50%     344849.000000  344894.000000       NaN    100.000000
# 75%     519158.750000  519229.750000       NaN    254.000000
# max     689359.000000  689450.000000       NaN   3444.000000
#
#                 STREETNAME       CROSSSTREET1       CROSSSTREET2 SUFFIX  \
# count                51155              49582              48656    407
# unique                1584               2953               2837      5
# top     OLD FOREST HILL RD  MOUNT PLEASANT RD  MOUNT PLEASANT RD      A
# freq                   352                728                643    312
# mean                   NaN                NaN                NaN    NaN
# std                    NaN                NaN                NaN    NaN
# min                    NaN                NaN                NaN    NaN
# 25%                    NaN                NaN                NaN    NaN
# 50%                    NaN                NaN                NaN    NaN
# 75%                    NaN                NaN                NaN    NaN
# max                    NaN                NaN                NaN    NaN
#
#         UNIT_NUMBER  TREE_POSITION_NUMBER       SITE          WARD  \
# count       51156.0          51152.000000       2113  51155.000000
# unique          NaN                   NaN        215           NaN
# top             NaN                   NaN  MOSS PARK           NaN
# freq            NaN                   NaN        120           NaN
# mean            0.0            833.759071        NaN     11.156544
# std             0.0           8779.562394        NaN      4.208132
# min             0.0              1.000000        NaN      4.000000
# 25%             0.0             10.000000        NaN      9.000000
# 50%             0.0             10.000000        NaN     11.000000
# 75%             0.0             30.000000        NaN     14.000000
# max             0.0          99999.000000        NaN     24.000000
#
#           BOTANICAL_NAME    COMMON_NAME     DBH_TRUNK  \
# count              51156          51156  51155.000000
# unique               217            218           NaN
# top     Acer platanoides  Maple, Norway           NaN
# freq                9506           9506           NaN
# mean                 NaN            NaN     44.858157
# std                  NaN            NaN     25.948259
# min                  NaN            NaN      1.000000
# 25%                  NaN            NaN     25.000000
# 50%                  NaN            NaN     40.000000
# 75%                  NaN            NaN     61.000000
# max                  NaN            NaN    540.000000
#
#                                                  geometry
# count                                               51156
# unique                                              46397
# top     {"type": "Point", "coordinates": [-79.37039696...
# freq                                                   97
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
df = df.dropna()  # simple approach (you can improve later)

# %%
target = "TREE_CONDITION"   # CHANGE THIS if your dataset uses another name

# %%
categorical_cols = df.select_dtypes(include=['object', 'string', 'category']).columns

# %%
df.index.name
df.index
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [_id, OBJECTID, STRUCTID, ADDRESS, STREETNAME, CROSSSTREET1, CROSSSTREET2, SUFFIX, UNIT_NUMBER, TREE_POSITION_NUMBER, SITE, WARD, BOTANICAL_NAME, COMMON_NAME, DBH_TRUNK, geometry]
# Index: []

# %%
(df.columns)
# Out:
# Index(['_id', 'OBJECTID', 'STRUCTID', 'ADDRESS', 'STREETNAME', 'CROSSSTREET1',
#        'CROSSSTREET2', 'SUFFIX', 'UNIT_NUMBER', 'TREE_POSITION_NUMBER', 'SITE',
#        'WARD', 'BOTANICAL_NAME', 'COMMON_NAME', 'DBH_TRUNK', 'geometry'],
#       dtype='str')
