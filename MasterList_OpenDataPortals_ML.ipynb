# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("MasterList_OpenDataPortals.csv")

# View basic info
print(df.head())
print(df.info())
print(df.describe(include="all"))
# Out:
#   Province         Organization        Type  \
# 0       AB  Province of Alberta  Provincial
# 1       AB                Banff   Municipal
# 2       AB              Canmore   Municipal
# 3       AB          Chestermere   Municipal
# 4       AB              Calgary   Municipal
#
#                                                  URL URL 2  \
# 0                   https://open.alberta.ca/opendata   NaN
# 1                    https://maps.banff.ca/opendata/   NaN
# 2       http://opendata-canmore.opendata.arcgis.com/   NaN
# 3  https://www.arcgis.com/home/search.html?q=owne...   NaN
# 4                           https://data.calgary.ca/   NaN
#
#                                              License  \
# 0                    https://open.alberta.ca/licence
# 1                      http://banffmaps.ca/opendata/
# 2  https://s3.amazonaws.com/canmoregis/OpenData/T...
# 3                                No License Provided
# 4  https://data.calgary.ca/stories/s/Open-Calgary...
#
#                                          Attribution Libraries Hospitals GTFS  \
# 0  Contains information licensed under the Open G...       NaN       NaN  NaN
# 1  Contains information licensed under the Open G...       NaN       NaN  NaN
# 2  Contains information licensed under the Town o...       NaN       NaN  NaN
# 3                                                NaN       NaN       NaN  NaN
# 4  Contains information licensed under the Open G...       Yes       NaN  Yes
#
#   Buildings Businesses Police Fire Education Parks Community Centers
# 0       NaN        NaN    NaN  NaN       Yes   NaN               NaN
# 1       Yes        NaN    NaN  NaN       NaN   NaN               NaN
# 2       Yes        NaN    NaN  NaN       NaN   Yes               NaN
# 3       Yes        NaN    NaN  NaN       NaN   NaN               NaN
# 4       NaN        NaN    Yes  NaN       Yes   Yes               Yes
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Province           111 non-null    str
#  1   Organization       111 non-null    str
#  2   Type               111 non-null    str
#  3   URL                111 non-null    str
#  4   URL 2              2 non-null      str
#  5   License            105 non-null    str
#  6   Attribution        78 non-null     str
#  7   Libraries          36 non-null     str
#  8   Hospitals          15 non-null     str
#  9   GTFS               33 non-null     str
#  10  Buildings          63 non-null     str
#  11  Businesses         3 non-null      str
#  12  Police             15 non-null     str
#  13  Fire               27 non-null     str
#  14  Education          8 non-null      str
#  15  Parks              6 non-null      str
#  16  Community Centers  5 non-null      str
# dtypes: str(17)
# memory usage: 38.4 KB
# None
#        Province               Organization       Type  \
# count       111                        111        111
# unique       12                        107          4
# top          ON  Province of New Brunswick  Municipal
# freq         40                          2         92
#
#                                 URL  \
# count                           111
# unique                          110
# top     http://geohub.cambridge.ca/
# freq                              2
#
#                                                     URL 2  \
# count                                                   2
# unique                                                  2
# top     http://gatineau.ca/donneesouvertes/default_en....
# freq                                                    1
#
#                                                License  \
# count                                              105
# unique                                              91
# top     https://www.donneesquebec.ca/fr/licence/#cc-by
# freq                                                15
#
#                                               Attribution Libraries Hospitals  \
# count                                                  78        36        15
# unique                                                 77         2         1
# top     Contains information licensed under the Open G...       Yes       Yes
# freq                                                    2        35        15
#
#        GTFS Buildings Businesses Police Fire Education Parks Community Centers
# count    33        63          3     15   27         8     6                 5
# unique    1         1          1      1    1         1     1                 1
# top     Yes       Yes        Yes    Yes  Yes       Yes   Yes               Yes
# freq     33        63          3     15   27         8     6                 5

# %%
# Drop duplicates
df = df.drop_duplicates()

# Handle missing values (simple approach)
df = df.dropna()

print(df.isnull().sum())
# Out:
# Province             0
# Organization         0
# Type                 0
# URL                  0
# URL 2                0
# License              0
# Attribution          0
# Libraries            0
# Hospitals            0
# GTFS                 0
# Buildings            0
# Businesses           0
# Police               0
# Fire                 0
# Education            0
# Parks                0
# Community Centers    0
# dtype: int64

# %%
target_column = "target_column"  # <-- change this

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for column in df.select_dtypes(include=["object", "string"]).columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# %%
label_encoders = {}

for column in df.select_dtypes(include=["object"]).columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# %%
print(df.columns.tolist())
# Out:
# ['Province', 'Organization', 'Type', 'URL', 'URL 2', 'License', 'Attribution', 'Libraries', 'Hospitals', 'GTFS', 'Buildings', 'Businesses', 'Police', 'Fire', 'Education', 'Parks', 'Community Centers']

# %%
print(df.head())
print(df.columns)
# Out:
# Empty DataFrame
# Columns: [Province, Organization, Type, URL, URL 2, License, Attribution, Libraries, Hospitals, GTFS, Buildings, Businesses, Police, Fire, Education, Parks, Community Centers]
# Index: []
# Index(['Province', 'Organization', 'Type', 'URL', 'URL 2', 'License',
#        'Attribution', 'Libraries', 'Hospitals', 'GTFS', 'Buildings',
#        'Businesses', 'Police', 'Fire', 'Education', 'Parks',
#        'Community Centers'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Province', 'Organization', 'Type', 'URL', 'URL 2', 'License',
#        'Attribution', 'Libraries', 'Hospitals', 'GTFS', 'Buildings',
#        'Businesses', 'Police', 'Fire', 'Education', 'Parks',
#        'Community Centers'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Province', 'Organization', 'Type', 'URL', 'URL 2', 'License',
#        'Attribution', 'Libraries', 'Hospitals', 'GTFS', 'Buildings',
#        'Businesses', 'Police', 'Fire', 'Education', 'Parks',
#        'Community Centers'],
#       dtype='str')

# %%
(df.columns)
# Out:
# Index(['Province', 'Organization', 'Type', 'URL', 'URL 2', 'License',
#        'Attribution', 'Libraries', 'Hospitals', 'GTFS', 'Buildings',
#        'Businesses', 'Police', 'Fire', 'Education', 'Parks',
#        'Community Centers'],
#       dtype='str')

# %%
rf_model = RandomForestClassifier()

# %%
print(dir())
# Out:
# ['DecisionTreeClassifier', 'In', 'LabelEncoder', 'Out', 'RandomForestClassifier', '_', '_20', '_21', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'check_is_fitted', 'classification_report', 'column', 'confusion_matrix', 'df', 'dt_model', 'exit', 'get_ipython', 'label_encoders', 'le', 'np', 'open', 'pd', 'plt', 'quit', 'rf_model', 'sns', 'target_column', 'train_test_split']
