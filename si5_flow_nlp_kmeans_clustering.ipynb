# %%
import pandas as pd
import numpy as np

import re
import string

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("SI_5_flow.csv")

df.head()
# Out:
#   class_2022;class_2025;n Events;Period
# 0          Other;Taxus;371616;Jan-March
# 1          Taxus;Taxus;293764;Jan-March
# 2          Other;Other;161945;Jan-March
# 3          Alnus;Alnus;102121;Jan-March
# 4         Other;Populus;48778;Jan-March

# %%
print(df.shape)
print(df.columns)
print(df.info())
# Out:
# (125, 1)
# Index(['class_2022;class_2025;n Events;Period'], dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 1 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   class_2022;class_2025;n Events;Period  125 non-null    str
# dtypes: str(1)
# memory usage: 4.5 KB
# None

# %%
df.head()
# Out:
#   class_2022;class_2025;n Events;Period
# 0          Other;Taxus;371616;Jan-March
# 1          Taxus;Taxus;293764;Jan-March
# 2          Other;Other;161945;Jan-March
# 3          Alnus;Alnus;102121;Jan-March
# 4         Other;Populus;48778;Jan-March

# %%
print(df.columns)
# Out:
# Index(['class_2022;class_2025;n Events;Period'], dtype='str')

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Example dataset
data = load_iris()
X = data.data

inertia = []
K_range = range(2, 10)

for k in K_range:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    model.fit(X)
    inertia.append(model.inertia_)

plt.plot(K_range, inertia, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.show()

# %%
df.head()
# Out:
#   class_2022;class_2025;n Events;Period
# 0          Other;Taxus;371616;Jan-March
# 1          Taxus;Taxus;293764;Jan-March
# 2          Other;Other;161945;Jan-March
# 3          Alnus;Alnus;102121;Jan-March
# 4         Other;Populus;48778;Jan-March

# %%
print(df.columns)
# Out:
# Index(['class_2022;class_2025;n Events;Period'], dtype='str')

# %%
print(hasattr(kmeans, "cluster_centers_"))
print('vectorizer' in globals())
print('order_centroids' in globals())
# Out:
# True
# True
# False

# %%
df.to_csv("SI_5_flow_clustered.csv", index=False)
