# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Evaluation
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Tree visualization
from sklearn import tree

# %%
# Load dataset
df = pd.read_csv("MobilePhonePrice.csv")

# Display first 5 rows
print(df.head())
# Out:
#      Brand              Model  ... Battery Capacity (mAh) Price ($)
# 0    Apple      iPhone 13 Pro  ...                   3095       999
# 1  Samsung   Galaxy S21 Ultra  ...                   5000      1199
# 2  OnePlus              9 Pro  ...                   4500       899
# 3   Xiaomi  Redmi Note 10 Pro  ...                   5020       279
# 4   Google            Pixel 6  ...                   4614       799
#
# [5 rows x 8 columns]

# %%
# Dataset information
print(df.info())

# Check missing values
print(df.isnull().sum())

# Statistical summary
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    str
#  1   Model                   407 non-null    str
#  2   Storage                 407 non-null    str
#  3   RAM                     407 non-null    str
#  4   Screen Size (inches)    407 non-null    str
#  5   Camera (MP)             407 non-null    str
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    str
# dtypes: int64(1), str(7)
# memory usage: 42.4 KB
# None
# Brand                     0
# Model                     0
# Storage                   0
# RAM                       0
# Screen Size (inches)      0
# Camera (MP)               0
# Battery Capacity (mAh)    0
# Price ($)                 0
# dtype: int64
#        Battery Capacity (mAh)
# count              407.000000
# ...

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#      Brand              Model  ... Battery Capacity (mAh) Price ($)
# 0    Apple      iPhone 13 Pro  ...                   3095       999
# 1  Samsung   Galaxy S21 Ultra  ...                   5000      1199
# 2  OnePlus              9 Pro  ...                   4500       899
# 3   Xiaomi  Redmi Note 10 Pro  ...                   5020       279
# 4   Google            Pixel 6  ...                   4614       799
#
# [5 rows x 8 columns]
# ['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)', 'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)']

# %%
print(df.head())
print(df.columns)
# Out:
#      Brand              Model  ... Battery Capacity (mAh) Price ($)
# 0    Apple      iPhone 13 Pro  ...                   3095       999
# 1  Samsung   Galaxy S21 Ultra  ...                   5000      1199
# 2  OnePlus              9 Pro  ...                   4500       899
# 3   Xiaomi  Redmi Note 10 Pro  ...                   5020       279
# 4   Google            Pixel 6  ...                   4614       799
#
# [5 rows x 8 columns]
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='str')

# %%
'target_column'
# Out:
# 'target_column'

# %%
print("y_test exists:", "y_test" in globals())
print("dt_predictions exists:", "dt_predictions" in globals())
# Out:
# y_test exists: False
# dt_predictions exists: False

# %%
print("X_train:", "X_train" in globals())
print("dt_model:", "dt_model" in globals())
# Out:
# X_train: False
# dt_model: True

# %%
df.head()
df.columns
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='str')

# %%
(df.head())
# Out:
#      Brand              Model  ... Battery Capacity (mAh) Price ($)
# 0    Apple      iPhone 13 Pro  ...                   3095       999
# 1  Samsung   Galaxy S21 Ultra  ...                   5000      1199
# 2  OnePlus              9 Pro  ...                   4500       899
# 3   Xiaomi  Redmi Note 10 Pro  ...                   5020       279
# 4   Google            Pixel 6  ...                   4614       799
#
# [5 rows x 8 columns]

# %%
rf_model = RandomForestClassifier()  # resets it

# %%
rf_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}
