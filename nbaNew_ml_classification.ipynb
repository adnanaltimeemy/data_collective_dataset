# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("nbaNew.csv")

df.head()
# Out:
#         #  SeasonStart  PlayerName   PlayerSalary  Pos   Age   Tm     G    GS  \
# 0  8035.0       1986.0  A.C. Green             NaN  PF  22.0  LAL  82.0   1.0
# 1  8420.0       1987.0  A.C. Green             NaN  PF  23.0  LAL  79.0  72.0
# 2  8807.0       1988.0  A.C. Green             NaN  PF  24.0  LAL  82.0  64.0
# 3  9242.0       1989.0  A.C. Green             NaN  PF  25.0  LAL  82.0  82.0
# 4  9688.0       1990.0  A.C. Green  $1,750,000.00   PF  26.0  LAL  82.0  82.0
#
#        MP  ...     FT%    ORB    DRB    TRB    AST   STL   BLK    TOV     PF  \
# 0  1542.0  ...  61.10%  160.0  221.0  381.0   54.0  49.0  49.0   99.0  229.0
# 1  2240.0  ...  78.00%  210.0  405.0  615.0   84.0  70.0  80.0  102.0  171.0
# 2  2636.0  ...  77.30%  245.0  465.0  710.0   93.0  87.0  45.0  120.0  204.0
# 3  2510.0  ...  78.60%  258.0  481.0  739.0  103.0  94.0  55.0  119.0  172.0
# 4  2709.0  ...  75.10%  262.0  450.0  712.0   90.0  66.0  50.0  116.0  207.0
#
#       PTS
# 0   521.0
# 1   852.0
# 2   937.0
# 3  1088.0
# 4  1061.0
#
# [5 rows x 54 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# (24630, 54)
# <class 'pandas.DataFrame'>
# RangeIndex: 24630 entries, 0 to 24629
# Data columns (total 54 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   #              24624 non-null  float64
#  1   SeasonStart    24624 non-null  float64
#  2   PlayerName     24625 non-null  str
#  3   PlayerSalary   10978 non-null  str
#  4   Pos            24624 non-null  str
#  5   Age            24616 non-null  float64
#  6   Tm             24624 non-null  str
#  7   G              24624 non-null  float64
#  8   GS             18233 non-null  float64
#  9   MP             24138 non-null  float64
#  10  PER            24101 non-null  float64
#  11  TS%            24538 non-null  str
#  12  3PAr           18839 non-null  float64
#  13  FTr            24525 non-null  str
#  14  ORB%           20792 non-null  float64
#  15  DRB%           20792 non-null  float64
#  16  TRB%           21571 non-null  float64
#  17  AST%           22555 non-null  float64
#  18  STL%           20792 non-null  float64
#  19  BLK%           20792 non-null  float64
#  20  TOV%           19582 non-null  float64
#  21  USG%           19640 non-null  float64
#  22  blanl          0 non-null      float64
#  23  OWS            24585 non-null  float64
#  24  DWS            24585 non-null  float64
#  25  WS             24585 non-null  float64
#  26  WS/48          24101 non-null  float64
#  27  blank2         0 non-null      float64
#  28  OBPM           20797 non-null  float64
#  29  DBPM           20797 non-null  float64
#  30  BPM            20797 non-null  float64
#  31  VORP           20797 non-null  float64
#  32  FG             24624 non-null  float64
#  33  FGA            24624 non-null  float64
#  34  FG%            24525 non-null  str
#  35  3P             18927 non-null  float64
#  36  3PA            18927 non-null  float64
#  37  3P%            15416 non-null  float64
#  38  2P             24624 non-null  float64
#  39  2PA            24624 non-null  float64
#  40  2P%            24496 non-null  str
#  41  eFG%           24525 non-null  str
#  42  FT             24624 non-null  float64
#  43  FTA            24624 non-null  float64
#  44  FT%            23766 non-null  str
#  45  ORB            20797 non-null  float64
#  46  DRB            20797 non-null  float64
#  47  TRB            24312 non-null  float64
#  48  AST            24624 non-null  float64
#  49  STL            20797 non-null  float64
#  50  BLK            20797 non-null  float64
#  51  TOV            19645 non-null  float64
#  52  PF             24624 non-null  float64
#  53  PTS            24624 non-null  float64
# dtypes: float64(44), str(10)
# memory usage: 11.6 MB
# None
#                   #   SeasonStart           Age             G            GS  \
# count  24624.000000  24624.000000  24616.000000  24624.000000  18233.000000
# mean   12354.094989   1992.594989     26.664405     50.837110     23.593375
# std     7125.490095     17.429594      3.841892     26.496161     28.632387
# min        0.000000   1950.000000     18.000000      1.000000      0.000000
# 25%     6186.750000   1981.000000     24.000000     27.000000      0.000000
# 50%    12357.500000   1996.000000     26.000000     58.000000      8.000000
# 75%    18524.250000   2007.000000     29.000000     75.000000     45.000000
# max    24690.000000   2017.000000     44.000000     88.000000     83.000000
#
#                  MP           PER          3PAr          ORB%          DRB%  \
# count  24138.000000  24101.000000  18839.000000  20792.000000  20792.000000
# mean    1209.720317     12.479071      0.158604      6.181565     13.708657
# std      941.146575      6.039014      0.187495      4.872685      6.636402
# min        0.000000    -90.600000      0.000000      0.000000      0.000000
# 25%      340.000000      9.800000      0.005000      2.600000      8.800000
# 50%     1053.000000     12.700000      0.064000      5.400000     12.700000
# 75%     1971.000000     15.600000      0.288000      9.000000     18.100000
# max     3882.000000    129.100000      1.000000    100.000000    100.000000
#
#        ...           FTA           ORB           DRB           TRB  \
# count  ...  24624.000000  20797.000000  20797.000000  24312.000000
# mean   ...    136.775219     62.189210    147.199404    224.637381
# std    ...    146.078918     67.324881    145.921912    228.190203
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...     27.000000     12.000000     33.000000     51.000000
# 50%    ...     88.000000     38.000000    106.000000    159.000000
# 75%    ...    201.000000     91.000000    212.000000    322.000000
# max    ...   1363.000000    587.000000   1111.000000   2149.000000
#
#                 AST           STL           BLK           TOV            PF  \
# count  24624.000000  20797.000000  20797.000000  19645.000000  24624.000000
# mean     114.852623     39.897052     24.470260     73.939832    116.339222
# std      135.863913     38.713053     36.935084     67.713803     84.791873
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       19.000000      9.000000      3.000000     18.000000     39.000000
# 50%       68.000000     29.000000     11.000000     55.000000    109.000000
# 75%      160.000000     60.000000     29.000000    112.000000    182.000000
# max     1164.000000    301.000000    456.000000    464.000000    386.000000
#
#                 PTS
# count  24624.000000
# mean     510.116350
# std      492.922981
# min        0.000000
# 25%      106.000000
# 50%      364.000000
# 75%      778.000000
# max     4029.000000
#
# [8 rows x 44 columns]
# #                    6
# SeasonStart          6
# PlayerName           5
# PlayerSalary     13652
# Pos                  6
# Age                 14
# Tm                   6
# G                    6
# GS                6397
# MP                 492
# PER                529
# TS%                 92
# 3PAr              5791
# FTr                105
# ORB%              3838
# DRB%              3838
# TRB%              3059
# AST%              2075
# STL%              3838
# BLK%              3838
# TOV%              5048
# USG%              4990
# blanl            24630
# OWS                 45
# DWS                 45
# WS                  45
# WS/48              529
# blank2           24630
# OBPM              3833
# DBPM              3833
# BPM               3833
# VORP              3833
# FG                   6
# FGA                  6
# FG%                105
# 3P                5703
# 3PA               5703
# 3P%               9214
# 2P                   6
# 2PA                  6
# 2P%                134
# eFG%               105
# FT                   6
# FTA                  6
# FT%                864
# ORB               3833
# DRB               3833
# TRB                318
# AST                  6
# STL               3833
# BLK               3833
# TOV               4985
# PF                   6
# PTS                  6
# dtype: int64

# %%
df = df.dropna()   # or you can use fillna depending on dataset

# %%
for col in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
print(df.columns)
# Out:
# Index(['#', 'SeasonStart', 'PlayerName', 'PlayerSalary ', 'Pos', 'Age', 'Tm',
#        'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%',
#        'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS',
#        'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['#', 'SeasonStart', 'PlayerName', 'PlayerSalary ', 'Pos', 'Age', 'Tm',
#        'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%',
#        'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS',
#        'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='str')

# %%
print("log_model exists?", "log_model" in globals())
# Out:
# log_model exists? False
