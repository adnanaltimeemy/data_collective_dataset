# %%
# =========================
# 1. Import Libraries
# =========================
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# =========================
# 2. Load Dataset
# =========================
df = pd.read_csv("Spotify Dataset.csv")

df.head()
# Out:
#          Song            Artist  ... Speechiness  Popularity
# 0           3    Britney Spears  ...           5          62
# 1       43776           Beyoncé  ...          13          72
# 2  #Beautiful      Mariah Carey  ...           4          51
# 3     #SELFIE  The Chainsmokers  ...          25          65
# 4  #thatPOWER         will.i.am  ...           6          68
#
# [5 rows x 25 columns]

# %%
# =========================
# 3. Basic Exploration
# =========================
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (599, 25)
# <class 'pandas.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Song                  599 non-null    str
#  1   Artist                599 non-null    str
#  2   Genre                 599 non-null    str
#  3   Year                  599 non-null    int64
#  4   Streams               599 non-null    int64
#  5   In Spotify Playlists  599 non-null    int64
#  6   On Spotify Charts     599 non-null    int64
#  7   Billboard Rankings    599 non-null    int64
#  8   In Apple Playlists    599 non-null    int64
#  9   On Apple Charts       599 non-null    int64
#  10  In Deezer Playlists   599 non-null    str
#  11  In Deezer Charts      599 non-null    int64
#  12  In YouTube Playlists  599 non-null    int64
#  13  On Shazam Charts      599 non-null    int64
#  14  Bpm                   599 non-null    int64
#  15  Decibel               599 non-null    int64
#  16  Mode                  599 non-null    str
#  17  Energy                599 non-null    int64
#  18  Danceability          599 non-null    int64
#  19  Liveness              599 non-null    int64
#  20  Valence               599 non-null    int64
#  21  Duration              599 non-null    int64
#  22  Acousticness          599 non-null    int64
#  23  Speechiness           599 non-null    int64
#  24  Popularity            599 non-null    int64
# dtypes: int64(20), str(5)
# memory usage: 143.9 KB
# None
# Song                    0
# Artist                  0
# Genre                   0
# Year                    0
# Streams                 0
# In Spotify Playlists    0
# On Spotify Charts       0
# Billboard Rankings      0
# In Apple Playlists      0
# On Apple Charts         0
# In Deezer Playlists     0
# In Deezer Charts        0
# In YouTube Playlists    0
# On Shazam Charts        0
# Bpm                     0
# Decibel                 0
# Mode                    0
# Energy                  0
# Danceability            0
# Liveness                0
# Valence                 0
# Duration                0
# Acousticness            0
# Speechiness             0
# Popularity              0
# dtype: int64

# %%
for col in df.select_dtypes(include=np.number).columns:
    df[col] = df[col].fillna(df[col].median())

for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# =========================
# 5. Encode Categorical Features
# =========================
label_encoders = {}

for col in df.select_dtypes(include="object").columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
print(df.columns.tolist())
# Out:
# ['Song', 'Artist', 'Genre', 'Year', 'Streams', 'In Spotify Playlists', 'On Spotify Charts', 'Billboard Rankings', 'In Apple Playlists', 'On Apple Charts', 'In Deezer Playlists', 'In Deezer Charts', 'In YouTube Playlists', 'On Shazam Charts', 'Bpm', 'Decibel', 'Mode', 'Energy', 'Danceability', 'Liveness', 'Valence', 'Duration', 'Acousticness', 'Speechiness', 'Popularity']

# %%
print(df.columns.tolist())
# Out:
# ['Song', 'Artist', 'Genre', 'Year', 'Streams', 'In Spotify Playlists', 'On Spotify Charts', 'Billboard Rankings', 'In Apple Playlists', 'On Apple Charts', 'In Deezer Playlists', 'In Deezer Charts', 'In YouTube Playlists', 'On Shazam Charts', 'Bpm', 'Decibel', 'Mode', 'Energy', 'Danceability', 'Liveness', 'Valence', 'Duration', 'Acousticness', 'Speechiness', 'Popularity']

# %%
print("df exists:", 'df' in globals())
print("X exists:", 'X' in globals())
print("y exists:", 'y' in globals())
print("X_train exists:", 'X_train' in globals())
# Out:
# df exists: True
# X exists: False
# y exists: False
# X_train exists: False
