# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("street-tree-data-YO.csv")

df.head()
# Out:
#    _id  OBJECTID STRUCTID  ADDRESS     STREETNAME           CROSSSTREET1  \
# 0   18        18   YO1614        5     BERTRAM ST         LONBOROUGH AVE
# 1  289       290  YO20643       74    KENWOOD AVE             LOUISE AVE
# 2  362       363  YO13670      357   CALEDONIA RD              CORBY AVE
# 3  383       384    YO179      566  BERESFORD AVE  LN E DURIE S ST JOHNS
# 4  411       412   YO6218      686     VAUGHAN RD                BUDE ST
#
#               CROSSSTREET2 SUFFIX  UNIT_NUMBER  TREE_POSITION_NUMBER SITE  \
# 0         BEECHBOROUGH AVE    NaN            0                  20.0  NaN
# 1            MAPLEWOOD AVE    NaN            0                  10.0  NaN
# 2  LN S SUMMIT W CALEDONIA    NaN            0                  10.0  NaN
# 3             ST JOHN'S RD    NaN            0                  10.0  NaN
# 4            GLENHOLME AVE    NaN            0                  10.0  NaN
#
#    WARD             BOTANICAL_NAME            COMMON_NAME  DBH_TRUNK  \
# ...

# %%
print(df.shape)
print(df.info())
print(df.describe(include="all"))
# Out:
# (10991, 16)
# <class 'pandas.DataFrame'>
# RangeIndex: 10991 entries, 0 to 10990
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   _id                   10991 non-null  int64
#  1   OBJECTID              10991 non-null  int64
#  2   STRUCTID              10991 non-null  str
#  3   ADDRESS               10991 non-null  int64
#  4   STREETNAME            10991 non-null  str
#  5   CROSSSTREET1          10757 non-null  str
#  6   CROSSSTREET2          10365 non-null  str
#  7   SUFFIX                100 non-null    str
#  8   UNIT_NUMBER           10991 non-null  int64
#  9   TREE_POSITION_NUMBER  10990 non-null  float64
#  10  SITE                  136 non-null    str
#  11  WARD                  10991 non-null  int64
#  12  BOTANICAL_NAME        10991 non-null  str
#  13  COMMON_NAME           10991 non-null  str
#  14  DBH_TRUNK             10687 non-null  float64
# ...

# %%
df = df.dropna()   # simple approach (you can improve later)

# %%
print(df.head())
print(df.columns)
# Out:
# Empty DataFrame
# Columns: [_id, OBJECTID, STRUCTID, ADDRESS, STREETNAME, CROSSSTREET1, CROSSSTREET2, SUFFIX, UNIT_NUMBER, TREE_POSITION_NUMBER, SITE, WARD, BOTANICAL_NAME, COMMON_NAME, DBH_TRUNK, geometry]
# Index: []
# Index(['_id', 'OBJECTID', 'STRUCTID', 'ADDRESS', 'STREETNAME', 'CROSSSTREET1',
#        'CROSSSTREET2', 'SUFFIX', 'UNIT_NUMBER', 'TREE_POSITION_NUMBER', 'SITE',
#        'WARD', 'BOTANICAL_NAME', 'COMMON_NAME', 'DBH_TRUNK', 'geometry'],
#       dtype='str')

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['_id', 'OBJECTID', 'STRUCTID', 'ADDRESS', 'STREETNAME', 'CROSSSTREET1', 'CROSSSTREET2', 'SUFFIX', 'UNIT_NUMBER', 'TREE_POSITION_NUMBER', 'SITE', 'WARD', 'BOTANICAL_NAME', 'COMMON_NAME', 'DBH_TRUNK', 'geometry']
# Empty DataFrame
# Columns: [_id, OBJECTID, STRUCTID, ADDRESS, STREETNAME, CROSSSTREET1, CROSSSTREET2, SUFFIX, UNIT_NUMBER, TREE_POSITION_NUMBER, SITE, WARD, BOTANICAL_NAME, COMMON_NAME, DBH_TRUNK, geometry]
# Index: []

# %%
print("X exists:", 'X' in locals())
print("y exists:", 'y' in locals())
# Out:
# X exists: False
# y exists: False

# %%
print("X exists:", 'X' in globals())
print("y exists:", 'y' in globals())
print("X_train exists:", 'X_train' in globals())
print("y_train exists:", 'y_train' in globals())
# Out:
# X exists: False
# y exists: False
# X_train exists: False
# y_train exists: False

# %%
print('df' in globals())
print('X' in globals())
print('y' in globals())
print('X_train' in globals())
print('y_train' in globals())
# Out:
# True
# False
# False
# False
# False

# %%
for var in ['df', 'X', 'y', 'X_train', 'X_test', 'y_train', 'y_test', 'y_pred_rf']:
    print(var, var in globals())
# Out:
# df True
# X False
# y False
# X_train False
# X_test False
# y_train False
# y_test False
# y_pred_rf False
