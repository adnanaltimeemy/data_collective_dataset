# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("murders_raw.csv")

# Preview
df.head()
# Out:
#         state  population  total  murder_rate
# 0     Alabama   4,853,875    348          7.2
# 1      Alaska     737,709     59          8.0
# 2     Arizona   6,817,565    309          4.5
# 3    Arkansas   2,977,853    181          6.1
# 4  California  38,993,940  1,861          4.8

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# (51, 4)
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        51 non-null     str
#  1   population   51 non-null     str
#  2   total        51 non-null     str
#  3   murder_rate  51 non-null     float64
# dtypes: float64(1), str(3)
# memory usage: 2.7 KB
# None
#        murder_rate
# count    51.000000
# mean      4.956863
# std       3.496070
# min       1.100000
# 25%       2.850000
# 50%       4.500000
# 75%       6.000000
# max      24.200000
# state          0
# population     0
# total          0
# murder_rate    0
# dtype: int64

# %%
target_column = "YOUR_TARGET_COLUMN_HERE"

# %%
df_imputed = df.copy()

# %%
label_encoders = {}
df_encoded = df_imputed.copy()

for col in df_encoded.columns:
    if df_encoded[col].dtype == "object":
        le = LabelEncoder()
        df_encoded[col] = le.fit_transform(df_encoded[col])
        label_encoders[col] = le

# %%
print(df_encoded.columns.tolist())
# Out:
# ['state', 'population', 'total', 'murder_rate']

# %%
print(df_encoded.columns.tolist())
# Out:
# ['state', 'population', 'total', 'murder_rate']
