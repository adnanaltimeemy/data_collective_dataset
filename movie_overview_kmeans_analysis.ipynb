# %%
import pandas as pd
import numpy as np

import re
import string

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("movies2.csv")

df.head()
# Out:
#              movie_name  director  category  imdb_rating  watched
# 0      Kill Bill Vol. 1         0         0          8.2        0
# 1          Pulp Fiction         0         0          8.3        0
# 2      Django Unchained         0         0          8.4        1
# 3  Inglourious Basterds         0         0          8.3        0
# 4                Avatar         1         1          7.8        0

# %%
if "overview" in df.columns:
    df = df.dropna(subset=["overview"])
else:
    print("Column 'overview' not found. Available columns:", df.columns)
# Out:
# Column 'overview' not found. Available columns: Index(['movie_name', 'director', 'category', 'imdb_rating', 'watched'], dtype='str')

# %%
import pandas as pd

texts = pd.Series([
    "Hello World 123!!!",
    "This is TEXT cleaning 456."
])

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['movie_name', 'director', 'category', 'imdb_rating', 'watched'], dtype='str')
#              movie_name  director  category  imdb_rating  watched
# 0      Kill Bill Vol. 1         0         0          8.2        0
# 1          Pulp Fiction         0         0          8.3        0
# 2      Django Unchained         0         0          8.4        1
# 3  Inglourious Basterds         0         0          8.3        0
# 4                Avatar         1         1          7.8        0

# %%
from sklearn.datasets import load_iris

data = load_iris()
X = data.data

# %%
print(df.columns)
# Out:
# Index(['movie_name', 'director', 'category', 'imdb_rating', 'watched'], dtype='str')

# %%
import numpy as np
import scipy.sparse as sp

print("Is numpy array:", isinstance(X, np.ndarray))
print("Is sparse matrix:", sp.issparse(X))
# Out:
# Is numpy array: True
# Is sparse matrix: False

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'movie_name'
# 'director'
# 'category'
# 'imdb_rating'
# 'watched'

# %%
df.columns = df.columns.str.strip()
