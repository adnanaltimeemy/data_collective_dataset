# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("rmp_wit_comments.csv")

# Preview
df.head()
# Out:
#      course                                           comments
# 0  MATH1900  He is very enthusiastic to help students. His ...
# 1   MATH250  Great professor, really wants his students to ...
# 2  MATH2860  Lectures are clear and pretty easy to follow. ...
# 3  MATH2860  He is a great professor. He mixes humor into a...
# 4  MATH2025  i found him to be a good professor he keeps th...

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("rmp_wit_comments.csv")

# Preview
df.head()
# Out:
#      course                                           comments
# 0  MATH1900  He is very enthusiastic to help students. His ...
# 1   MATH250  Great professor, really wants his students to ...
# 2  MATH2860  Lectures are clear and pretty easy to follow. ...
# 3  MATH2860  He is a great professor. He mixes humor into a...
# 4  MATH2025  i found him to be a good professor he keeps th...

# %%
print(df.shape)
print(df.columns)
print(df.isnull().sum())
# Out:
# (18, 2)
# Index(['course', 'comments'], dtype='str')
# course      0
# comments    0
# dtype: int64

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['course', 'comments'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['course', 'comments'], dtype='str')

# %%
# Check columns
print(df.columns)
# Out:
# Index(['course', 'comments'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['course', 'comments'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['course', 'comments'], dtype='str')
