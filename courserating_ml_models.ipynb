# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("courserating.csv")

df.head()
# Out:
#   Unnamed: 0  SQL  Spatial  PA1  ...  Forecast  R Prog  Hadoop  Regression
# 0         LN  4.0      NaN  NaN  ...       2.0     4.0     NaN         2.0
# 1         MH  3.0      4.0  NaN  ...       NaN     NaN     NaN         NaN
# 2         JH  2.0      2.0  NaN  ...       NaN     NaN     NaN         NaN
# 3         EN  4.0      NaN  NaN  ...       NaN     4.0     NaN         3.0
# 4         DU  4.0      4.0  NaN  ...       NaN     NaN     NaN         NaN
#
# [5 rows x 10 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# (15, 10)
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  15 non-null     str
#  1   SQL         6 non-null      float64
#  2   Spatial     6 non-null      float64
#  3   PA1         6 non-null      float64
#  4   DM in R     2 non-null      float64
#  5   Python      2 non-null      float64
#  6   Forecast    2 non-null      float64
#  7   R Prog      3 non-null      float64
#  8   Hadoop      1 non-null      float64
#  9   Regression  2 non-null      float64
# dtypes: float64(9), str(1)
# memory usage: 1.3 KB
# None
#            SQL  Spatial      PA1  ...  R Prog  Hadoop  Regression
# count  6.00000  6.00000  6.00000  ...     3.0     1.0    2.000000
# mean   3.50000  3.50000  3.50000  ...     4.0     4.0    2.500000
# std    0.83666  0.83666  0.83666  ...     0.0     NaN    0.707107
# min    2.00000  2.00000  2.00000  ...     4.0     4.0    2.000000
# 25%    3.25000  3.25000  3.25000  ...     4.0     4.0    2.250000
# 50%    4.00000  4.00000  4.00000  ...     4.0     4.0    2.500000
# 75%    4.00000  4.00000  4.00000  ...     4.0     4.0    2.750000
# max    4.00000  4.00000  4.00000  ...     4.0     4.0    3.000000
#
# [8 rows x 9 columns]
# Unnamed: 0     0
# SQL            9
# Spatial        9
# PA1            9
# DM in R       13
# Python        13
# Forecast      13
# R Prog        12
# Hadoop        14
# Regression    13
# dtype: int64

# %%
df = df.dropna()  # simple approach (you can improve later)

# %%
for column in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column].astype(str))
    label_encoders[column] = le

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'SQL', 'Spatial', 'PA1', 'DM in R', 'Python', 'Forecast',
#        'R Prog', 'Hadoop', 'Regression'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'SQL', 'Spatial', 'PA1', 'DM in R', 'Python', 'Forecast',
#        'R Prog', 'Hadoop', 'Regression'],
#       dtype='str')

# %%
print(dir())
# Out:
# ['DecisionTreeRegressor', 'In', 'LabelEncoder', 'Out', 'RandomForestRegressor', '_', '_2', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'column', 'df', 'dt_model', 'exit', 'get_ipython', 'label_encoders', 'le', 'mean_absolute_error', 'mean_squared_error', 'np', 'open', 'pd', 'quit', 'r2_score', 'train_test_split']

# %%
print("y_test exists:", "y_test" in globals())
# Out:
# y_test exists: False

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'SQL', 'Spatial', 'PA1', 'DM in R', 'Python', 'Forecast',
#        'R Prog', 'Hadoop', 'Regression'],
#       dtype='str')

# %%
print("y_test exists:", "y_test" in globals())
# Out:
# y_test exists: False
