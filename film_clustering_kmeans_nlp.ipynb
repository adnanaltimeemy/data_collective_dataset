# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("films.csv")

# Show basic info
print(df.head())
print(df.columns)
# Out:
#          Year  Length(min)                    Title Subject  \
# 0  01/01/1990        111.0  Tie Me Up! Tie Me Down!  Comedy
# 1  01/01/1991        113.0               High Heels  Comedy
# 2  01/01/1983        104.0           Dead Zone, The  Horror
# 3  01/01/1979        122.0                     Cuba  Action
# 4  01/01/1978         94.0           Days of Heaven   Drama
#
#                  Actor          Actress           Director  Popularity Awards
# 0    Banderas, Antonio  Abril, Victoria   Almod�var, Pedro        68.0     No
# 1         Bos�, Miguel  Abril, Victoria   Almod�var, Pedro        68.0     No
# 2  Walken, Christopher    Adams, Brooke  Cronenberg, David        79.0     No
# 3        Connery, Sean    Adams, Brooke    Lester, Richard         6.0     No
# 4        Gere, Richard    Adams, Brooke   Malick, Terrence        14.0     No
# Index(['Year', 'Length(min)', 'Title', 'Subject', 'Actor', 'Actress',
#        'Director', 'Popularity', 'Awards'],
#       dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['Year', 'Length(min)', 'Title', 'Subject', 'Actor', 'Actress', 'Director', 'Popularity', 'Awards']

# %%
print(df.columns.tolist())
# Out:
# ['Year', 'Length(min)', 'Title', 'Subject', 'Actor', 'Actress', 'Director', 'Popularity', 'Awards']

# %%
df.head()
# Out:
#          Year  Length(min)                    Title Subject  \
# 0  01/01/1990        111.0  Tie Me Up! Tie Me Down!  Comedy
# 1  01/01/1991        113.0               High Heels  Comedy
# 2  01/01/1983        104.0           Dead Zone, The  Horror
# 3  01/01/1979        122.0                     Cuba  Action
# 4  01/01/1978         94.0           Days of Heaven   Drama
#
#                  Actor          Actress           Director  Popularity Awards
# 0    Banderas, Antonio  Abril, Victoria   Almod�var, Pedro        68.0     No
# 1         Bos�, Miguel  Abril, Victoria   Almod�var, Pedro        68.0     No
# 2  Walken, Christopher    Adams, Brooke  Cronenberg, David        79.0     No
# 3        Connery, Sean    Adams, Brooke    Lester, Richard         6.0     No
# 4        Gere, Richard    Adams, Brooke   Malick, Terrence        14.0     No

# %%
df.to_csv("films_clustered.csv", index=False)
