# %%
# Data handling
import pandas as pd
import numpy as np

# NLP preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer

# Machine learning
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Evaluation and visualization
from sklearn.metrics import silhouette_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV file
df = pd.read_csv("Mammographic Masses.csv")

# Display first rows
df.head()
# Out:
#    BI-RADS   Age  Shape  Margin  Density  Severity
# 0      4.0  18.0    1.0     1.0      3.0         0
# 1      4.0  19.0    3.0     1.0      3.0         0
# 2      4.0  19.0    1.0     1.0      3.0         0
# 3      4.0  19.0    1.0     1.0      3.0         0
# 4      4.0  19.0    1.0     1.0      3.0         0

# %%
# Dataset information
df.info()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 961 entries, 0 to 960
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BI-RADS   959 non-null    float64
#  1   Age       956 non-null    float64
#  2   Shape     930 non-null    float64
#  3   Margin    913 non-null    float64
#  4   Density   885 non-null    float64
#  5   Severity  961 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 45.2 KB
# BI-RADS      2
# Age          5
# Shape       31
# Margin      48
# Density     76
# Severity     0
# dtype: int64

# %%
# Replace missing values represented by '?'
df = df.replace("?", np.nan)

# Remove rows with missing data
df = df.dropna()

df.shape
# Out:
# (830, 6)

# %%
# Change column name if required
print(df.columns)
# Out:
# Index(['BI-RADS', 'Age', 'Shape', 'Margin', 'Density', 'Severity'], dtype='str')

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'TfidfVectorizer', 'KMeans', 'StandardScaler', 'silhouette_score', 'confusion_matrix', 'plt', 'sns', '_i2', 'df', '_2', '_i3', '_3', '_i4', '_4', '_i5', '_i6', '_i7'])

# %%
df.to_csv(
    "Mammographic_Masses_KMeans_Result.csv",
    index=False
)
