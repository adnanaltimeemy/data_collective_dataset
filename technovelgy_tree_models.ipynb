# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("technovelgy.csv")

df.head()
# Out:
#     Copyright© Technovelgy LLC; all rights reserved.  ... Unnamed: 3
# 0                                               Name  ...   Category
# 1                         Andy - an artificial human  ...         ai
# 2                                         Autobutle   ...         ai
# 3  Automaton Chessplayer - the first chess-playin...  ...         ai
# 4                                          Automonk   ...         ai
#
# [5 rows x 4 columns]

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (3805, 4)
# <class 'pandas.DataFrame'>
# RangeIndex: 3805 entries, 0 to 3804
# Data columns (total 4 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Copyright© Technovelgy LLC; all rights reserved.  3805 non-null   str
#  1   Unnamed: 1                                        3792 non-null   str
#  2   Unnamed: 2                                        3805 non-null   str
#  3   Unnamed: 3                                        3805 non-null   str
# dtypes: str(4)
# memory usage: 542.7 KB
# None
# Copyright© Technovelgy LLC; all rights reserved.     0
# Unnamed: 1                                          13
# Unnamed: 2                                           0
# Unnamed: 3                                           0
# dtype: int64

# %%
df = df.dropna()  # or use fillna if needed

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()
df[df.select_dtypes(include=['object', 'string']).columns] = encoder.fit_transform(
    df.select_dtypes(include=['object', 'string'])
)

# %%
[c for c in df.columns if "target" in c.lower()]
# Out:
# []

# %%
print("X:", "X" in globals())
print("y:", "y" in globals())
# Out:
# X: False
# y: False

# %%
import os
print(os.listdir())
# Out:
# ['ExplainLikeImCalvin.csv', 'CostaCoffee.ipynb', 'Sycho.ipynb', 'obscure_scifi_books_dataset.csv', 'Hugin_Fm_Base_cleaned.csv', 'Untitled Folder', 'bios.csv', 'Heavenly_Desserts_Manchester_Sales.ipynb', 'world-universities_cleaned.csv', 'pret_menu.csv', 'asos_ocado_dataset.ipynb', 'decision_tree_intro.ipynb', 'checkins_forest_tree.ipynb', 'CHECKOUT.ipynb', 'stress.csv', 'Dailyprices.ipynb', 'DSS.ipynb', 'Predicito.ipynb', 'glass.csv', 'energy_clusters_output.csv', ' penguin_random_house_sales_analysis.ipynb', 'degrees-that-pay-back.csv', 'Patrick.ipynb', 'iso.csv', 'Video Game Sales Data (Clean).csv', 'gala-mode.csv', 'ads_ctr_optimisation_decision_tree_random_forest.ipynb', 'hr-employee-attrition.csv', 'all_pivoted.csv', 'Austin.csv', 'Compare.ipynb', 'Cod.ipynb', 'muslim_bakery_uk_dataset.ipynb', 'chiquito_taco_bell_uk_dataset.ipynb', 'michael_kors_sales_profit_demographics_analysis.ipynb', 'rvd_nlp_logistic_regression.ipynb', 'manchester_halal_restaurants_sales_demographics.ipynb'
# ...

# %%
print("X_train" in globals())
# Out:
# False

# %%
print(df.columns)
# Out:
# Index(['Copyright© Technovelgy LLC; all rights reserved.', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3'],
#       dtype='str')

# %%
hasattr(rf_model, "estimators_")
# Out:
# False
