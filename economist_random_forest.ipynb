# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("EconomistData.csv")

# Quick overview
print(df.head())
print(df.info())
print(df.describe())
# Out:
#        Country  HDI.Rank    HDI  CPI             Region
# 0  Afghanistan       172  0.398  1.5       Asia Pacific
# 1      Albania        70  0.739  3.1  East EU Cemt Asia
# 2      Algeria        96  0.698  2.9               MENA
# 3       Angola       148  0.486  2.0                SSA
# 4    Argentina        45  0.797  3.0           Americas
# <class 'pandas.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   173 non-null    str
#  1   HDI.Rank  173 non-null    int64
#  2   HDI       173 non-null    float64
#  3   CPI       173 non-null    float64
#  4   Region    173 non-null    str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 9.7 KB
# None
#          HDI.Rank         HDI         CPI
# count  173.000000  173.000000  173.000000
# mean    95.283237    0.658087    4.052023
# std     55.007670    0.175589    2.116782
# min      1.000000    0.286000    1.500000
# 25%     47.000000    0.509000    2.500000
# 50%     96.000000    0.698000    3.200000
# 75%    143.000000    0.793000    5.100000
# max    187.000000    0.943000    9.500000

# %%
# Handle missing values (simple strategy)
df = df.dropna()

# If you have categorical variables
df = pd.get_dummies(df, drop_first=True)

# %%
target_column in df.columns
# Out:
# False

# %%
print(df.columns)
# Out:
# Index(['HDI.Rank', 'HDI', 'CPI', 'Country_Albania', 'Country_Algeria',
#        'Country_Angola', 'Country_Argentina', 'Country_Armenia',
#        'Country_Australia', 'Country_Austria',
#        ...
#        'Country_Vanuatu', 'Country_Venezuela', 'Country_Yemen',
#        'Country_Zambia', 'Country_Zimbabwe', 'Region_Asia Pacific',
#        'Region_EU W. Europe', 'Region_East EU Cemt Asia', 'Region_MENA',
#        'Region_SSA'],
#       dtype='str', length=180)

# %%
print(df.columns)
# Out:
# Index(['HDI.Rank', 'HDI', 'CPI', 'Country_Albania', 'Country_Algeria',
#        'Country_Angola', 'Country_Argentina', 'Country_Armenia',
#        'Country_Australia', 'Country_Austria',
#        ...
#        'Country_Vanuatu', 'Country_Venezuela', 'Country_Yemen',
#        'Country_Zambia', 'Country_Zimbabwe', 'Region_Asia Pacific',
#        'Region_EU W. Europe', 'Region_East EU Cemt Asia', 'Region_MENA',
#        'Region_SSA'],
#       dtype='str', length=180)

# %%
print("X_train exists:", "X_train" in globals())
# Out:
# X_train exists: False

# %%
print("X_train exists:", "X_train" in globals())
# Out:
# X_train exists: False
