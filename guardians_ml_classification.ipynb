# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("guardians_2_uppercase_unique.csv")

df.head()
# Out:
#    134       SLEEP!  1  0  1.1
# 0  135        NO!!!  1  0    1
# 1   76        BRAHL  1  1    0
# 2  132  MEGA-LASER.  1  0    0
# 3   40        HOLE.  1  0    0
# 4  126       YONDU?  1  0    1

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (199, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   134     199 non-null    int64
#  1   SLEEP!  199 non-null    str
#  2   1       199 non-null    int64
#  3   0       199 non-null    int64
#  4   1.1     199 non-null    int64
# dtypes: int64(4), str(1)
# memory usage: 12.7 KB
# None
#               134           1           0         1.1
# count  199.000000  199.000000  199.000000  199.000000
# mean    99.326633    4.281407    0.190955    0.105528
# std     57.973077    3.322894    0.394045    0.308007
# min      0.000000    1.000000    0.000000    0.000000
# 25%     49.500000    1.000000    0.000000    0.000000
# 50%     99.000000    3.000000    0.000000    0.000000
# 75%    149.500000    7.000000    0.000000    0.000000
# max    199.000000   13.000000    1.000000    1.000000

# %%
df = df.dropna()  # simple approach; adjust if needed

# %%
label_encoders = {}

for column in df.columns:
    if df[column].dtype == 'object':
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column])
        label_encoders[column] = le

# %%
print(df.columns)
# Out:
# Index(['134', 'SLEEP!', '1', '0', '1.1'], dtype='str')

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['134', 'SLEEP!', '1', '0', '1.1']
#    134       SLEEP!  1  0  1.1
# 0  135        NO!!!  1  0    1
# 1   76        BRAHL  1  1    0
# 2  132  MEGA-LASER.  1  0    0
# 3   40        HOLE.  1  0    0
# 4  126       YONDU?  1  0    1

# %%
print("X exists:", 'X' in locals())
print("y exists:", 'y' in locals())
print("X_train exists:", 'X_train' in locals())
print("y_train exists:", 'y_train' in locals())
# Out:
# X exists: False
# y exists: False
# X_train exists: False
# y_train exists: False

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (199, 5)
# ['134', 'SLEEP!', '1', '0', '1.1']
