# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("england-metropolitan-counties.csv")
df.head()
# Out:
#   ons_code   gss_code  ... district_population  region_gss_code
# 0       2A  E11000001  ...             2573200        E12000002
# 1       2B  E11000002  ...             1365000        E12000002
# 2       2C  E11000003  ...             1290000        E12000003
# 3       2D  E11000004  ...             1089400        E12000001
# 4       2E  E11000005  ...             2591300        E12000005
#
# [5 rows x 6 columns]

# %%
print(df.columns)
# Out:
# Index(['ons_code', 'gss_code', 'district_name', 'borough_count',
#        'district_population', 'region_gss_code'],
#       dtype='str')

# %%
# Try to auto-detect a text column
text_column = None

for col in df.columns:
    if df[col].dtype == "object":
        text_column = col
        break

print("Using text column:", text_column)
# Out:
# Using text column: None

# %%
print(df[text_column].head())
print(df[text_column].isna().sum())
# Out:
# 0    2A
# 1    2B
# 2    2C
# 3    2D
# 4    2E
# Name: ons_code, dtype: str
# 0

# %%
df.columns = df.columns.str.strip()

# %%
df.head()
df.columns
# Out:
# Index(['ons_code', 'gss_code', 'district_name', 'borough_count',
#        'district_population', 'region_gss_code'],
#       dtype='str')

# %%
df.head()
# Out:
#   ons_code   gss_code  ... district_population  region_gss_code
# 0       2A  E11000001  ...             2573200        E12000002
# 1       2B  E11000002  ...             1365000        E12000002
# 2       2C  E11000003  ...             1290000        E12000003
# 3       2D  E11000004  ...             1089400        E12000001
# 4       2E  E11000005  ...             2591300        E12000005
#
# [5 rows x 6 columns]

# %%
print(df.columns)
# Out:
# Index(['ons_code', 'gss_code', 'district_name', 'borough_count',
#        'district_population', 'region_gss_code'],
#       dtype='str')

# %%
print(type(X))
print(X[:5] if hasattr(X, "__getitem__") else X)
# Out:
# <class 'numpy.ndarray'>
# [['2A' 'E11000001' 'Greater Manchester' 10 2573200 'E12000002']
#  ['2B' 'E11000002' 'Merseyside' 5 1365000 'E12000002']
#  ['2C' 'E11000003' 'South Yorkshire' 4 1290000 'E12000003']
#  ['2D' 'E11000004' 'Tyne and Wear' 5 1089400 'E12000001']
#  ['2E' 'E11000005' 'West Midlands' 7 2591300 'E12000005']]

# %%
hasattr(vectorizer, "vocabulary_")
# Out:
# False
