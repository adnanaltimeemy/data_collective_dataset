# %%
# Data handling
import pandas as pd
import numpy as np

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# NLP
from sklearn.feature_extraction.text import TfidfVectorizer

import warnings
warnings.filterwarnings("ignore")

# %%
# Load CSV file

df = pd.read_csv("country_lat_lon.csv")

# Display first rows
df.head()
# Out:
#   ISO 3166 Country Code               Country  Latitude  Longitude
# 0                    AD               Andorra     42.50       1.50
# 1                    AE  United Arab Emirates     24.00      54.00
# 2                    AF           Afghanistan     33.00      65.00
# 3                    AG   Antigua and Barbuda     17.05     -61.80
# 4                    AI              Anguilla     18.25     -63.17

# %%
# Dataset information

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ISO 3166 Country Code  239 non-null    str
#  1   Country                240 non-null    str
#  2   Latitude               240 non-null    float64
#  3   Longitude              240 non-null    float64
# dtypes: float64(2), str(2)
# memory usage: 10.6 KB

# %%
# Standardise column names

df.columns = (
    df.columns
    .str.lower()
    .str.replace(" ", "_")
)

df.columns
# Out:
# Index(['iso_3166_country_code', 'country', 'latitude', 'longitude'], dtype='str')

# %%
# Display columns

df.columns
# Out:
# Index(['iso_3166_country_code', 'country', 'latitude', 'longitude'], dtype='str')

# %%
df = df.dropna()

df.shape
# Out:
# (239, 4)

# %%
df = df.dropna()

df.shape
# Out:
# (239, 4)

# %%
df.to_csv(
    "country_lat_lon_kmeans_clusters.csv",
    index=False
)
