# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Weather_Sample.csv")

# Preview data
df.head()
# Out:
#    Year  AdjustedMonth  AdjustedDay  AirportID  AdjustedHour  Timezone  \
# 0  2013              9            1      14843             0        -4
# 1  2013              9            1      14843             1        -4
# 2  2013              9            1      14843             2        -4
# 3  2013              9            1      14843             3        -4
# 4  2013              9            1      14843             4        -4
#
#    Visibility  DryBulbFarenheit  DryBulbCelsius  DewPointFarenheit  \
# 0        10.0                81            27.2                 76
# 1        10.0                82            27.8                 76
# 2        10.0                81            27.2                 76
# 3        10.0                81            27.2                 76
# 4        10.0                83            28.3                 77
#
#    DewPointCelsius  RelativeHumidity  WindSpeed  Altimeter
# 0             24.4                85          0      29.95
# 1             24.4                82          0      29.95
# 2             24.4                85          0      29.95
# 3             24.4                85          0      29.96
# 4             25.0                82          0      29.97

# %%
print(df.shape)
print(df.info())
print(df.describe())

# Check missing values
print(df.isnull().sum())
# Out:
# (113332, 14)
# <class 'pandas.DataFrame'>
# RangeIndex: 113332 entries, 0 to 113331
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               113332 non-null  int64
#  1   AdjustedMonth      113332 non-null  int64
#  2   AdjustedDay        113332 non-null  int64
#  3   AirportID          113332 non-null  int64
#  4   AdjustedHour       113332 non-null  int64
#  5   Timezone           113332 non-null  int64
#  6   Visibility         113332 non-null  float64
#  7   DryBulbFarenheit   113332 non-null  int64
#  8   DryBulbCelsius     113332 non-null  float64
#  9   DewPointFarenheit  113332 non-null  int64
#  10  DewPointCelsius    113332 non-null  float64
#  11  RelativeHumidity   113332 non-null  int64
#  12  WindSpeed          113332 non-null  int64
#  13  Altimeter          113332 non-null  float64
# dtypes: float64(4), int64(10)
# memory usage: 12.1 MB
# None
#            Year  AdjustedMonth    AdjustedDay     AirportID   AdjustedHour  \
# count  113332.0  113332.000000  113332.000000  113332.00000  113332.000000
# mean     2013.0       9.513915      15.697173   13052.29133      11.344960
# std         0.0       0.499809       8.780953    1529.32292       6.965429
# min      2013.0       9.000000       1.000000   10140.00000       0.000000
# 25%      2013.0       9.000000       8.000000   11618.00000       5.000000
# 50%      2013.0      10.000000      16.000000   13342.00000      11.000000
# 75%      2013.0      10.000000      23.000000   14307.00000      17.000000
# max      2013.0      10.000000      31.000000   15376.00000      23.000000
#
#             Timezone     Visibility  DryBulbFarenheit  DryBulbCelsius  \
# count  113332.000000  113332.000000     113332.000000    113332.00000
# mean       -6.116772       9.179216         66.997300        19.44227
# std         1.371595       2.131229         12.683595         7.04596
# min       -10.000000       0.000000         26.000000        -3.30000
# 25%        -7.000000      10.000000         59.000000        15.00000
# 50%        -6.000000      10.000000         67.000000        19.40000
# 75%        -5.000000      10.000000         76.000000        24.40000
# max        -4.000000      10.000000        110.000000        43.30000
#
#        DewPointFarenheit  DewPointCelsius  RelativeHumidity      WindSpeed  \
# count      113332.000000    113332.000000     113332.000000  113332.000000
# mean           54.537306        12.521459         68.535992       6.841845
# std            13.627159         7.571196         20.614585       5.031292
# min            -1.000000       -18.300000          3.000000       0.000000
# 25%            46.000000         7.800000         55.000000       3.000000
# 50%            56.000000        13.300000         73.000000       7.000000
# 75%            66.000000        18.900000         85.000000      10.000000
# max            80.000000        26.700000        100.000000      43.000000
#
#            Altimeter
# count  113332.000000
# mean       29.993200
# std         0.157152
# min        28.940000
# 25%        29.900000
# 50%        29.990000
# 75%        30.090000
# max        30.530000
# Year                 0
# AdjustedMonth        0
# AdjustedDay          0
# AirportID            0
# AdjustedHour         0
# Timezone             0
# Visibility           0
# DryBulbFarenheit     0
# DryBulbCelsius       0
# DewPointFarenheit    0
# DewPointCelsius      0
# RelativeHumidity     0
# WindSpeed            0
# Altimeter            0
# dtype: int64

# %%
print(df.dtypes)
print(df.isnull().sum())
# Out:
# Year                   int64
# AdjustedMonth          int64
# AdjustedDay            int64
# AirportID              int64
# AdjustedHour           int64
# Timezone               int64
# Visibility           float64
# DryBulbFarenheit       int64
# DryBulbCelsius       float64
# DewPointFarenheit      int64
# DewPointCelsius      float64
# RelativeHumidity       int64
# WindSpeed              int64
# Altimeter            float64
# dtype: object
# Year                 0
# AdjustedMonth        0
# AdjustedDay          0
# AirportID            0
# AdjustedHour         0
# Timezone             0
# Visibility           0
# DryBulbFarenheit     0
# DryBulbCelsius       0
# DewPointFarenheit    0
# DewPointCelsius      0
# RelativeHumidity     0
# WindSpeed            0
# Altimeter            0
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Year', 'AdjustedMonth', 'AdjustedDay', 'AirportID', 'AdjustedHour', 'Timezone', 'Visibility', 'DryBulbFarenheit', 'DryBulbCelsius', 'DewPointFarenheit', 'DewPointCelsius', 'RelativeHumidity', 'WindSpeed', 'Altimeter']

# %%
print(df.columns.tolist())
# Out:
# ['Year', 'AdjustedMonth', 'AdjustedDay', 'AirportID', 'AdjustedHour', 'Timezone', 'Visibility', 'DryBulbFarenheit', 'DryBulbCelsius', 'DewPointFarenheit', 'DewPointCelsius', 'RelativeHumidity', 'WindSpeed', 'Altimeter']

# %%
print(df.columns.tolist())
df.head()
# Out:
# ['Year', 'AdjustedMonth', 'AdjustedDay', 'AirportID', 'AdjustedHour', 'Timezone', 'Visibility', 'DryBulbFarenheit', 'DryBulbCelsius', 'DewPointFarenheit', 'DewPointCelsius', 'RelativeHumidity', 'WindSpeed', 'Altimeter']
#    Year  AdjustedMonth  AdjustedDay  AirportID  AdjustedHour  Timezone  \
# 0  2013              9            1      14843             0        -4
# 1  2013              9            1      14843             1        -4
# 2  2013              9            1      14843             2        -4
# 3  2013              9            1      14843             3        -4
# 4  2013              9            1      14843             4        -4
#
#    Visibility  DryBulbFarenheit  DryBulbCelsius  DewPointFarenheit  \
# 0        10.0                81            27.2                 76
# 1        10.0                82            27.8                 76
# 2        10.0                81            27.2                 76
# 3        10.0                81            27.2                 76
# 4        10.0                83            28.3                 77
#
#    DewPointCelsius  RelativeHumidity  WindSpeed  Altimeter
# 0             24.4                85          0      29.95
# 1             24.4                82          0      29.95
# 2             24.4                85          0      29.95
# 3             24.4                85          0      29.96
# 4             25.0                82          0      29.97

# %%
df.columns
# Out:
# Index(['Year', 'AdjustedMonth', 'AdjustedDay', 'AirportID', 'AdjustedHour',
#        'Timezone', 'Visibility', 'DryBulbFarenheit', 'DryBulbCelsius',
#        'DewPointFarenheit', 'DewPointCelsius', 'RelativeHumidity', 'WindSpeed',
#        'Altimeter'],
#       dtype='str')
