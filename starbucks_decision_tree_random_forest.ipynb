# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("starbucks_location.csv")

df.head()
# Out:
#        Brand  Store Number  ... Longitude Latitude
# 0  Starbucks  47370-257954  ...      1.53    42.51
# 1  Starbucks  22331-212325  ...     55.47    25.42
# 2  Starbucks  47089-256771  ...     55.47    25.39
# 3  Starbucks  22126-218024  ...     54.38    24.48
# 4  Starbucks  17127-178586  ...     54.54    24.51
#
# [5 rows x 13 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe(include='all'))
print(df.isnull().sum())
# Out:
# (25600, 13)
# <class 'pandas.DataFrame'>
# RangeIndex: 25600 entries, 0 to 25599
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           25600 non-null  str
#  1   Store Number    25600 non-null  str
#  2   Store Name      25600 non-null  str
#  3   Ownership Type  25600 non-null  str
#  4   Street Address  25598 non-null  str
#  5   City            25585 non-null  str
#  6   State/Province  25600 non-null  str
#  7   Country         25600 non-null  str
#  8   Postcode        24078 non-null  str
#  9   Phone Number    18739 non-null  str
#  10  Timezone        25600 non-null  str
#  11  Longitude       25599 non-null  float64
#  12  Latitude        25599 non-null  float64
# dtypes: float64(2), str(11)
# memory usage: 5.9 MB
# None
#             Brand  Store Number  ...     Longitude      Latitude
# count       25600         25600  ...  25599.000000  25599.000000
# unique          4         25599  ...           NaN           NaN
# top     Starbucks  19773-160973  ...           NaN           NaN
# freq        25249             2  ...           NaN           NaN
# mean          NaN           NaN  ...    -27.872234     34.793016
# std           NaN           NaN  ...     96.844046     13.342332
# min           NaN           NaN  ...   -159.460000    -46.410000
# 25%           NaN           NaN  ...   -104.665000     31.240000
# 50%           NaN           NaN  ...    -79.350000     36.750000
# 75%           NaN           NaN  ...    100.630000     41.570000
# max           NaN           NaN  ...    176.920000     64.850000
#
# [11 rows x 13 columns]
# Brand                0
# Store Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6861
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %%
df.head()
# Out:
#        Brand  Store Number  ... Longitude Latitude
# 0  Starbucks  47370-257954  ...      1.53    42.51
# 1  Starbucks  22331-212325  ...     55.47    25.42
# 2  Starbucks  47089-256771  ...     55.47    25.39
# 3  Starbucks  22126-218024  ...     54.38    24.48
# 4  Starbucks  17127-178586  ...     54.54    24.51
#
# [5 rows x 13 columns]

# %%
categorical_cols = df.select_dtypes(include=['object', 'string']).columns

# %%
print(df.columns)
# Out:
# Index(['Brand', 'Store Number', 'Store Name', 'Ownership Type',
#        'Street Address', 'City', 'State/Province', 'Country', 'Postcode',
#        'Phone Number', 'Timezone', 'Longitude', 'Latitude'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Brand', 'Store Number', 'Store Name', 'Ownership Type',
#        'Street Address', 'City', 'State/Province', 'Country', 'Postcode',
#        'Phone Number', 'Timezone', 'Longitude', 'Latitude'],
#       dtype='str')

# %%
df.head()
# Out:
#    Brand  Store Number  Store Name  ...  Timezone  Longitude  Latitude
# 0      2         16993       12074  ...        42       1.53     42.51
# 1      2          7448        1931  ...        21      55.47     25.42
# 2      2         16831        5306  ...        21      55.47     25.39
# 3      2          7288       20602  ...        21      54.38     24.48
# 4      2          3933        1950  ...        21      54.54     24.51
#
# [5 rows x 13 columns]
