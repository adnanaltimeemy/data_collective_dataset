# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("heroes.csv", sep=';')

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (735, 12)
# <class 'pandas.DataFrame'>
# RangeIndex: 735 entries, 0 to 734
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              735 non-null    str
#  1   Identity          632 non-null    str
#  2   Birth place       317 non-null    str
#  3   Publisher         720 non-null    str
#  4   Height            518 non-null    float64
#  5   Weight            498 non-null    float64
#  6   Gender            706 non-null    str
#  7   First appearance  367 non-null    float64
#  8   Eye color         563 non-null    str
#  9   Hair color        563 non-null    str
#  10  Strength          609 non-null    float64
#  11  Intelligence      609 non-null    str
# dtypes: float64(4), str(8)
# memory usage: 108.6 KB
# None
#            Height      Weight  First appearance    Strength
# count  518.000000  498.000000        367.000000  609.000000
# mean   187.235077  112.447671       1979.855586   45.008210
# std     59.185250  103.964283         19.717218   33.031458
# min     15.340000    2.340000       1933.000000    5.000000
# 25%    173.935000   61.827500       1965.000000   10.000000
# 50%    183.235000   81.750000       1979.000000   35.000000
# 75%    190.495000  107.767500       1994.000000   80.000000
# max    975.370000  900.700000       2099.000000  100.000000

# %%
df = df.dropna()   # simple approach (you can improve later)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for column in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'Name'
# 'Identity'
# 'Birth place'
# 'Publisher'
# 'Height'
# 'Weight'
# 'Gender'
# 'First appearance'
# 'Eye color'
# 'Hair color'
# 'Strength'
# 'Intelligence'

# %%
import numpy as np

# Example dataset
data = np.array([
    [1, 2, 0],
    [3, 4, 1],
    [5, 6, 0]
])

X = data[:, :-1]
y = data[:, -1]

# %%
df.head()
# Out:
#     Name  Identity  Birth place  ...  Hair color  Strength  Intelligence
# 0      0       110           98  ...           9     100.0             4
# 16    81       141           79  ...           1      30.0             1
# 22     1        19           74  ...           9      80.0             4
# 23   141        92            3  ...           4      55.0             2
# 26     2         1           29  ...           3      10.0             1
#
# [5 rows x 12 columns]

# %%
print('X_train' in globals())
print('y_train' in globals())
# Out:
# False
# False

# %%
print(X.shape)
print(y.shape)
# Out:
# (3, 2)
# (3,)

# %%
print("X_test:", 'X_test' in globals())
print("y_test:", 'y_test' in globals())
print("dt_pred:", 'dt_pred' in globals())
print("rf_pred:", 'rf_pred' in globals())
# Out:
# X_test: False
# y_test: False
# dt_pred: False
# rf_pred: False

# %%
print(rf_model)
# Out:
# RandomForestClassifier(random_state=42)
