# %%
# =========================
# 1. Import Libraries
# =========================
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# =========================
# 2. Load Dataset
# =========================
df = pd.read_csv("Tomahawk.csv")

# View data
print(df.head())
print(df.info())
# Out:
#        site  lat  lng  ...          phone email web
# 0  Tomahawk  NaN  NaN  ...   01642 822000   NaN NaN
# 1  Tomahawk  NaN  NaN  ...   01482 231330   NaN NaN
# 2  Tomahawk  NaN  NaN  ...   01244 311839   NaN NaN
# 3  Tomahawk  NaN  NaN  ...   01325 344399   NaN NaN
# 4  Tomahawk  NaN  NaN  ...  0191 386 6210   NaN NaN
#
# [5 rows x 9 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   site     17 non-null     str
#  1   lat      0 non-null      float64
#  2   lng      0 non-null      float64
#  3   zip      17 non-null     str
#  4   name     17 non-null     str
#  5   address  17 non-null     str
#  6   phone    13 non-null     str
#  7   email    0 non-null      float64
#  8   web      0 non-null      float64
# dtypes: float64(4), str(5)
# memory usage: 2.6 KB
# None

# %%
# =========================
# 3. Handle Missing Values
# =========================
df = df.dropna()   # simple approach (you can improve later)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for col in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
print(df.head())
# Out:
# Empty DataFrame
# Columns: [site, lat, lng, zip, name, address, phone, email, web]
# Index: []

# %%
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
"target_column"
# Out:
# 'target_column'

# %%
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')
