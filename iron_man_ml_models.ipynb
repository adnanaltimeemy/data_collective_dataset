# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("iron_man_uppercase_unique.csv")

# View basic info
print(df.head())
print(df.info())
print(df.describe())
# Out:
#     41    JARVIS  1  1.1  0
# 0  122  PEPPER.”  1    0  0
# 1   31   OBADIAH  1    1  0
# 2  121   MONITOR  1    0  0
# 3   33     WOMAN  1    1  0
# 4   95    TYCOON  1    1  0
# <class 'pandas.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   41      136 non-null    int64
#  1   JARVIS  136 non-null    str
#  2   1       136 non-null    int64
#  3   1.1     136 non-null    int64
#  4   0       136 non-null    int64
# dtypes: int64(4), str(1)
# memory usage: 7.5 KB
# None
#                41           1         1.1           0
# count  136.000000  136.000000  136.000000  136.000000
# mean    68.198529    3.044118    0.301471    0.154412
# std     39.770978    2.529435    0.460593    0.362679
# min      0.000000    1.000000    0.000000    0.000000
# 25%     33.750000    1.000000    0.000000    0.000000
# 50%     68.500000    2.000000    0.000000    0.000000
# 75%    102.250000    4.000000    1.000000    0.000000
# max    136.000000   12.000000    1.000000    1.000000

# %%
# Drop duplicates if any
df = df.drop_duplicates()

# Handle missing values (simple strategy)
df = df.dropna()

# %%
label_encoders = {}

for column in df.columns:
    if df[column].dtype == 'object':
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column])
        label_encoders[column] = le

# %%
print("Columns:")
for col in df.columns:
    print(repr(col))
# Out:
# Columns:
# '41'
# 'JARVIS'
# '1'
# '1.1'
# '0'

# %%
df.columns.tolist()
# Out:
# ['41', 'JARVIS', '1', '1.1', '0']

# %%
print(df.columns.tolist())
# Out:
# ['41', 'JARVIS', '1', '1.1', '0']

# %%
print(df.columns.tolist())
# Out:
# ['41', 'JARVIS', '1', '1.1', '0']
