# %%
# Import libraries

import pandas as pd
import numpy as np

# NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Machine learning
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# Visualization
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# Load CSV file

movies = pd.read_csv("movies-hun.csv")

# Display first rows
movies.head()
# Out:
#                            Film       Műfaj            Stúdió  \
# 0                        Avatar       Akció  20th Century Fox
# 1         Bosszúállók: Végjáték       Akció    Marvel Studios
# 2                       Titanic  Romantikus  20th Century Fox
# 3      Star Wars: Az Ébredő Erő       Akció         Lucasfilm
# 4  Bosszúállók: Végtelen háború       Akció    Marvel Studios
#
#    Közönség értékelés (%)  Bevétel (millió $)  Kiadás (millió $)    Év
# 0                      82                2847                261  2009
# 1                      91                2798                356  2019
# 2                      90                2187                294  1997
# 3                      86                2068                447  2015
# 4                      91                2048                325  2018

# %%
movies.info()

print(movies.columns)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Film                    25 non-null     str
#  1   Műfaj                   25 non-null     str
#  2   Stúdió                  25 non-null     str
#  3   Közönség értékelés (%)  25 non-null     int64
#  4   Bevétel (millió $)      25 non-null     int64
#  5   Kiadás (millió $)       25 non-null     int64
#  6   Év                      25 non-null     int64
# dtypes: int64(4), str(3)
# memory usage: 2.5 KB
# Index(['Film', 'Műfaj', 'Stúdió', 'Közönség értékelés (%)',
#        'Bevétel (millió $)', 'Kiadás (millió $)', 'Év'],
#       dtype='str')

# %%
print(movies.columns)

if text_column in movies.columns:
    movies["clean_text"] = movies[text_column].apply(clean_text)
else:
    print(f"Column '{text_column}' not found.")
# Out:
# Index(['Film', 'Műfaj', 'Stúdió', 'Közönség értékelés (%)',
#        'Bevétel (millió $)', 'Kiadás (millió $)', 'Év'],
#       dtype='str')
# Column 'description' not found.

# %%
print(movies.shape)
print(movies.columns.tolist())
# Out:
# (25, 7)
# ['Film', 'Műfaj', 'Stúdió', 'Közönség értékelés (%)', 'Bevétel (millió $)', 'Kiadás (millió $)', 'Év']

# %%
movies.columns
# Out:
# Index(['Film', 'Műfaj', 'Stúdió', 'Közönség értékelés (%)',
#        'Bevétel (millió $)', 'Kiadás (millió $)', 'Év'],
#       dtype='str')

# %%
movies.to_csv(
    "movies_hun_clustered.csv",
    index=False
)
