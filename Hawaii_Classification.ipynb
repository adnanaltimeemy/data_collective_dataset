# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("hawaii.csv")

df.head()
# Out:
#                                      id                        name  \
# 0  cc1c18dc-77d7-4ca5-b3b7-8180f77feecd               Aloha Beer Co
# 1  bf244193-89cd-4321-906c-abda26f7199d     Beer Lab HI - Beretania
# 2  cd6359e5-3449-49a1-aa3d-23e0bfc8b2d8    Beer Lab HI - Pearlridge
# 3  8b27739b-7bf1-4e11-ae31-920941115b64  Beer Lab HI - Puck's Alley
# 4  d2699492-6d8c-492d-a52d-e71342e717ca         Big Island Brewhaus
#
#   brewery_type                     address_1  address_2  address_3      city  \
# 0      brewpub                  700 Queen St        NaN        NaN  Honolulu
# 1        micro           1318 S Beretania St        NaN        NaN  Honolulu
# 2      brewpub      98-1005 Moanalua Rd #884        NaN        NaN      Aiea
# 3      brewpub           2600 S King St #107        NaN        NaN  Honolulu
# 4      brewpub  64-1066 Mamalahoa Hwy Unit 5        NaN        NaN   Kamuela
#
#   state_province postal_code        country         phone  \
# 0         Hawaii  96813-5110  United States  8.085442e+09
# 1         Hawaii  96814-1512  United States  8.088880e+09
# 2         Hawaii  96701-4700  United States  8.087620e+09
# 3         Hawaii  96826-3266  United States  8.087440e+09
# 4         Hawaii  96743-7309  United States  8.088872e+09
#
#                             website_url   longitude   latitude
# 0              http://www.alohabeer.com -157.857248  21.301249
# 1   https://www.beerlabhi.com/beretania -157.840622  21.301161
# 2  https://www.beerlabhi.com/pearlridge -157.939931  21.383086
# 3       https://www.beerlabhi.com/pucks -157.821405  21.292193
# 4      http://www.bigislandbrewhaus.com -155.661471  20.025552

# %%
df.info()
df.describe()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              34 non-null     str
#  1   name            34 non-null     str
#  2   brewery_type    34 non-null     str
#  3   address_1       34 non-null     str
#  4   address_2       0 non-null      float64
#  5   address_3       0 non-null      float64
#  6   city            34 non-null     str
#  7   state_province  34 non-null     str
#  8   postal_code     34 non-null     str
#  9   country         34 non-null     str
#  10  phone           28 non-null     float64
#  11  website_url     34 non-null     str
#  12  longitude       34 non-null     float64
#  13  latitude        34 non-null     float64
# dtypes: float64(5), str(9)
# memory usage: 9.1 KB
# id                 0
# name               0
# brewery_type       0
# address_1          0
# address_2         34
# address_3         34
# city               0
# state_province     0
# postal_code        0
# country            0
# phone              6
# website_url        0
# longitude          0
# latitude           0
# dtype: int64

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [id, name, brewery_type, address_1, address_2, address_3, city, state_province, postal_code, country, phone, website_url, longitude, latitude]
# Index: []

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['id', 'name', 'brewery_type', 'address_1', 'address_2', 'address_3', 'city', 'state_province', 'postal_code', 'country', 'phone', 'website_url', 'longitude', 'latitude']
# Empty DataFrame
# Columns: [id, name, brewery_type, address_1, address_2, address_3, city, state_province, postal_code, country, phone, website_url, longitude, latitude]
# Index: []

# %%
print(df.columns.tolist())
# Out:
# ['id', 'name', 'brewery_type', 'address_1', 'address_2', 'address_3', 'city', 'state_province', 'postal_code', 'country', 'phone', 'website_url', 'longitude', 'latitude']

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [id, name, brewery_type, address_1, address_2, address_3, city, state_province, postal_code, country, phone, website_url, longitude, latitude]
# Index: []
