# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Date_Corrections.csv")

# Preview
df.head()
# Out:
#                        Title NewAirDate
# 0  Let He Who Is Without Sin  11-Nov-96
# 1                     Basics  20-May-96
# 2                  Flashback  09-Nov-96
# 3                  The Chute  18-Sep-96
# 4              False Profits  02-Oct-96

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       22 non-null     str
#  1   NewAirDate  22 non-null     str
# dtypes: str(2)
# memory usage: 928.0 bytes
# Title         0
# NewAirDate    0
# dtype: int64

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Title', 'NewAirDate'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Title', 'NewAirDate'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Title', 'NewAirDate'], dtype='str')

# %%
X = df.values

# %%
X = df.drop(columns=['Title'])

# %%
print(X.dtypes)
# Out:
# NewAirDate    str
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['Title', 'NewAirDate'], dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['Title', 'NewAirDate'], dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['Title', 'NewAirDate'], dtype='str')

# %%
df.columns
df.head()
# Out:
#                        Title NewAirDate
# 0  Let He Who Is Without Sin  11-Nov-96
# 1                     Basics  20-May-96
# 2                  Flashback  09-Nov-96
# 3                  The Chute  18-Sep-96
# 4              False Profits  02-Oct-96
