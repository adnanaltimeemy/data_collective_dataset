# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("ncaa-team-data.csv")

# Quick look
print(df.head())
print(df.info())
# Out:
#     season       conf   w   l     wl  w_conf  l_conf  wl_conf    srs   sos  \
# 0  2018-19  Southland  27   6  0.818    14.0     4.0    0.778  -1.28 -8.10
# 1  2017-18  Southland  16  16  0.500     8.0    10.0    0.444  -9.14 -6.82
# 2  2016-17  Southland  13  16  0.448     7.0    11.0    0.389 -11.86 -7.10
# 3  2015-16  Southland  13  18  0.419     8.0    10.0    0.444 -13.93 -7.53
# 4  2014-15  Southland  10  21  0.323     4.0    14.0    0.222 -17.20 -6.34
#
#    ...  seed      coaches  seeded  year  is_ap_pre  is_ap_high  is_ap_final  \
# 0  ...    15  Joe Golding    True  2019      False       False        False
# 1  ...    20  Joe Golding   False  2018      False       False        False
# 2  ...    20  Joe Golding   False  2017      False       False        False
# 3  ...    20  Joe Golding   False  2016      False       False        False
# 4  ...    20  Joe Golding   False  2015      False       False        False
#
#   pts_diff             school  pts_total
# 0     11.4  abilene-christian      137.6
# 1      2.5  abilene-christian      144.9
# 2     -2.2  abilene-christian      140.8
# 3     -2.0  abilene-christian      144.6
# 4     -6.8  abilene-christian      134.2
#
# [5 rows x 26 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 17840 entries, 0 to 17839
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           17840 non-null  str
#  1   conf             17840 non-null  str
#  2   w                17840 non-null  int64
#  3   l                17840 non-null  int64
#  4   wl               17840 non-null  float64
#  5   w_conf           17840 non-null  float64
#  6   l_conf           17840 non-null  float64
#  7   wl_conf          17840 non-null  float64
#  8   srs              17840 non-null  float64
#  9   sos              17840 non-null  float64
#  10  pts              17840 non-null  float64
#  11  pts_vs           17840 non-null  float64
#  12  ap_pre           17840 non-null  int64
#  13  ap_high          17840 non-null  int64
#  14  ap_final         17840 non-null  int64
#  15  ncaa_tournament  17840 non-null  int64
#  16  seed             17840 non-null  int64
#  17  coaches          17840 non-null  str
#  18  seeded           17840 non-null  bool
#  19  year             17840 non-null  int64
#  20  is_ap_pre        17840 non-null  bool
#  21  is_ap_high       17840 non-null  bool
#  22  is_ap_final      17840 non-null  bool
#  23  pts_diff         17840 non-null  float64
#  24  school           17840 non-null  str
#  25  pts_total        17840 non-null  float64
# dtypes: bool(4), float64(10), int64(8), str(4)
# memory usage: 3.7 MB
# None

# %%
# Drop missing values (simple approach)
df = df.dropna()

# If there are categorical columns, encode them
df = pd.get_dummies(df, drop_first=True)

print(df.shape)
# Out:
# (17840, 2696)

# %%
X = df.drop("target", axis=1, errors="ignore")

# %%
df.columns.tolist()
# Out:
# ['w',
#  'l',
#  'wl',
#  'w_conf',
#  'l_conf',
#  'wl_conf',
#  'srs',
#  'sos',
#  'pts',
#  'pts_vs',
#  'ap_pre',
#  'ap_high',
#  'ap_final',
#  'ncaa_tournament',
#  'seed',
#  'seeded',
#  'year',
#  'is_ap_pre',
#  'is_ap_high',
#  'is_ap_final',
#  'pts_diff',
#  'pts_total',
#  'season_1947-48-nm',
#  'season_1948-49',
#  'season_1948-49-nm',
#  'season_1949-50',
#  'season_1949-50-nm',
#  'season_1950-51',
#  'season_1950-51-nm',
#  'season_1951-52',
#  'season_1951-52-nm',
#  'season_1952-53',
#  'season_1952-53-nm',
#  'season_1953-54',
#  'season_1953-54-nm',
#  'season_1954-55',
#  'season_1954-55-nm',
#  'season_1955-56',
#  'season_1955-56-nm',
#  'season_1956-57',
#  'season_1956-57-nm',
#  'season_1957-58',
#  'season_1957-58-nm',
#  'season_1958-59',
#  'season_1958-59-nm',
#  'season_1959-60',
#  'season_1959-60-nm',
#  'season_1960-61',
#  'season_1960-61-nm',
#  'season_1961-62',
#  'season_1962-63',
#  'season_1963-64',
#  'season_1964-65',
#  'season_1965-66',
#  'season_1965-66-nm',
#  'season_1966-67',
#  'season_1966-67-nm',
#  'season_1967-68',
#  'season_1967-68-nm',
#  'season_1968-69',
#  'season_1968-69-nm',
#  'season_1969-70',
#  'season_1969-70-nm',
#  'season_1970-71',
#  'season_1970-71-nm',
#  'season_1971-72',
#  'season_1971-72-nm',
#  'season_1972-73',
#  'season_1972-73-nm',
#  'season_1973-74',
#  'season_1974-75',
#  'season_1975-76',
#  'season_1976-77',
#  'season_1977-78',
#  'season_1978-79',
#  'season_1979-80',
#  'season_1979-80-nm',
#  'season_1980-81',
#  'season_1981-82',
#  'season_1982-83',
#  'season_1983-84',
#  'season_1984-85',
#  'season_1985-86',
#  'season_1986-87',
#  'season_1987-88',
#  'season_1988-89',
#  'season_1989-90',
#  'season_1990-91',
#  'season_1991-92',
#  'season_1992-93',
#  'season_1993-94',
#  'season_1994-95',
#  'season_1995-96',
#  'season_1996-97',
#  'season_1996-97-nm',
#  'season_1997-98',
#  'season_1998-99',
#  'season_1998-99-nm',
#  'season_1999-00',
#  'season_2000-01',
#  'season_2001-02',
#  'season_2002-03',
#  'season_2002-03-nm',
#  'season_2003-04',
#  'season_2004-05',
#  'season_2004-05-nm',
#  'season_2005-06',
#  'season_2005-06-nm',
#  'season_2006-07',
#  'season_2006-07-nm',
#  'season_2007-08',
#  'season_2007-08-nm',
#  'season_2008-09',
#  'season_2008-09-nm',
#  'season_2009-10',
#  'season_2009-10-nm',
#  'season_2010-11',
#  'season_2011-12',
#  'season_2012-13',
#  'season_2013-14',
#  'season_2014-15',
#  'season_2015-16',
#  'season_2016-17',
#  'season_2017-18',
#  'season_2018-19',
#  'conf_A-Sun',
#  'conf_AAC',
#  'conf_AAWU',
#  'conf_ACC',
#  'conf_AEC',
#  'conf_ASC',
#  'conf_AWC',
#  'conf_BIAA',
#  'conf_Big 12',
#  'conf_Big 7',
#  'conf_Big 8',
#  'conf_Big East',
#  'conf_Big Sky',
#  'conf_Big South',
#  'conf_Big Ten',
#  'conf_Big West',
#  'conf_CAA',
#  'conf_CBA',
#  'conf_CUSA',
#  'conf_EAA',
#  'conf_ECACM',
#  'conf_ECACN',
#  'conf_ECACS',
#  'conf_ECBL',
#  'conf_ECC',
#  'conf_GMWC',
#  'conf_GSC',
#  'conf_GWC',
#  'conf_Horizon',
#  'conf_Ind',
#  'conf_Ivy',
#  'conf_MAAC',
#  'conf_MAC',
#  'conf_MCC',
#  'conf_MEAC',
#  'conf_MSAC',
#  'conf_MVC',
#  'conf_MW City',
#  'conf_MW Coll',
#  'conf_MWC',
#  'conf_Metro',
#  'conf_Metro NY',
#  'conf_Mid-3',
#  'conf_Mid-Atl',
#  'conf_Mid-Cont',
#  'conf_NAC',
#  'conf_NEC',
#  'conf_NJNY7',
#  'conf_OVC',
#  'conf_PCAA',
#  'conf_PCC',
#  'conf_Pac-10',
#  'conf_Pac-12',
#  'conf_Pac-8',
#  'conf_Patriot',
#  'conf_SEC',
#  'conf_SWAC',
#  'conf_SWC',
#  'conf_Southern',
#  'conf_Southland',
#  'conf_Summit',
#  'conf_Sun Belt',
#  'conf_TAAC',
#  'conf_WAC',
#  'conf_WCAC',
#  'conf_WCC',
#  'conf_WNY3',
#  'conf_Yankee',
#  'coaches_A.W. Hamilton',
#  'coaches_Aaron James',
#  'coaches_Abe Lemons',
#  'coaches_Adam Walsh',
#  'coaches_Adolph Rupp',
#  'coaches_Adrian Buoncristiani',
#  'coaches_Ajac Triplett',
#  'coaches_Aki Thomas',
#  'coaches_Al Baggett',
#  'coaches_Al Brown',
#  'coaches_Al Grushkin',
#  'coaches_Al Harden',
#  'coaches_Al Lobalbo',
#  'coaches_Al McGuire',
#  'coaches_Al Seibert',
#  'coaches_Al Skinner',
#  'coaches_Al Walker',
#  'coaches_Alan Kyber',
#  'coaches_Alan LeForce',
#  'coaches_Alan Major',
#  'coaches_Albert Brightman',
#  'coaches_Albert E. Negratti',
#  'coaches_Albert McClellan',
#  'coaches_Alden Pasche',
#  'coaches_Alex Severence',
#  'coaches_Alfred Robertson',
#  'coaches_Allan Freund',
#  'coaches_Allen Edwards',
#  'coaches_Allen Van Winkle',
#  'coaches_Alton Kircher',
#  'coaches_Alvin Brooks',
#  'coaches_Andre Payne',
#  'coaches_Andrew Greer',
#  'coaches_Andrew Toole',
#  'coaches_Andy Enfield',
#  'coaches_Andy Kennedy',
#  'coaches_Andy Newman',
#  'coaches_Andy Russo',
#  'coaches_Andy Stoglin',
#  'coaches_Andy Walker',
#  'coaches_Anfernee Hardaway',
#  'coaches_Anthony Evans',
#  'coaches_Anthony Fields',
#  'coaches_Anthony Grant',
#  'coaches_Anthony Kuolt',
#  'coaches_Anthony Latina',
#  'coaches_Anthony Packer',
#  'coaches_Anthony Solomon',
#  'coaches_Anthony Stewart',
#  'coaches_Arad McCutchan',
#  'coaches_Archie Miller',
#  'coaches_Archie Oldham',
#  'coaches_Armond Hill',
#  'coaches_Art Loche',
#  'coaches_Art Perry',
#  'coaches_Art Tolis',
#  'coaches_Arthur Gallon',
#  'coaches_Arthur McLarney',
#  'coaches_Ashley Howard',
#  'coaches_Austin Claunch',
#  'coaches_Avery Johnson',
#  'coaches_B.J. Hill',
#  'coaches_Babe McCarthy',
#  'coaches_Bacari Alexander',
#  'coaches_Baker Dunleavy',
#  'coaches_Banks McFadden',
#  'coaches_Barclay Radebaugh',
#  'coaches_Barret Peery',
#  'coaches_Barry Collier',
#  'coaches_Barry Dowd',
#  'coaches_Barry Hinson',
#  'coaches_Barry Parkhill',
#  'coaches_Barry Rohrssen',
#  'coaches_Bart Bellairs',
#  'coaches_Bart Lundy',
#  'coaches_Bashir Mason',
#  'coaches_Bebe Lee',
#  'coaches_Ben Betts',
#  'coaches_Ben Bluitt',
#  'coaches_Ben Braun',
#  'coaches_Ben Carnevale',
#  'coaches_Ben Howland',
#  'coaches_Ben Jacobson',
#  'coaches_Ben Jobe',
#  'coaches_Ben Kribbs',
#  'coaches_Ben Lindsey',
#  'coaches_Benjamin Neff',
#  'coaches_Benjamin VanAlstyne',
#  'coaches_Benjy Taylor',
#  'coaches_Bennie Seltzer',
#  'coaches_Benny Dees',
#  'coaches_Benny Hollis',
#  'coaches_Benny Moss',
#  'coaches_Berl Huffman',
#  'coaches_Bernard Wilson',
#  'coaches_Bernie Ockene',
#  'coaches_Beryl Shipley',
#  'coaches_Bill Bayno',
#  'coaches_Bill Berry',
#  'coaches_Bill Bibb',
#  'coaches_Bill Blair',
#  'coaches_Bill Blakeley',
#  'coaches_Bill Burke',
#  'coaches_Bill C. Foster',
#  'coaches_Bill Carmody',
#  'coaches_Bill Chandler',
#  'coaches_Bill Coen',
#  'coaches_Bill Cofield',
#  'coaches_Bill Courtney',
#  'coaches_Bill Detrick',
#  'coaches_Bill Dooley',
#  'coaches_Bill E. Foster',
#  'coaches_Bill Evans',
#  'coaches_Bill Ferguson',
#  'coaches_Bill Fitch',
#  'coaches_Bill Franey',
#  'coaches_Bill Frieder',
#  'coaches_Bill Gardiner',
#  'coaches_Bill Gibson',
#  'coaches_Bill Grier',
#  'coaches_Bill Guthridge',
#  'coaches_Bill Harrell',
#  'coaches_Bill Henderson',
#  'coaches_Bill Herrion',
#  'coaches_Bill Hodges',
#  'coaches_Bill Jones',
#  'coaches_Bill Kajikawa',
#  'coaches_Bill Kirsch',
#  'coaches_Bill Klucas',
#  'coaches_Bill Lynn',
#  'coaches_Bill Menefee',
#  'coaches_Bill Mulligan',
#  'coaches_Bill Musselman',
#  "coaches_Bill O'Connor",
#  'coaches_Bill Oates',
#  'coaches_Bill Olson',
#  'coaches_Bill Perigo',
#  'coaches_Bill Raftery',
#  'coaches_Bill Reigel',
#  'coaches_Bill Rohr',
#  'coaches_Bill Scott',
#  'coaches_Bill Self',
#  'coaches_Bill Stockton',
#  'coaches_Bill Strannigan',
#  'coaches_Bill Trumbo',
#  'coaches_Bill Turner',
#  'coaches_Bill Vesp',
#  'coaches_Bill Weimar',
#  'coaches_Bill White',
#  'coaches_Bill Whitmore',
#  'coaches_Bill Wright',
#  'coaches_Billy Donlon',
#  'coaches_Billy Donovan',
#  'coaches_Billy Gillispie',
#  'coaches_Billy Hahn',
#  'coaches_Billy Henry',
#  'coaches_Billy Kennedy',
#  'coaches_Billy Lange',
#  'coaches_Billy Lee',
#  'coaches_Billy McCann',
#  'coaches_Billy Taylor',
#  'coaches_Billy Tubbs',
#  'coaches_Blaine Taylor',
#  'coaches_Blair Gullion',
#  'coaches_Blue Foster',
#  'coaches_Bo Brickels',
#  'coaches_Bo Ellis',
#  'coaches_Bo Ryan',
#  'coaches_Bo Shepard',
#  'coaches_Bob Bass',
#  'coaches_Bob Bender',
#  'coaches_Bob Beyer',
#  'coaches_Bob Boyd',
#  'coaches_Bob Brown',
#  'coaches_Bob Burton',
#  'coaches_Bob Calihan',
#  'coaches_Bob Conibear',
#  'coaches_Bob Cousy',
#  'coaches_Bob Daniels',
#  'coaches_Bob Davis',
#  'coaches_Bob Dewey',
#  'coaches_Bob Donewald',
#  'coaches_Bob Duffy',
#  'coaches_Bob Dukiet',
#  'coaches_Bob Feerick',
#  'coaches_Bob Gaillard',
#  'coaches_Bob Gottlieb',
#  'coaches_Bob Greenwood',
#  'coaches_Bob Hallberg',
#  'coaches_Bob Hamilton',
#  'coaches_Bob Hawking',
#  'coaches_Bob Hill',
#  'coaches_Bob Hoffman',
#  'coaches_Bob Hofman',
#  'coaches_Bob Huggins',
#  'coaches_Bob Kelly',
#  'coaches_Bob King',
#  'coaches_Bob Knight',
#  'coaches_Bob Leckie',
#  'coaches_Bob Luksta',
#  'coaches_Bob MacKinnon',
#  'coaches_Bob Marlin',
#  'coaches_Bob McKillop',
#  'coaches_Bob McKinley',
#  'coaches_Bob Miller',
#  'coaches_Bob Mulcahy',
#  'coaches_Bob Nichols',
#  'coaches_Bob Ortegel',
#  'coaches_Bob Prewitt',
#  'coaches_Bob Quinn',
#  'coaches_Bob Reinhart',
#  'coaches_Bob Richey',
#  'coaches_Bob Rupert',
#  'coaches_Bob Schermerhorn',
#  'coaches_Bob Snake LeGrand',
#  'coaches_Bob Spear',
#  'coaches_Bob Staak',
#  'coaches_Bob Stevens',
#  'coaches_Bob Sundvold',
#  'coaches_Bob Sweeney',
#  'coaches_Bob Tallent',
#  'coaches_Bob Thomason',
#  'coaches_Bob Valvano',
#  'coaches_Bob Vanatta',
#  'coaches_Bob Wade',
#  'coaches_Bob Walsh',
#  'coaches_Bob Walters',
#  'coaches_Bob Weinhauer',
#  'coaches_Bob Weltlich',
#  'coaches_Bob Wenzel',
#  'coaches_Bob Williams',
#  'coaches_Bob Wright',
#  'coaches_Bob Zuffelato',
#  'coaches_Bobby Braswell',
#  'coaches_Bobby Collins',
#  'coaches_Bobby Cremins',
#  'coaches_Bobby Dye',
#  'coaches_Bobby Gonzalez',
#  'coaches_Bobby Hurley',
#  'coaches_Bobby Hussey',
#  'coaches_Bobby Jones',
#  'coaches_Bobby Laughlin',
#  'coaches_Bobby Lutz',
#  'coaches_Bobby Nash',
#  'coaches_Bobby Paschal',
#  'coaches_Bobby Roberts',
#  'coaches_Bobby Rogers',
#  'coaches_Bobby Watson',
#  'coaches_Bones McKinney',
#  'coaches_Brad Brownell',
#  'coaches_Brad Greenberg',
#  'coaches_Brad Holland',
#  'coaches_Brad Huse',
#  'coaches_Brad Siegfried',
#  'coaches_Brad Snyder',
#  'coaches_Brad Soderberg',
#  'coaches_Brad Stevens',
#  'coaches_Brad Underwood',
#  'coaches_Branch McCracken',
#  'coaches_Brandon Miller',
#  'coaches_Brendan Malone',
#  'coaches_Bret Campbell',
#  'coaches_Brett Reed',
#  'coaches_Brian Collins',
#  'coaches_Brian Dutcher',
#  'coaches_Brian Earl',
#  'coaches_Brian Ellerbe',
#  'coaches_Brian Fish',
#  'coaches_Brian Gregory',
#  'coaches_Brian Hammel',
#  'coaches_Brian Hill',
#  'coaches_Brian Jones',
#  'coaches_Brian Katz',
#  'coaches_Brian Kennedy',
#  'coaches_Brian Mahoney',
#  'coaches_Brian McCall',
#  'coaches_Brian Nash',
#  'coaches_Brian Wardle',
#  'coaches_Brick Breeden',
#  'coaches_Brooks Thompson',
#  'coaches_Bruce Drake',
#  'coaches_Bruce Hale',
#  'coaches_Bruce Haroldson',
#  'coaches_Bruce Larson',
#  "coaches_Bruce O'Neil",
#  'coaches_Bruce Parkhill',
#  'coaches_Bruce Pearl',
#  'coaches_Bruce Stewart',
#  'coaches_Bruce Weber',
#  'coaches_Bruiser Flint',
#  'coaches_Bryce Drew',
#  "coaches_Bucky O'Connor",
#  'coaches_Bucky Waters',
#  'coaches_Bud Foster',
#  'coaches_Bud Getchell',
#  'coaches_Bud Kennedy',
#  'coaches_Bud Millikan',
#  'coaches_Buddy Brehmer',
#  'coaches_Buddy Jeannette',
#  'coaches_Buddy Mahar',
#  "coaches_Buddy O'Grady",
#  'coaches_Burr Carlson',
#  'coaches_Bus Connor',
#  'coaches_Bus Male',
#  'coaches_Buster Brannon',
#  'coaches_Buster Harvey',
#  'coaches_Buster Sheary',
#  'coaches_Butch Beard',
#  'coaches_Butch Estes',
#  'coaches_Butch Pierre',
#  'coaches_Butch van Breda Kolff',
#  'coaches_Buzz Peterson',
#  'coaches_Buzz Ridl',
#  'coaches_Buzz Williams',
#  'coaches_Byron Rimm',
#  'coaches_Byron Samuels',
#  'coaches_Byron Smith',
#  'coaches_C.B. McGrath',
#  'coaches_C.M. Newton',
#  'coaches_Cal Luther',
#  'coaches_Calvin Irvin',
#  'coaches_Calvin White',
#  'coaches_Cam Henderson',
#  'coaches_Cameron Dollar',
#  'coaches_Cappy Cappon',
#  'coaches_Carl Slone',
#  'coaches_Carl Stewart',
#  'coaches_Carl Tacy',
#  'coaches_Carnie Hatch',
#  'coaches_Carroll Dawson',
#  'coaches_Carroll Williams',
#  'coaches_Carson Cunningham',
#  'coaches_Carter Wilson',
#  'coaches_Casey Alexander',
#  'coaches_Cecil Baker',
#  'coaches_Celester Collier',
#  'coaches_Charles Bradley',
#  'coaches_Charles Cummings',
#  'coaches_Charles Finley',
#  'coaches_Charles Johnson',
#  'coaches_Charles Luce',
#  'coaches_Charles McGlone',
#  'coaches_Charles Moir',
#  'coaches_Charles Ramsey',
#  'coaches_Charles Spoonhour',
#  'coaches_Charles Woollum',
#  'coaches_Charlie Coles',
#  'coaches_Charlie Harrison',
#  'coaches_Charlie Parker',
#  'coaches_Charlie Schmaus',
#  'coaches_Charlton Young',
#  'coaches_Chester Sellitto',
#  'coaches_Chick Davies',
#  'coaches_Chico Caldwell',
#  'coaches_Chico Potts',
#  'coaches_Chip Conner',
#  'coaches_Chris Beard',
#  'coaches_Chris Casey',
#  'coaches_Chris Collins',
#  'coaches_Chris Fuller',
#  'coaches_Chris Holtmann',
#  'coaches_Chris Jans',
#  'coaches_Chris Knoche',
#  'coaches_Chris Lowery',
#  'coaches_Chris Mack',
#  'coaches_Chris Mooney',
#  'coaches_Chris Mullin',
#  'coaches_Chris Ogden',
#  'coaches_Chris Walker',
#  'coaches_Chuck Daly',
#  'coaches_Chuck Driesell',
#  'coaches_Chuck Martin',
#  'coaches_Chuck Noe',
#  'coaches_Chuck Orsborn',
#  'coaches_Chuck Swenson',
#  'coaches_Clair Bee',
#  'coaches_Clarence Finley',
#  'coaches_Clarence Iba',
#  'coaches_Clarence Sonny Means',
#  'coaches_Claude English',
#  'coaches_Claude Retherford',
#  'coaches_Clay Sutherland',
#  'coaches_Clem Haskins',
#  'coaches_Clemon Johnson',
#  'coaches_Cleveland Edwards',
#  'coaches_Cliff Ellis',
#  'coaches_Cliff Malpass',
#  'coaches_Cliff Warren',
#  'coaches_Cliff Wettig',
#  'coaches_Clifford Reed',
#  'coaches_Clifford Wells',
#  'coaches_Clint Bryant',
#  'coaches_Clyde Drexler',
#  'coaches_Cob Jarvis',
#  'coaches_Coleman Crawford',
#  'coaches_Connie Inman',
#  'coaches_Corey Williams',
#  'coaches_Corliss Williamson',
#  'coaches_Cotton Fitzsimmons',
#  'coaches_Country Graham',
#  'coaches_Craig Esherick',
#  'coaches_Craig Hodges',
#  'coaches_Craig Littlepage',
#  'coaches_Craig Neal',
#  'coaches_Craig Rasmusen',
#  'coaches_Craig Robinson',
#  'coaches_Craig Smith',
#  'coaches_Cuonzo Martin',
#  'coaches_Curtis Hunter',
#  'coaches_Cy Alexander',
#  'coaches_Cy McClairen',
#  'coaches_Dale Bandy',
#  'coaches_Dale Brown',
#  'coaches_Dale Layer',
#  'coaches_Damon Stoudamire',
#  'coaches_Dan Bazzani',
#  'coaches_Dan Bell',
#  'coaches_Dan Belluomini',
#  'coaches_Dan Cunha',
#  "coaches_Dan D'Antoni",
#  'coaches_Dan Dakich',
#  'coaches_Dan Dougherty',
#  'coaches_Dan Earl',
#  'coaches_Dan Engelstad',
#  'coaches_Dan Fitzgerald',
#  'coaches_Dan Glines',
#  'coaches_Dan Hipsher',
#  'coaches_Dan Hurley',
#  'coaches_Dan Jones',
#  'coaches_Dan Kenney',
#  'coaches_Dan Leibovitz',
#  'coaches_Dan Majerle',
#  'coaches_Dan McHale',
#  'coaches_Dan Monson',
#  'coaches_Dan Muller',
#  'coaches_Dan Peters',
#  'coaches_Dan Raskin',
#  'coaches_Dan Spika',
#  'coaches_Dana Altman',
#  'coaches_Dana Ford',
#  'coaches_Dana Kirk',
#  'coaches_Dane Fife',
#  'coaches_Daniel Lynch',
#  'coaches_Danny Doyle',
#  'coaches_Danny Kaspar',
#  'coaches_Danny Manning',
#  'coaches_Danny Miller',
#  'coaches_Danny Monk',
#  'coaches_Danny Nee',
#  'coaches_Danny Roberts',
#  'coaches_Darelle Porter',
#  'coaches_Darian DeVries',
#  'coaches_Darrell Hawkins',
#  'coaches_Darrell Hedric',
#  'coaches_Darrell Johnson',
#  'coaches_Darrell Walker',
#  'coaches_Darrin Horn',
#  'coaches_Dave Balza',
#  'coaches_Dave Benaderet',
#  'coaches_Dave Bezold',
#  'coaches_Dave Bike',
#  'coaches_Dave Bliss',
#  'coaches_Dave Bollwinkel',
#  'coaches_Dave Buss',
#  'coaches_Dave Calloway',
#  'coaches_Dave Dickerson',
#  'coaches_Dave Duke',
#  'coaches_Dave Faucher',
#  'coaches_Dave Fehte',
#  'coaches_Dave Gavitt',
#  'coaches_Dave Grube',
#  'coaches_Dave Leach',
#  'coaches_Dave Leitao',
#  'coaches_Dave Loos',
#  'coaches_Dave Magarity',
#  'coaches_Dave McMillan',
#  'coaches_Dave Odom',
#  'coaches_Dave Patton',
#  'coaches_Dave Paulsen',
#  'coaches_Dave Pilipovich',
#  'coaches_Dave Possinger',
#  'coaches_Dave Pritchett',
#  'coaches_Dave Rice',
#  'coaches_Dave Rose',
#  'coaches_Dave Schellhase',
#  'coaches_Dave Simmons',
#  'coaches_Dave Smalley',
#  'coaches_Dave Strack',
#  'coaches_Dave Wike',
#  'coaches_Dave Wojcik',
#  'coaches_Davey Whitney',
#  'coaches_David Boots',
#  'coaches_David Carter',
#  'coaches_David Cox',
#  'coaches_David Farrar',
#  'coaches_David Henderson',
#  'coaches_David Hobbs',
#  'coaches_David McLaughlin',
#  'coaches_David Padgett',
#  'coaches_David Patrick',
#  'coaches_David Reese',
#  'coaches_David Richman',
#  'coaches_David Spencer',
#  'coaches_Dean Demopoukos',
#  'coaches_Dean Ehlers',
#  'coaches_Dean Keener',
#  'coaches_Dean Smith',
#  'coaches_Dedrique Taylor',
#  'coaches_Dee Nutt',
#  'coaches_Dee Rowe',
#  'coaches_Delle Bovi',
#  'coaches_Delray Brooks',
#  'coaches_Denis Willens',
#  'coaches_Dennis Cutts',
#  'coaches_Dennis Felton',
#  'coaches_Dennis Harp',
#  'coaches_Dennis Nutt',
#  'coaches_Dennis Walling',
#  'coaches_Dennis Wolff',
#  'coaches_Denny Crum',
#  'coaches_Denny Huston',
#  'coaches_Dereck Whittenburg',
#  'coaches_Derek Allister',
#  'coaches_Derek Kellogg',
#  'coaches_Derek Thomas',
#  'coaches_Derek Thompson',
#  'coaches_Derek Waugh',
#  'coaches_Derrin Hansen',
#  'coaches_Dick Acres',
#  'coaches_Dick Baker',
#  'coaches_Dick Bennett',
#  'coaches_Dick Berg',
#  'coaches_Dick Campbell',
#  'coaches_Dick Conover',
#  'coaches_Dick Danford',
#  'coaches_Dick Davey',
#  'coaches_Dick Davis',
#  'coaches_Dick DiBiaso',
#  'coaches_Dick Edwards',
#  'coaches_Dick Fichtner',
#  'coaches_Dick Fick',
#  'coaches_Dick Garibaldi',
#  'coaches_Dick Harp',
#  'coaches_Dick Harter',
#  'coaches_Dick Hunsaker',
#  'coaches_Dick Kuchen',
#  'coaches_Dick Lien',
#  'coaches_Dick Longo',
#  'coaches_Dick McDonald',
#  'coaches_Dick Motta',
#  'coaches_Dick Parfitt',
#  'coaches_Dick Schultz',
#  'coaches_Dick Shilts',
#  'coaches_Dick Stewart',
#  'coaches_Dick Tarrant',
#  'coaches_Dick Versace',
#  'coaches_Dick Vitale',
#  'coaches_Dick Walters',
#  'coaches_Dickey Nutt',
#  'coaches_Digger Phelps',
#  'coaches_Dino Gaudio',
#  'coaches_Dobbie Lambert',
#  'coaches_Doc Carlson',
#  'coaches_Doc Hayes',
#  'coaches_Doc Sadler',
#  'coaches_Doggie Julian',
#  'coaches_Dom Perno',
#  'coaches_Dom Rosselli',
#  'coaches_Don Beasley',
#  'coaches_Don Boven',
#  'coaches_Don Casey',
#  'coaches_Don Corbett',
#  'coaches_Don DeVoe',
#  'coaches_Don Donoher',
#  'coaches_Don Doucette',
#  'coaches_Don Eddy',
#  'coaches_Don Friday',
#  'coaches_Don Harnum',
#  'coaches_Don Haskins',
#  'coaches_Don Holst',
#  'coaches_Don Kennedy',
#  'coaches_Don Knodel',
#  'coaches_Don Maestri',
#  'coaches_Don Martin',
#  'coaches_Don Monson',
#  'coaches_Don Newman',
#  'coaches_Don Ruberg',
#  'coaches_Don Sicko',
#  'coaches_Don Smith',
#  'coaches_Don Suman',
#  'coaches_Don Verlin',
#  'coaches_Don Williams',
#  'coaches_Don Wilson',
#  'coaches_Donald Feeley',
#  'coaches_Donald Warnke',
#  'coaches_Donald White',
#  'coaches_Donnie Jones',
#  'coaches_Donnie Marsh',
#  'coaches_Donnie Tyndall',
#  'coaches_Donny Daniels',
#  'coaches_Donte Jackson',
#  'coaches_Donyell Marshall',
#  'coaches_Doug Davalos',
#  'coaches_Doug Durham',
#  'coaches_Doug Noll',
#  'coaches_Doug Oliver',
#  'coaches_Doug Wojcik',
#  'coaches_Doyle Parrack',
#  'coaches_Duane Reboul',
#  'coaches_Duce Belford',
#  'coaches_Duck Dowell',
#  'coaches_Duddy Waller',
#  'coaches_Dudey Moore',
#  'coaches_Duggar Baucom',
#  'coaches_Dustin Kerns',
#  'coaches_Dusty DeStefano',
#  'coaches_Dusty May',
#  'coaches_Dutch Belnap',
#  'coaches_Dutch Lonborg',
#  'coaches_Dwayne Morrison',
#  'coaches_Dwight Freeman',
#  'coaches_Dwight Jones',
#  'coaches_Dylan Howard',
#  'coaches_E.A. Diddle',
#  'coaches_E.D. Taylor',
#  'coaches_E.W. Foy',
#  'coaches_Earl Grant',
#  'coaches_Earl Hawkins',
#  'coaches_Earl Voss',
#  'coaches_Eck Allen',
#  'coaches_Ed Badger',
#  'coaches_Ed Byhre',
#  'coaches_Ed Conlin',
#  'coaches_Ed Conroy',
#  'coaches_Ed Cooley',
#  'coaches_Ed Daniels',
#  'coaches_Ed DeChellis',
#  'coaches_Ed DeLacy',
#  'coaches_Ed Douma',
#  'coaches_Ed Goorjian',
#  'coaches_Ed Gregory',
#  'coaches_Ed Jucker',
#  'coaches_Ed McLean',
#  'coaches_Ed Meyers',
#  'coaches_Ed Murphy',
#  'coaches_Ed Schilling',
#  'coaches_Ed Stanczyk',
#  'coaches_Ed Tapscott',
#  'coaches_Ed Thompson',
#  'coaches_Ed Visscher',
#  'coaches_Eddie Biedenbach',
#  'coaches_Eddie Burke',
#  'coaches_Eddie Crawford',
#  'coaches_Eddie Fields',
#  'coaches_Eddie Fogler',
#  'coaches_Eddie Hickey',
#  'coaches_Eddie Holbrook',
#  'coaches_Eddie Jordan',
#  'coaches_Eddie McCarter',
#  'coaches_Eddie Payne',
#  'coaches_Eddie Sutton',
#  'coaches_Edgar Diddle',
#  'coaches_Edward Ashnault',
#  'coaches_Edward Donovan',
#  'coaches_Edward Joyner',
#  'coaches_Edward Martin',
#  'coaches_Edward Melvin',
#  'coaches_Edward Phelps',
#  'coaches_Eldon Miller',
#  'coaches_Ellis Johnson',
#  'coaches_Ellison Ketchum',
#  'coaches_Elmer Gross',
#  'coaches_Elmer Lampe',
#  'coaches_Elmer Ripley',
#  'coaches_Elwood Plummer',
#  'coaches_Emmet Hendricks',
#  'coaches_Emmett Davis',
#  'coaches_Emmett Lowery',
#  'coaches_Emory Luck',
#  'coaches_Eran Ganot',
#  'coaches_Eric Bridgeland',
#  'coaches_Eric Konkol',
#  'coaches_Eric Musselman',
#  'coaches_Eric Reveno',
#  'coaches_Ernest Calverley',
#  'coaches_Ernie Kent',
#  'coaches_Ernie McCoy',
#  'coaches_Ernie Nestor',
#  'coaches_Ernie Smith',
#  'coaches_Ernie Zeigler',
#  'coaches_Eugene Gibson',
#  'coaches_Eugene Harris',
#  'coaches_Eugene Lambert',
#  'coaches_Everett Case',
#  'coaches_Everett Dean',
#  'coaches_Everett Shelton',
#  'coaches_Fang Mitchell',
#  'coaches_Floyd Burdette',
#  'coaches_Floyd Millet',
#  'coaches_Floyd S. Wilson',
#  'coaches_Floyd Stahl',
#  'coaches_Flucie Stewart',
#  'coaches_Forddy Anderson',
#  'coaches_Forrest Twogood',
#  'coaches_Fran Dunphy',
#  'coaches_Fran Fraschilla',
#  'coaches_Fran McCaffery',
#  "coaches_Fran O'Hanlon",
#  'coaches_Frank Arnold',
#  'coaches_Frank Dobbs',
#  'coaches_Frank Fellows',
#  'coaches_Frank Haith',
#  'coaches_Frank Harrell',
#  'coaches_Frank Johnson',
#  'coaches_Frank Kerns',
#  'coaches_Frank La Porte',
#  'coaches_Frank Layden',
#  'coaches_Frank Martin',
#  'coaches_Frank McGuire',
#  'coaches_Frank McLaughlin',
#  'coaches_Frank Mulzoff',
#  'coaches_Frank Oftring',
#  'coaches_Frank Power',
#  'coaches_Frank Selvy',
#  'coaches_Frank Sullivan',
#  'coaches_Frank Szymanski',
#  'coaches_Frank Truitt',
#  'coaches_Frankie Allen',
#  'coaches_Fred B. Lewis',
#  'coaches_Fred Barakat',
#  'coaches_Fred Conley',
#  'coaches_Fred Enke',
#  'coaches_Fred Goodman',
#  'coaches_Fred Hill',
#  'coaches_Fred Hobdy',
#  'coaches_Fred Hoiberg',
#  'coaches_Fred J. Crowell',
#  'coaches_Fred Overton',
#  'coaches_Fred Schaus',
#  'coaches_Fred Shabel',
#  'coaches_Fred Snowden',
#  'coaches_Fred Taylor',
#  'coaches_Fred Trenkle',
#  'coaches_Freddie Goss',
#  'coaches_Frosty Cox',
#  'coaches_Fuzzy Evans',
#  'coaches_G.G. Smith',
#  'coaches_Gale Catlett',
#  'coaches_Gary Brokaw',
#  'coaches_Gary Colson',
#  'coaches_Gary Cunningham',
#  'coaches_Gary Edwards',
#  'coaches_Gary Garner',
#  'coaches_Gary Hulst',
#  'coaches_Gary McPherson',
#  'coaches_Gary Moss',
#  'coaches_Gary Stewart',
#  'coaches_Gary Thompson',
#  'coaches_Gary Walters',
#  'coaches_Gary Waters',
#  'coaches_Gary Williams',
#  'coaches_Gary Zarecky',
#  'coaches_Gene Bartow',
#  'coaches_Gene Cross',
#  'coaches_Gene Evans',
#  'coaches_Gene Iba',
#  'coaches_Gene Keady',
#  'coaches_Gene Littles',
#  'coaches_Gene Robbins',
#  'coaches_Gene Roberti',
#  'coaches_Gene Smithson',
#  'coaches_Gene Sullivan',
#  'coaches_Gene Visscher',
#  'coaches_Geno Ford',
#  'coaches_George Balanis',
#  'coaches_George Bisacca',
#  'coaches_George Blaney',
#  'coaches_George Carlisle',
#  'coaches_George Davidson',
#  'coaches_George Felton',
#  'coaches_George Fisher',
#  'coaches_George Garber',
#  'coaches_George Hanson',
#  'coaches_George Hill',
#  'coaches_George Hunter',
#  'coaches_George Ireland',
#  'coaches_George Ivory',
#  'coaches_George King',
#  'coaches_George Krajack',
#  'coaches_George McCarty',
#  'coaches_George McQuarn',
#  'coaches_George Nessman',
#  'coaches_George Pfeifer',
#  'coaches_George Raveling',
#  'coaches_George Scholz',
#  'coaches_George Smith',
#  'coaches_George Theofanis',
#  'coaches_George Wigton',
#  'coaches_Gerald Alaimo',
#  'coaches_Gerald Myers',
#  'coaches_Gerry Friel',
#  'coaches_Gerry Gerard',
#  'coaches_Gerry Gimelstob',
#  'coaches_Gib Arnold',
#  'coaches_Gib Chapman',
#  'coaches_Gil Jackson',
#  'coaches_Gil Philbrick',
#  ...]

# %%
print(df.columns)
# Out:
# Index(['w', 'l', 'wl', 'w_conf', 'l_conf', 'wl_conf', 'srs', 'sos', 'pts',
#        'pts_vs',
#        ...
#        'school_wichita-state', 'school_william-mary', 'school_winthrop',
#        'school_wisconsin', 'school_wofford', 'school_wright-state',
#        'school_wyoming', 'school_xavier', 'school_yale',
#        'school_youngstown-state'],
#       dtype='str', length=2696)

# %%
df.head()
# Out:
#     w   l     wl  w_conf  l_conf  wl_conf    srs   sos   pts  pts_vs  ...  \
# 0  27   6  0.818    14.0     4.0    0.778  -1.28 -8.10  74.5    63.1  ...
# 1  16  16  0.500     8.0    10.0    0.444  -9.14 -6.82  73.7    71.2  ...
# 2  13  16  0.448     7.0    11.0    0.389 -11.86 -7.10  69.3    71.5  ...
# 3  13  18  0.419     8.0    10.0    0.444 -13.93 -7.53  71.3    73.3  ...
# 4  10  21  0.323     4.0    14.0    0.222 -17.20 -6.34  63.7    70.5  ...
#
#    school_wichita-state  school_william-mary  school_winthrop  \
# 0                 False                False            False
# 1                 False                False            False
# 2                 False                False            False
# 3                 False                False            False
# 4                 False                False            False
#
#    school_wisconsin  school_wofford  school_wright-state  school_wyoming  \
# 0             False           False                False           False
# 1             False           False                False           False
# 2             False           False                False           False
# 3             False           False                False           False
# 4             False           False                False           False
#
#    school_xavier  school_yale  school_youngstown-state
# 0          False        False                    False
# 1          False        False                    False
# 2          False        False                    False
# 3          False        False                    False
# 4          False        False                    False
#
# [5 rows x 2696 columns]
