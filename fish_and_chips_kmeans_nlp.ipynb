# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("fish+and+chips.csv")

# Show basic info
print(df.head())
print(df.columns)
# Out:
#                                     id                    recipeName  rating  \
# 0       Classic-Fish-and-Chips-1094128        Classic Fish and Chips       4
# 1    Classic-Fish-And-Chips-Allrecipes        Classic Fish and Chips       4
# 2  Beer-Battered-Fish-and-Chips-484809  Beer Battered Fish and Chips       4
# 3               Fish-and-chips_-357942               Fish and Chips!       5
# 4                Fish-and-chips-348079                Fish and Chips       0
#
#    totalTimeInSeconds                           course           cuisine  \
# 0              3600.0                              NaN               NaN
# 1              2700.0                    [Main Dishes]               NaN
# 2              3000.0                    [Main Dishes]           [Irish]
# 3              4500.0                    [Main Dishes]               NaN
# 4                 NaN  [Lunch and Snacks, Main Dishes]  [English, Irish]
#
#                                          ingredients
# 0  [fish, salt, oil, yukon gold potatoes, self ri...
# 1  [potatoes, all-purpose flour, baking powder, s...
# 2  [vegetable oil, baking potatoes, beer, all-pur...
# 3  [russet potatoes, kosher salt, canola oil, bee...
# 4  [vegetable oil, russet potatoes, beer, all-pur...
# Index(['id', 'recipeName', 'rating', 'totalTimeInSeconds', 'course', 'cuisine',
#        'ingredients'],
#       dtype='str')

# %%
print("text" in df.columns)
# Out:
# False

# %%
print(df.columns.tolist())
# Out:
# ['id', 'recipeName', 'rating', 'totalTimeInSeconds', 'course', 'cuisine', 'ingredients']

# %%
print(type(df))
print('texts' in globals())
print('X' in globals())
# Out:
# <class 'pandas.DataFrame'>
# False
# False

# %%
df.columns.tolist()
# Out:
# ['id',
#  'recipeName',
#  'rating',
#  'totalTimeInSeconds',
#  'course',
#  'cuisine',
#  'ingredients']

# %%
df.to_csv("fish_chips_clustered.csv", index=False)
