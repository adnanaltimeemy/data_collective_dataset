# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Food_Data.csv")

# Show basic info
print(df.head())
print(df.info())
# Out:
#    Item_Id     Category         Menu_item              Store_Name  Price  \
# 0  4000197    Beverages  Macchiato Medium               Einsteins   3.79
# 1   120029     desserts    1L Smart Water           Coffee Corner   3.15
# 2   516007       snacks         Power Bar           Coffee Corner   2.49
# 3   110037  Brew Coffee       Hot Choc 16           Coffee Corner   3.20
# 4  4001978         food         S MA & CH  Coffee Store/Papa John   4.39
#
#    Sales_Qty  Gross_sales  Item_Disc  Net_Sales
# 0         53       200.87        0.0     200.87
# 1         64       201.60        0.0     201.60
# 2         82       204.18        0.0     204.18
# 3         64       204.80        0.0     204.80
# 4         47       206.33        0.0     206.33
# <class 'pandas.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Item_Id      372 non-null    int64
#  1   Category     372 non-null    str
#  2   Menu_item    372 non-null    str
#  3   Store_Name   372 non-null    str
#  4   Price        372 non-null    float64
#  5   Sales_Qty    372 non-null    int64
#  6   Gross_sales  372 non-null    float64
#  7   Item_Disc    372 non-null    float64
#  8   Net_Sales    372 non-null    float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 38.1 KB
# None

# %%
print(df.columns.tolist())
# Out:
# ['Item_Id', 'Category', 'Menu_item', 'Store_Name', 'Price', 'Sales_Qty', 'Gross_sales', 'Item_Disc', 'Net_Sales']

# %%
df.head()
# Out:
#    Item_Id     Category         Menu_item              Store_Name  Price  \
# 0  4000197    Beverages  Macchiato Medium               Einsteins   3.79
# 1   120029     desserts    1L Smart Water           Coffee Corner   3.15
# 2   516007       snacks         Power Bar           Coffee Corner   2.49
# 3   110037  Brew Coffee       Hot Choc 16           Coffee Corner   3.20
# 4  4001978         food         S MA & CH  Coffee Store/Papa John   4.39
#
#    Sales_Qty  Gross_sales  Item_Disc  Net_Sales
# 0         53       200.87        0.0     200.87
# 1         64       201.60        0.0     201.60
# 2         82       204.18        0.0     204.18
# 3         64       204.80        0.0     204.80
# 4         47       206.33        0.0     206.33

# %%
print(df.columns.tolist())
# Out:
# ['Item_Id', 'Category', 'Menu_item', 'Store_Name', 'Price', 'Sales_Qty', 'Gross_sales', 'Item_Disc', 'Net_Sales']

# %%
print(df.columns.tolist())
# Out:
# ['Item_Id', 'Category', 'Menu_item', 'Store_Name', 'Price', 'Sales_Qty', 'Gross_sales', 'Item_Disc', 'Net_Sales']

# %%
print(df.columns.tolist())
# Out:
# ['Item_Id', 'Category', 'Menu_item', 'Store_Name', 'Price', 'Sales_Qty', 'Gross_sales', 'Item_Disc', 'Net_Sales']

# %%
df.head()
# Out:
#    Item_Id     Category         Menu_item              Store_Name  Price  \
# 0  4000197    Beverages  Macchiato Medium               Einsteins   3.79
# 1   120029     desserts    1L Smart Water           Coffee Corner   3.15
# 2   516007       snacks         Power Bar           Coffee Corner   2.49
# 3   110037  Brew Coffee       Hot Choc 16           Coffee Corner   3.20
# 4  4001978         food         S MA & CH  Coffee Store/Papa John   4.39
#
#    Sales_Qty  Gross_sales  Item_Disc  Net_Sales
# 0         53       200.87        0.0     200.87
# 1         64       201.60        0.0     201.60
# 2         82       204.18        0.0     204.18
# 3         64       204.80        0.0     204.80
# 4         47       206.33        0.0     206.33

# %%
print(df.columns.tolist())
# Out:
# ['Item_Id', 'Category', 'Menu_item', 'Store_Name', 'Price', 'Sales_Qty', 'Gross_sales', 'Item_Disc', 'Net_Sales']
