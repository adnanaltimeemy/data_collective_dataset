# %%
# Data handling
import pandas as pd
import numpy as np

# NLP
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# K-means clustering
from sklearn.cluster import KMeans

# Visualization
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Download stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load CSV file
df = pd.read_csv("311_Animals_short.csv")

# Display first rows
df.head()
# Out:
#    Unique Key     Created Date Closed Date Agency  \
# 0    64345465   3/14/2025 1:20         NaN   NYPD
# 1    64349550   3/14/2025 0:44         NaN   NYPD
# 2    64342912   3/14/2025 0:25         NaN   NYPD
# 3    64344236  3/13/2025 23:33         NaN   NYPD
# 4    64344359  3/13/2025 21:52         NaN   DSNY
#
#                        Agency Name Complaint Type  Descriptor  \
# 0  New York City Police Department   Animal-Abuse   Neglected
# 1  New York City Police Department   Animal-Abuse    Tortured
# 2  New York City Police Department   Animal-Abuse  No Shelter
# 3  New York City Police Department   Animal-Abuse   Neglected
# 4         Department of Sanitation    Dead Animal         Cat
#
#                 Location Type  Incident Zip       Incident Address  ...  \
# 0  Residential Building/House       11207.0      285 COZINE AVENUE  ...
# 1  Residential Building/House       11412.0  189-04 LIBERTY AVENUE  ...
# 2        Residential Building       11421.0        87-12 86 STREET  ...
# 3  Residential Building/House       11237.0      142 WILSON AVENUE  ...
# 4                    Sidewalk       11236.0     9007 FARRAGUT ROAD  ...
#
#   Resolution Action Updated Date Community Board   Borough  \
# 0                 3/14/2025 1:59     05 BROOKLYN  BROOKLYN
# 1                            NaN       12 QUEENS    QUEENS
# 2                 3/14/2025 2:46       09 QUEENS    QUEENS
# 3                            NaN     04 BROOKLYN  BROOKLYN
# 4                3/13/2025 23:55     18 BROOKLYN  BROOKLYN
#
#   X Coordinate (State Plane) Y Coordinate (State Plane) Park Facility Name  \
# 0                  1017039.0                   178484.0        Unspecified
# 1                  1048718.0                   195665.0        Unspecified
# 2                  1023620.0                   191482.0        Unspecified
# 3                  1004894.0                   194531.0        Unspecified
# 4                  1009484.0                   173679.0        Unspecified
#
#   Park Borough   Latitude  Longitude  \
# 0     BROOKLYN  40.656513 -73.881825
# 1       QUEENS  40.703497 -73.767487
# 2       QUEENS  40.692163 -73.858031
# 3     BROOKLYN  40.700595 -73.925548
# 4     BROOKLYN  40.643349 -73.909072
#
#                                         Location
# 0   POINT (-73.88182509318824 40.65651333701598)
# 1   POINT (-73.76748678190313 40.70349714790391)
# 2   POINT (-73.85803061095832 40.69216306198625)
# 3  POINT (-73.92554773084896 40.700595346355186)
# 4   POINT (-73.90907203894598 40.64334941476116)
#
# [5 rows x 31 columns]

# %%
# Dataset information
df.info()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4969 entries, 0 to 4968
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      4969 non-null   int64
#  1   Created Date                    4969 non-null   str
#  2   Closed Date                     4692 non-null   str
#  3   Agency                          4969 non-null   str
#  4   Agency Name                     4969 non-null   str
#  5   Complaint Type                  4969 non-null   str
#  6   Descriptor                      4945 non-null   str
#  7   Location Type                   4969 non-null   str
#  8   Incident Zip                    4945 non-null   float64
#  9   Incident Address                4946 non-null   str
#  10  Street Name                     4946 non-null   str
#  11  Cross Street 1                  4933 non-null   str
#  12  Cross Street 2                  4938 non-null   str
#  13  Intersection Street 1           4933 non-null   str
#  14  Intersection Street 2           4938 non-null   str
#  15  Address Type                    4945 non-null   str
#  16  City                            4543 non-null   str
#  17  Landmark                        4542 non-null   str
#  18  Facility Type                   0 non-null      float64
#  19  Status                          4969 non-null   str
#  20  Due Date                        0 non-null      float64
#  21  Resolution Action Updated Date  4784 non-null   str
#  22  Community Board                 4969 non-null   str
#  23  Borough                         4969 non-null   str
#  24  X Coordinate (State Plane)      4907 non-null   float64
#  25  Y Coordinate (State Plane)      4907 non-null   float64
#  26  Park Facility Name              4969 non-null   str
#  27  Park Borough                    4969 non-null   str
#  28  Latitude                        4907 non-null   float64
#  29  Longitude                       4907 non-null   float64
#  30  Location                        4907 non-null   str
# dtypes: float64(7), int64(1), str(23)
# memory usage: 2.7 MB
# Unique Key                           0
# Created Date                         0
# Closed Date                        277
# Agency                               0
# Agency Name                          0
# Complaint Type                       0
# Descriptor                          24
# Location Type                        0
# Incident Zip                        24
# Incident Address                    23
# Street Name                         23
# Cross Street 1                      36
# Cross Street 2                      31
# Intersection Street 1               36
# Intersection Street 2               31
# Address Type                        24
# City                               426
# Landmark                           427
# Facility Type                     4969
# Status                               0
# Due Date                          4969
# Resolution Action Updated Date     185
# Community Board                      0
# Borough                              0
# X Coordinate (State Plane)          62
# Y Coordinate (State Plane)          62
# Park Facility Name                   0
# Park Borough                         0
# Latitude                            62
# Longitude                           62
# Location                            62
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='str')

# %%
df.to_csv(
    "311_Animals_KMeans_results.csv",
    index=False
)

print("File saved successfully")
# Out:
# File saved successfully
