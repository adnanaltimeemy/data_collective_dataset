# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("titles_after_normaliztion.csv")

df.head()
# Out:
#     type  release_year  runtime  ...     imdb_votes  tmdb_popularity  tmdb_score
# 0   SHOW          1945       51  ...   23439.382474            0.600    6.829175
# 1  MOVIE          1976      114  ...  808582.000000           40.965    8.179000
# 2  MOVIE          1972      109  ...  107673.000000           10.010    7.300000
# 3  MOVIE          1975       91  ...  534486.000000           15.461    7.811000
# 4  MOVIE          1967      150  ...   72662.000000           20.398    7.600000
#
# [5 rows x 9 columns]

# %%
print(df.info())
print(df.isnull().sum())

# Optional: fill missing values
df = df.dropna()   # or use df.fillna(...)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  5850 non-null   str
#  1   release_year          5850 non-null   int64
#  2   runtime               5850 non-null   int64
#  3   genres                5850 non-null   int64
#  4   production_countries  5850 non-null   int64
#  5   imdb_score            5850 non-null   float64
#  6   imdb_votes            5850 non-null   float64
#  7   tmdb_popularity       5850 non-null   float64
#  8   tmdb_score            5850 non-null   float64
# dtypes: float64(4), int64(4), str(1)
# memory usage: 438.0 KB
# None
# type                    0
# release_year            0
# runtime                 0
# genres                  0
# production_countries    0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['type', 'release_year', 'runtime', 'genres', 'production_countries',
#        'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['type', 'release_year', 'runtime', 'genres', 'production_countries',
#        'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['type', 'release_year', 'runtime', 'genres', 'production_countries',
#        'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['type', 'release_year', 'runtime', 'genres', 'production_countries',
#        'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='str')

# %%
for v in ["X_train", "y_train", "X_test", "y_test"]:
    print(v, v in globals())
# Out:
# X_train False
# y_train False
# X_test False
# y_test False

# %%
print(rf_model)
# Out:
# RandomForestClassifier(random_state=42)
