# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("theses.csv")

df.head()
# Out:
#   TKey    Author                                              Title  Year  \
# 0  T10  A2298360  Security-driven software evolution using a mod...  2014
# 1  T11  A1910461    Impact analysis in description logic ontologies  2014
# 2  T42  A1777265  Intelligent system based assessments of academ...  2015
# 3  T49  A1407833  Graph patterns: structure; query answering and...  2013
# 4  T65  A1291615  Autonomic behavioural framework for structural...  2015
#
#   Type                    School         Country  Pages ISBN
# 0  PhD    De Montfort University  United Kingdom    NaN  NaN
# 1  PhD  University of Manchester  United Kingdom    NaN  NaN
# 2  PhD    Aberystwyth University  United Kingdom    NaN  NaN
# 3  PhD   University of Edinburgh  United Kingdom    NaN  NaN
# 4  PhD  Robert Gordon University  United Kingdom    NaN  NaN

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (1928, 9)
# <class 'pandas.DataFrame'>
# RangeIndex: 1928 entries, 0 to 1927
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TKey     1928 non-null   str
#  1   Author   1928 non-null   str
#  2   Title    1928 non-null   str
#  3   Year     1928 non-null   int64
#  4   Type     1928 non-null   str
#  5   School   1925 non-null   str
#  6   Country  1925 non-null   str
#  7   Pages    181 non-null    float64
#  8   ISBN     69 non-null     str
# dtypes: float64(1), int64(1), str(7)
# memory usage: 374.5 KB
# None
# TKey          0
# Author        0
# Title         0
# Year          0
# Type          0
# School        3
# Country       3
# Pages      1747
# ISBN       1859
# dtype: int64

# %%
df = df.dropna()   # simple approach (you can also impute if needed)

# %%
print(df.head())
print(df.columns)
print(df.info())
# Out:
#       TKey    Author                                              Title  Year  \
# 367  T8887  A1439889  Augmenting Mathematical Formulae for More Effe...  2017
# 384  T9108  A1253462  Prediction games: machine learning in the pres...  2012
# 397  T9238   A513951  Heterogeneity in distributed embedded systems:...  2012
# 401  T9247  A1250587  Effective and Efficient Summarization of Two-D...  2019
# 439  T9776   A214399     Factorization models for multi-relational data  2014
#
#     Type                          School  Country  Pages               ISBN
# 367  PhD  Technical University of Berlin  Germany  212.0  978-3-7450-6208-3
# 384  PhD           University of Potsdam  Germany  121.0  978-3-86956-203-2
# 397  PhD      University of Braunschweig  Germany  154.0  978-3-95404-273-9
# 401  PhD           University of Bamberg  Germany  501.0  978-3-86309-672-4
# 439  PhD        University of Hildesheim  Germany  111.0  978-3-95404-734-5
# Index(['TKey', 'Author', 'Title', 'Year', 'Type', 'School', 'Country', 'Pages',
#        'ISBN'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# Index: 58 entries, 367 to 1918
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TKey     58 non-null     str
#  1   Author   58 non-null     str
#  2   Title    58 non-null     str
#  3   Year     58 non-null     int64
#  4   Type     58 non-null     str
#  5   School   58 non-null     str
#  6   Country  58 non-null     str
#  7   Pages    58 non-null     float64
#  8   ISBN     58 non-null     str
# dtypes: float64(1), int64(1), str(7)
# memory usage: 13.1 KB
# None

# %%
print(df.columns)
# Out:
# Index(['TKey', 'Author', 'Title', 'Year', 'Type', 'School', 'Country', 'Pages',
#        'ISBN'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['TKey', 'Author', 'Title', 'Year', 'Type', 'School', 'Country', 'Pages',
#        'ISBN'],
#       dtype='str')

# %%
print(df.head())
print(df.columns)
# Out:
#       TKey    Author                                              Title  Year  \
# 367  T8887  A1439889  Augmenting Mathematical Formulae for More Effe...  2017
# 384  T9108  A1253462  Prediction games: machine learning in the pres...  2012
# 397  T9238   A513951  Heterogeneity in distributed embedded systems:...  2012
# 401  T9247  A1250587  Effective and Efficient Summarization of Two-D...  2019
# 439  T9776   A214399     Factorization models for multi-relational data  2014
#
#     Type                          School  Country  Pages               ISBN
# 367  PhD  Technical University of Berlin  Germany  212.0  978-3-7450-6208-3
# 384  PhD           University of Potsdam  Germany  121.0  978-3-86956-203-2
# 397  PhD      University of Braunschweig  Germany  154.0  978-3-95404-273-9
# 401  PhD           University of Bamberg  Germany  501.0  978-3-86309-672-4
# 439  PhD        University of Hildesheim  Germany  111.0  978-3-95404-734-5
# Index(['TKey', 'Author', 'Title', 'Year', 'Type', 'School', 'Country', 'Pages',
#        'ISBN'],
#       dtype='str')
