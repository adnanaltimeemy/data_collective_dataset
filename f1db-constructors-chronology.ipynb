# %%
```python
# F1 Constructors: NLP + K-Means

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# 1. Load dataset
df = pd.read_csv("f1db-constructors-chronology.csv")

# 2. Fill missing values
df = df.fillna("")

# 3. Combine text columns
text_cols = df.select_dtypes(include="object").columns
df["text"] = df[text_cols].astype(str).agg(" ".join, axis=1)

# 4. Convert text to TF-IDF
tfidf = TfidfVectorizer(stop_words="english")
X = tfidf.fit_transform(df["text"])

# 5. K-Means clustering
k = 4
model = KMeans(n_clusters=k, random_state=42, n_init=10)
df["cluster"] = model.fit_predict(X)

# 6. Reduce dimensions for plotting
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X.toarray())

# 7. Plot clusters
plt.figure(figsize=(8, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df["cluster"])
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("F1 Constructors - K-Means Clusters")
plt.show()

# 8. Display results
print(df[["text", "cluster"]].head(20))

# 9. Save results
df.to_csv("f1db-constructors-clustered.csv", index=False)
```
# Out:
#   Cell In[1], line 1
#     ```python
#     ^
# SyntaxError: invalid syntax
