# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("owid-energy-codebook.csv")

df.head()
# Out:
#        column                         title  \
# 0     country                       Country
# 1        year                          Year
# 2    iso_code                      ISO code
# 3  population                    Population
# 4         gdp  Gross domestic product (GDP)
#
#                                          description  \
# 0                               Geographic location.
# 1                               Year of observation.
# 2     ISO 3166-1 alpha-3 three-letter country codes.
# 3  Population by country, available from 10,000 B...
# 4  Total economic output of a country or region p...
#
#                                  unit  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                              people
# 4  international-$ in 2011 prices ($)
#
#                                               source
# 0                 Our World in Data - Regions (2025)
# ...

# %%
print(df.shape)
print(df.info())
print(df.describe())

# Missing values
print(df.isnull().sum().sort_values(ascending=False).head(20))
# Out:
# (130, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   column       130 non-null    str
#  1   title        130 non-null    str
#  2   description  118 non-null    str
#  3   unit         127 non-null    str
#  4   source       130 non-null    str
# dtypes: str(5)
# memory usage: 49.2 KB
# None
#          column                             title  \
# count       130                               130
# unique      130                               126
# top     country  Annual change in coal production
# freq          1                                 2
#
#                                    description                  unit  \
# count                                      118                   127
# unique                                      30                     9
# top     Measured in kilowatt-hours per person.  terawatt-hours (TWh)
# ...

# %%
[col for col in df.columns if "co" in col.lower()]
# Out:
# ['column']

# %%
[col for col in df.columns if "co" in col.lower()]
# Out:
# ['column']

# %%
print(df.columns.tolist())
# Out:
# ['column', 'title', 'description', 'unit', 'source']

# %%
df.columns.tolist()
# Out:
# ['column', 'title', 'description', 'unit', 'source']

# %%
print(df.columns.tolist())
# Out:
# ['column', 'title', 'description', 'unit', 'source']

# %%
rf_model = RandomForestRegressor()  # new unfitted model
# (forgot to call fit again)
