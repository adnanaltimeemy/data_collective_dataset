# %%
# If needed (run once)
# !pip install pandas scikit-learn nltk matplotlib seaborn

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("coffee-flavors.csv")

# Preview data
df.head()
# Out:
#                        ids    labels parents
# 0        Enzymatic-Flowery   Flowery     NaN
# 1         Enzymatic-Fruity    Fruity     NaN
# 2          Enzymatic-Herby     Herby     NaN
# 3     Sugar Browning-Nutty     Nutty     NaN
# 4  Sugar Browning-Carmelly  Carmelly     NaN

# %%
df.columns
# Out:
# Index(['ids', 'labels', 'parents'], dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['ids', 'labels', 'parents']

# %%
df.head()
# Out:
#                        ids    labels parents
# 0        Enzymatic-Flowery   Flowery     NaN
# 1         Enzymatic-Fruity    Fruity     NaN
# 2          Enzymatic-Herby     Herby     NaN
# 3     Sugar Browning-Nutty     Nutty     NaN
# 4  Sugar Browning-Carmelly  Carmelly     NaN

# %%
print(df.columns)
# Out:
# Index(['ids', 'labels', 'parents'], dtype='str')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

documents = [
    "machine learning is fun",
    "python is great for data science",
    "kmeans clustering groups data",
]

# Create vectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# Fit and transform the documents
X = vectorizer.fit_transform(documents)

# Train KMeans
k = 2
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X)

# Get feature names
terms = vectorizer.get_feature_names_out()

# Sort cluster centers
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]

# Print top words
for i in range(k):
    print(f"\nCluster {i} top words:")
    top_terms = [terms[ind] for ind in order_centroids[i, :10]]
    print(", ".join(top_terms))
# Out:
# Cluster 0 top words:
# machine, learning, fun, science, python, great, data, kmeans, groups, clustering
#
# Cluster 1 top words:
# kmeans, groups, clustering, data, science, python, machine, learning, great, fun

# %%
terms = vectorizer.get_feature_names_out()

order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]

for i in range(k):
    print(f"\nCluster {i} top words:")
    top_terms = [terms[ind] for ind in order_centroids[i, :10]]
    print(", ".join(top_terms))
# Out:
# Cluster 0 top words:
# machine, learning, fun, science, python, great, data, kmeans, groups, clustering
#
# Cluster 1 top words:
# kmeans, groups, clustering, data, science, python, machine, learning, great, fun

# %%
print(df.columns)
# Out:
# Index(['ids', 'labels', 'parents'], dtype='str')

# %%
print(df.head())
# Out:
#                        ids    labels parents
# 0        Enzymatic-Flowery   Flowery     NaN
# 1         Enzymatic-Fruity    Fruity     NaN
# 2          Enzymatic-Herby     Herby     NaN
# 3     Sugar Browning-Nutty     Nutty     NaN
# 4  Sugar Browning-Carmelly  Carmelly     NaN
