# %%
# Data handling
import pandas as pd
import numpy as np

# NLP
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Machine learning
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# Visualisation
import matplotlib.pyplot as plt

# Download NLP resources
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load CSV file
df = pd.read_csv("qooka_dataset_v2.csv")

# Display dataset information
print(df.head())

print("\nDataset shape:")
print(df.shape)

print("\nColumns:")
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load CSV file
# ----> 2 df = pd.read_csv("qooka_dataset_v2.csv")
#       3
#       4 # Display dataset information
#       5 print(df.head())
#
# File ~/miniconda3/envs/coding/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/coding/lib/python3.12/site-packages/pandas/io/parsers/readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File ~/miniconda3/envs/coding/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File ~/miniconda3/envs/coding/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:215, in CParserWrapper.read(self, nrows)
#     213 try:
#     214     if self.low_memory:
# --> 215         chunks = self._reader.read_low_memory(nrows)
#     216         # destructive to chunks
#     217         data = _concatenate_chunks(chunks, self.names)
#
# File pandas/_libs/parsers.pyx:832, in pandas._libs.parsers.TextReader.read_low_memory()
# --> 832 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:897, in pandas._libs.parsers.TextReader._read_rows()
# --> 897 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:868, in pandas._libs.parsers.TextReader._tokenize_rows()
# --> 868 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:885, in pandas._libs.parsers.TextReader._check_tokenize_status()
# --> 885 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:2084, in pandas._libs.parsers.raise_parser_error()
# -> 2084 'Could not get source, probably due dynamically evaluated source code.'
#
# ParserError: Error tokenizing data. C error: Expected 9 fields in line 4, saw 12

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
# Find columns containing text data
text_columns = df.select_dtypes(include=['object']).columns

print("Text columns found:")
print(text_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Find columns containing text data
# ----> 2 text_columns = df.select_dtypes(include=['object']).columns
#       3
#       4 print("Text columns found:")
#       5 print(text_columns)
#
# NameError: name 'df' is not defined

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()


def clean_text(text):
    text = str(text).lower()

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove punctuation and numbers
    text = re.sub(r'[^a-z\s]', '', text)

    # Tokenisation
    words = text.split()

    # Remove stopwords and lemmatise
    words = [
        lemmatizer.lemmatize(word)
        for word in words
        if word not in stop_words
    ]

    return " ".join(words)


df['clean_text'] = df[text_column].apply(clean_text)

df[['clean_text']].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 27
#      23
#      24     return " ".join(words)
#      25
#      26
# ---> 27 df['clean_text'] = df[text_column].apply(clean_text)
#      28
#      29 df[['clean_text']].head()
#
# NameError: name 'df' is not defined

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1,2)
)

X = tfidf.fit_transform(df['clean_text'])

print("TF-IDF shape:")
print(X.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       2     max_features=5000,
#       3     ngram_range=(1,2)
#       4 )
#       5
# ----> 6 X = tfidf.fit_transform(df['clean_text'])
#       7
#       8 print("TF-IDF shape:")
#       9 print(X.shape)
#
# NameError: name 'df' is not defined

# %%
scores = []

K_range = range(2,11)

for k in K_range:
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    labels = kmeans.fit_predict(X)

    score = silhouette_score(X, labels)
    scores.append(score)


plt.figure(figsize=(8,5))
plt.plot(K_range, scores, marker='o')
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette score")
plt.title("Finding optimal K")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       8         random_state=42,
#       9         n_init=10
#      10     )
#      11
# ---> 12     labels = kmeans.fit_predict(X)
#      13
#      14     score = silhouette_score(X, labels)
#      15     scores.append(score)
#
# NameError: name 'X' is not defined

# %%
optimal_k = 5

kmeans = KMeans(
    n_clusters=optimal_k,
    random_state=42,
    n_init=10
)

df['cluster'] = kmeans.fit_predict(X)

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       5     random_state=42,
#       6     n_init=10
#       7 )
#       8
# ----> 9 df['cluster'] = kmeans.fit_predict(X)
#      10
#      11 df.head()
#
# NameError: name 'X' is not defined

# %%
df.to_csv(
    "qooka_dataset_v2_clustered.csv",
    index=False
)

print("Saved successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.to_csv(
#       2     "qooka_dataset_v2_clustered.csv",
#       3     index=False
#       4 )
#
# NameError: name 'df' is not defined
