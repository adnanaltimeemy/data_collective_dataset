# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("dataset2.csv")

print(df.head())
print(df.info())
# Out:
#    idResource  aggregateCategory
# 0       66445                  5
# 1       66446                  5
# 2       66447                  5
# 3       66448                  5
# 4       66451                  5
# <class 'pandas.DataFrame'>
# RangeIndex: 28961 entries, 0 to 28960
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idResource         28961 non-null  int64
#  1   aggregateCategory  28961 non-null  int64
# dtypes: int64(2)
# memory usage: 452.6 KB
# None

# %%
# Drop missing values (simple approach)
df = df.dropna()

# If you have categorical columns, encode them
label_encoders = {}

for col in df.select_dtypes(include=["object"]).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
df.columns = df.columns.str.strip()

# %%
print(df.head())
# Out:
#    idResource  aggregateCategory
# 0       66445                  5
# 1       66446                  5
# 2       66447                  5
# 3       66448                  5
# 4       66451                  5

# %%
df.head()
df.columns
# Out:
# Index(['idResource', 'aggregateCategory'], dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['idResource', 'aggregateCategory'], dtype='str')

# %%
df.head()
# Out:
#    idResource  aggregateCategory
# 0       66445                  5
# 1       66446                  5
# 2       66447                  5
# 3       66448                  5
# 4       66451                  5
