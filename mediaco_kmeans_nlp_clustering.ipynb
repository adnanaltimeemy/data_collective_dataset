# %%
import pandas as pd
import numpy as np

import re
import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mediaco_data_warehouse_1024.csv")

df.head()
# Out:
#                                                input  \
# 0  What was the song that stayed on the Top100 th...
# 1                  What awards has Edgar Wright won?
# 2       Can you tell me the headline news for today?
# 3   Where can I listen to the latest album by Adele?
# 4  I'm looking for a book by Haruki Murakami that...
#
#                                               output  \
# 0  TVC: Breaking Bad is a critically acclaimed TV...
# 1  ReMaster: Edgar Wright is a British filmmaker ...
# 2  Web: The current headline news today includes ...
# 3  BookWorm: There is no book by Adele in our rec...
# 4  BookWorm: First Person Singular is a novel by ...
#
#                                         ground_truth  label  \
# 0                                      Old Town Road  False
# 1  Edgar Wright has won several awards including ...  False
# 2  Global diplomatic tensions, economic updates, ...   True
# 3                 Spotify, Apple Music, Amazon Music  False
# 4       First Person Singular was published in 2020.  False
#
#                                      label_rationale
# 0  The output is incorrect because it talks about...
# 1  The output does not address the awards won by ...
# 2  The response from the Web agent covers the sam...
# 3  The response does not address the query proper...
# 4  The output states that the book was published ...

# %%
df.columns
# Out:
# Index(['input', 'output', 'ground_truth', 'label', 'label_rationale'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['input', 'output', 'ground_truth', 'label', 'label_rationale'], dtype='str')

# %%
df.head()
df.dtypes
# Out:
# input               str
# output              str
# ground_truth        str
# label              bool
# label_rationale     str
# dtype: object

# %%
print(type(X))
print(X[:5])
# Out:
# <class 'numpy.ndarray'>
# [['What was the song that stayed on the Top100 the longest?'
#   'TVC: Breaking Bad is a critically acclaimed TV show.' 'Old Town Road'
#   False
#   "The output is incorrect because it talks about a TV show instead of providing information about the song 'Old Town Road' that stayed on the Top100 for the longest."]
#  ['What awards has Edgar Wright won?'
#   'ReMaster: Edgar Wright is a British filmmaker known for his movies like Shaun of the Dead.'
#   'Edgar Wright has won several awards including the Empire Award for Best Director and the British Independent Film Award for Best Director.'
#   False
#   'The output does not address the awards won by Edgar Wright and instead provides information about his work, making it a clear contradiction.']
#  ['Can you tell me the headline news for today?'
#   'Web: The current headline news today includes global diplomatic tensions, economic updates, and the latest sports results.'
#   'Global diplomatic tensions, economic updates, latest sports results'
#   True
#   'The response from the Web agent covers the same topics as the ground truth, hence they are aligned and accurate.']
#  ['Where can I listen to the latest album by Adele?'
#   'BookWorm: There is no book by Adele in our records.'
#   'Spotify, Apple Music, Amazon Music' False
#   "The response does not address the query properly. Instead of addressing where Adele's latest album can be listened to, it incorrectly states that there is no book by Adele. Therefore, it contradicts the expected response."]
#  ["I'm looking for a book by Haruki Murakami that was published in 2020."
#   'BookWorm: First Person Singular is a novel by Haruki Murakami that was published in 2017.'
#   'First Person Singular was published in 2020.' False
#   'The output states that the book was published in 2017, which contradicts the ground truth that it was published in 2020.']]

# %%
print(type(X))
# Out:
# <class 'numpy.ndarray'>

# %%
print(df.shape)
print(df.dtypes)
print(df.head())
# Out:
# (1024, 5)
# input               str
# output              str
# ground_truth        str
# label              bool
# label_rationale     str
# dtype: object
#                                                input  \
# 0  What was the song that stayed on the Top100 th...
# 1                  What awards has Edgar Wright won?
# 2       Can you tell me the headline news for today?
# 3   Where can I listen to the latest album by Adele?
# 4  I'm looking for a book by Haruki Murakami that...
#
#                                               output  \
# 0  TVC: Breaking Bad is a critically acclaimed TV...
# 1  ReMaster: Edgar Wright is a British filmmaker ...
# 2  Web: The current headline news today includes ...
# 3  BookWorm: There is no book by Adele in our rec...
# 4  BookWorm: First Person Singular is a novel by ...
#
#                                         ground_truth  label  \
# 0                                      Old Town Road  False
# 1  Edgar Wright has won several awards including ...  False
# 2  Global diplomatic tensions, economic updates, ...   True
# 3                 Spotify, Apple Music, Amazon Music  False
# 4       First Person Singular was published in 2020.  False
#
#                                      label_rationale
# 0  The output is incorrect because it talks about...
# 1  The output does not address the awards won by ...
# 2  The response from the Web agent covers the sam...
# 3  The response does not address the query proper...
# 4  The output states that the book was published ...
