# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("FuelEfficiency.csv")

# View basic info
print(df.head())
print(df.info())
print(df.describe())
# Out:
#     MPG    GPM     WT  DIS  NC   HP   ACC  ET
# 0  16.9  5.917  4.360  350   8  155  14.9   1
# 1  15.5  6.452  4.054  351   8  142  14.3   1
# 2  19.2  5.208  3.605  267   8  125  15.0   1
# 3  18.5  5.405  3.940  360   8  150  13.0   1
# 4  30.0  3.333  2.155   98   4   68  16.5   0
# <class 'pandas.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MPG     38 non-null     float64
#  1   GPM     38 non-null     float64
#  2   WT      38 non-null     float64
#  3   DIS     38 non-null     int64
#  4   NC      38 non-null     int64
#  5   HP      38 non-null     int64
#  6   ACC     38 non-null     float64
#  7   ET      38 non-null     int64
# dtypes: float64(4), int64(4)
# memory usage: 2.5 KB
# None
#              MPG        GPM         WT         DIS         NC          HP  \
# count  38.000000  38.000000  38.000000   38.000000  38.000000   38.000000
# ...

# %%
# Check missing values
print(df.isnull().sum())

# Option 1: Drop missing values (simple approach)
df = df.dropna()
# Out:
# MPG    0
# GPM    0
# WT     0
# DIS    0
# NC     0
# HP     0
# ACC    0
# ET     0
# dtype: int64

# %%
print(df.shape)
print(df.columns)
# Out:
# (38, 8)
# Index(['MPG', 'GPM', 'WT', 'DIS', 'NC', 'HP', 'ACC', 'ET'], dtype='str')

# %%
print("X" in globals())
print("y" in globals())
# Out:
# False
# False

# %%
print(df.columns.tolist())
# Out:
# ['MPG', 'GPM', 'WT', 'DIS', 'NC', 'HP', 'ACC', 'ET']

# %%
print("X" in globals())
print("y" in globals())
print("X_train" in globals())
print("y_train" in globals())
# Out:
# False
# False
# False
# False

# %%
print(df.columns.tolist())
# Out:
# ['MPG', 'GPM', 'WT', 'DIS', 'NC', 'HP', 'ACC', 'ET']

# %%
for var in ["X", "y", "X_train", "X_test", "y_train", "y_test", "dt_preds", "rf_preds"]:
    print(var, var in globals())
# Out:
# X False
# y False
# X_train False
# X_test False
# y_train False
# y_test False
# dt_preds False
# rf_preds False
