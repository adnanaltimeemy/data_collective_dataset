# %%
# Install required libraries (run once if needed)
# !pip install pandas numpy scikit-learn nltk matplotlib seaborn wordcloud
# Out:
# Requirement already satisfied: pandas in ./miniconda3/envs/coding/lib/python3.12/site-packages (3.0.5)
# Requirement already satisfied: numpy in ./miniconda3/envs/coding/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: scikit-learn in ./miniconda3/envs/coding/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: nltk in ./miniconda3/envs/coding/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: matplotlib in ./miniconda3/envs/coding/lib/python3.12/site-packages (3.11.1)
# Requirement already satisfied: seaborn in ./miniconda3/envs/coding/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: wordcloud in ./miniconda3/envs/coding/lib/python3.12/site-packages (1.9.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click in ./miniconda3/envs/coding/lib/python3.12/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from nltk) (2025.10.23)
# Requirement already satisfied: tqdm in ./miniconda3/envs/coding/lib/python3.12/site-packages (from nltk) (4.68.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in ./miniconda3/envs/coding/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

import nltk
import re

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt
import seaborn as sns

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "import pandas as pd\nimport numpy as np\n\nimport nltk\nimport re\n\nfrom nltk.corpus import stopwords\nfrom nltk.stem import WordNetLemmatizer\n\nfrom sklearn.feature_extraction.text import TfidfVectorizer\nfrom sklearn.cluster import KMeans\nfrom sklearn.decomposition import PCA\nfrom sklearn.metrics import silhouette_score\n\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\nnltk.download('stopwords')\nnltk.download('wordnet')\nnltk.download('punkt')",
#   '# Load CSV file\ndf = pd.read_csv("qooka_dataset.csv")\n\n# Display dataset information\ndf.head()',
#   '# Check columns\ndf.info()',
#   'df = pd.read_csv(\n    "qooka_dataset.csv",\n    engine="python",\n    on_bad_lines="warn"\n)',
#   'with open("qooka_dataset.csv", "r", encoding="utf-8") as f:\n    for _ in range(10):\n        print(f.readline())',
#   '# Check columns\ndf.info()',
#   '# Find text columns\ntext_columns = df.select_dtypes(include=[\'object\']).columns\n\nprint("Text columns:", text_columns)',
#   'data.info()',
#   'locals()'],
#  '_oh': {1: True},
#  '_dh': [PosixPath('/Users/adnanaltimeemy')],
#  'In': ['',
#   "import pandas as pd\nimport numpy as np\n\nimport nltk\nimport re\n\nfrom nltk.corpus import stopwords\nfrom nltk.stem import WordNetLemmatizer\n\nfrom sklearn.feature_extraction.text import TfidfVectorizer\nfrom sklearn.cluster import KMeans\nfrom sklearn.decomposition import PCA\nfrom sklearn.metrics import silhouette_score\n\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\nnltk.download('stopwords')\nnltk.download('wordnet')\nnltk.download('punkt')",
#   '# Load CSV file\ndf = pd.read_csv("qooka_dataset.csv")\n\n# Display dataset information\ndf.head()',
#   '# Check columns\ndf.info()',
#   'df = pd.read_csv(\n    "qooka_dataset.csv",\n    engine="python",\n    on_bad_lines="warn"\n)',
#   'with open("qooka_dataset.csv", "r", encoding="utf-8") as f:\n    for _ in range(10):\n        print(f.readline())',
#   '# Check columns\ndf.info()',
#   '# Find text columns\ntext_columns = df.select_dtypes(include=[\'object\']).columns\n\nprint("Text columns:", text_columns)',
#   'data.info()',
#   'locals()'],
#  'Out': {1: True},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10522f740>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1053a74a0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1053a74a0>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': 9,
#  '__': '',
#  '___': '',
#  '__session__': '/Users/adnanaltimeemy/Untitled23.ipynb',
#  '_i': 'data.info()',
#  '_ii': '# Find text columns\ntext_columns = df.select_dtypes(include=[\'object\']).columns\n\nprint("Text columns:", text_columns)',
#  '_iii': '# Check columns\ndf.info()',
#  '_i1': "import pandas as pd\nimport numpy as np\n\nimport nltk\nimport re\n\nfrom nltk.corpus import stopwords\nfrom nltk.stem import WordNetLemmatizer\n\nfrom sklearn.feature_extraction.text import TfidfVectorizer\nfrom sklearn.cluster import KMeans\nfrom sklearn.decomposition import PCA\nfrom sklearn.metrics import silhouette_score\n\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\nnltk.download('stopwords')\nnltk.download('wordnet')\nnltk.download('punkt')",
#  'pd': <module 'pandas' from '/Users/adnanaltimeemy/miniconda3/envs/coding/lib/python3.12/site-packages/pandas/__init__.py'>,
#  'np': <module 'numpy' from '/Users/adnanaltimeemy/miniconda3/envs/coding/lib/python3.12/site-packages/numpy/__init__.py'>,
#  'nltk': <module 'nltk' from '/Users/adnanaltimeemy/miniconda3/envs/coding/lib/python3.12/site-packages/nltk/__init__.py'>,
#  're': <module 're' from '/Users/adnanaltimeemy/miniconda3/envs/coding/lib/python3.12/re/__init__.py'>,
#  'stopwords': <WordListCorpusReader in '.../corpora/stopwords' (not loaded yet)>,
#  'WordNetLemmatizer': nltk.stem.wordnet.WordNetLemmatizer,
#  'TfidfVectorizer': sklearn.feature_extraction.text.TfidfVectorizer,
#  'KMeans': sklearn.cluster._kmeans.KMeans,
#  'PCA': sklearn.decomposition._pca.PCA,
#  'silhouette_score': <function sklearn.metrics.cluster._unsupervised.silhouette_score(X, labels, *, metric='euclidean', sample_size=None, random_state=None, **kwds)>,
#  'plt': <module 'matplotlib.pyplot' from '/Users/adnanaltimeemy/miniconda3/envs/coding/lib/python3.12/site-packages/matplotlib/pyplot.py'>,
#  'sns': <module 'seaborn' from '/Users/adnanaltimeemy/miniconda3/envs/coding/lib/python3.12/site-packages/seaborn/__init__.py'>,
#  '_1': True,
#  '_i2': '# Load CSV file\ndf = pd.read_csv("qooka_dataset.csv")\n\n# Display dataset information\ndf.head()',
#  '_i3': '# Check columns\ndf.info()',
#  '_i4': 'df = pd.read_csv(\n    "qooka_dataset.csv",\n    engine="python",\n    on_bad_lines="warn"\n)',
#  '_i5': 'with open("qooka_dataset.csv", "r", encoding="utf-8") as f:\n    for _ in range(10):\n        print(f.readline())',
#  'f': <_io.TextIOWrapper name='qooka_dataset.csv' mode='r' encoding='utf-8'>,
#  '_i6': '# Check columns\ndf.info()',
#  '_i7': '# Find text columns\ntext_columns = df.select_dtypes(include=[\'object\']).columns\n\nprint("Text columns:", text_columns)',
#  '_i8': 'data.info()',
#  '_i9': 'locals()'}

# %%
df.head()
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.head()
#       2 df.info()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
clustered_df.to_csv(
    "qooka_dataset_clustered.csv",
    index=False
)

print("Saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 clustered_df.to_csv(
#       2     "qooka_dataset_clustered.csv",
#       3     index=False
#       4 )
#
# NameError: name 'clustered_df' is not defined
