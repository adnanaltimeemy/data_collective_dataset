# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load dataset
file_path = 'can_lang.csv'
df = pd.read_csv(file_path)

# Display first 5 rows
print(df.head())
# Out:
#                                   category                        language  \
# 0                     Aboriginal languages    Aboriginal languages, n.o.s.
# 1  Non-Official & Non-Aboriginal languages                       Afrikaans
# 2  Non-Official & Non-Aboriginal languages  Afro-Asiatic languages, n.i.e.
# 3  Non-Official & Non-Aboriginal languages                      Akan (Twi)
# 4  Non-Official & Non-Aboriginal languages                        Albanian
#
#    mother_tongue  most_at_home  most_at_work  lang_known
# 0            590           235            30         665
# 1          10260          4785            85       23415
# 2           1150           445            10        2775
# 3          13460          5985            25       22150
# 4          26895         13135           345       31930

# %%
# Check column names
print(df.columns)

# Dataset information
print(df.info())

# Missing values
print(df.isnull().sum())
# Out:
# Index(['category', 'language', 'mother_tongue', 'most_at_home', 'most_at_work',
#        'lang_known'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       214 non-null    str
#  1   language       214 non-null    str
#  2   mother_tongue  214 non-null    int64
#  3   most_at_home   214 non-null    int64
#  4   most_at_work   214 non-null    int64
#  5   lang_known     214 non-null    int64
# dtypes: int64(4), str(2)
# memory usage: 19.6 KB
# None
# category         0
# language         0
# mother_tongue    0
# most_at_home     0
# most_at_work     0
# lang_known       0
# dtype: int64

# %%
print(df.head())
# Out:
#                                   category                        language  \
# 0                     Aboriginal languages    Aboriginal languages, n.o.s.
# 1  Non-Official & Non-Aboriginal languages                       Afrikaans
# 2  Non-Official & Non-Aboriginal languages  Afro-Asiatic languages, n.i.e.
# 3  Non-Official & Non-Aboriginal languages                      Akan (Twi)
# 4  Non-Official & Non-Aboriginal languages                        Albanian
#
#    mother_tongue  most_at_home  most_at_work  lang_known
# 0            590           235            30         665
# 1          10260          4785            85       23415
# 2           1150           445            10        2775
# 3          13460          5985            25       22150
# 4          26895         13135           345       31930

# %%
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Example text data
texts = pd.Series([
    "Hello World! This is NLP.",
    "Python is great for text processing."
])

# Stopwords
stop_words = set(stopwords.words('english'))

def clean_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenization
    tokens = word_tokenize(text)

    # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]

    return ' '.join(tokens)

# Apply cleaning
cleaned_texts = texts.apply(clean_text)

print(cleaned_texts.head())
# Out:
# 0                 hello world nlp
# 1    python great text processing
# dtype: str

# %%
vectorizer = TfidfVectorizer(max_features=1000)
X = vectorizer.fit_transform(cleaned_texts)

print(X.shape)
# Out:
# (2, 7)

# %%
print(X)
print(X.shape)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 7 stored elements and shape (2, 7)>
#   Coords	Values
#   (0, 1)	0.5773502691896257
#   (0, 6)	0.5773502691896257
#   (0, 2)	0.5773502691896257
#   (1, 4)	0.5
#   (1, 0)	0.5
#   (1, 5)	0.5
#   (1, 3)	0.5
# (2, 7)

# %%
print(df.head())
# Out:
#                                   category                        language  \
# 0                     Aboriginal languages    Aboriginal languages, n.o.s.
# 1  Non-Official & Non-Aboriginal languages                       Afrikaans
# 2  Non-Official & Non-Aboriginal languages  Afro-Asiatic languages, n.i.e.
# 3  Non-Official & Non-Aboriginal languages                      Akan (Twi)
# 4  Non-Official & Non-Aboriginal languages                        Albanian
#
#    mother_tongue  most_at_home  most_at_work  lang_known
# 0            590           235            30         665
# 1          10260          4785            85       23415
# 2           1150           445            10        2775
# 3          13460          5985            25       22150
# 4          26895         13135           345       31930

# %%
print(len(clusters))
print(len(df))
# Out:
# 2
# 214

# %%
for i in range(len(kmeans.cluster_centers_)):
    print(f'\nCluster {i} Top Words:')

    center_terms = kmeans.cluster_centers_[i]
    top_indices = center_terms.argsort()[-10:][::-1]

    top_words = [terms[index] for index in top_indices]
    print(top_words)
# Out:
# Cluster 0 Top Words:
# ['world', 'nlp', 'hello', 'text', 'python', 'processing', 'great']
#
# Cluster 1 Top Words:
# ['text', 'python', 'processing', 'great', 'world', 'nlp', 'hello']

# %%
output_file = 'clustered_can_lang.csv'
df.to_csv(output_file, index=False)

print('Clustered dataset saved successfully!')
# Out:
# Clustered dataset saved successfully!
