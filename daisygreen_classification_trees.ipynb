# %%
# If needed (run once)
# !pip install pandas scikit-learn matplotlib seaborn

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV file
df = pd.read_csv("Daisygreen.csv")

# Preview data
df.head()
# Out:
#          site        lat       lng       zip  \
# 0  DaisyGreen  51.525739 -0.141429   NW1 3FG
# 1  DaisyGreen  51.518813 -0.180256    W2 6DS
# 2  DaisyGreen  51.515818 -0.081628  EC2M 1GT
# 3  DaisyGreen        NaN       NaN   NW8 7AS
# 4  DaisyGreen        NaN       NaN   TW9 1TH
#
#                                       name  \
# 0           BEANY | GREEN - REGENT’S PLACE
# 1  DARCIE & MAY | GREEN  GRAND UNION CANAL
# 2                           PARADISE GREEN
# 3                             JOHNNY GREEN
# 4            PEGGY JEAN AT RIVERSIDE GREEN
#
#                                              address         phone  email  web
# 0            25 Brock Street, Regent’s Place NW1 3FG  2.073879e+09    NaN  NaN
# 1          Sheldon Square, Paddington Central W2 6DS  2.035980e+09    NaN  NaN
# 2   Paradise Green, 100 Bishopsgate, London EC2M 1GT  2.035980e+09    NaN  NaN
# 3  Johnny Green, Henry House, 87 Allitsen Rd, Lon...  2.035980e+09    NaN  NaN
# 4  The Boat, Bridge Boathouses, Riverside, Richmo...  2.035980e+09    NaN  NaN

# %%
print("Shape:", df.shape)
print("\nColumns:\n", df.columns)
print("\nMissing values:\n", df.isnull().sum())

df.describe()
# Out:
# Shape: (14, 9)
#
# Columns:
#  Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')
#
# Missing values:
#  site        0
# lat         2
# lng         2
# zip         0
# name        0
# address     0
# phone       1
# email      14
# web        13
# dtype: int64
#              lat        lng         phone  email
# count  12.000000  12.000000  1.300000e+01    0.0
# mean   51.515030  -0.137241  2.045568e+09    NaN
# std     0.007314   0.035771  1.622677e+07    NaN
# min    51.497837  -0.182251  2.030197e+09    NaN
# 25%    51.513886  -0.164552  2.035980e+09    NaN
# 50%    51.516755  -0.141391  2.036532e+09    NaN
# 75%    51.518866  -0.111860  2.045129e+09    NaN
# max    51.525739  -0.081628  2.073879e+09    NaN

# %%
# Drop missing rows (simple approach)
df = df.dropna()

# If dataset has categorical variables, convert them:
df = pd.get_dummies(df, drop_first=True)

df.head()
# Out:
# Empty DataFrame
# Columns: [lat, lng, phone, email]
# Index: []

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [lat, lng, phone, email]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     0 non-null      float64
#  1   lng     0 non-null      float64
#  2   phone   0 non-null      float64
#  3   email   0 non-null      float64
# dtypes: float64(4)
# memory usage: 132.0 bytes

# %%
df.columns
df.head()
# Out:
# Empty DataFrame
# Columns: [lat, lng, phone, email]
# Index: []

# %%
print(df.columns)
# Out:
# Index(['lat', 'lng', 'phone', 'email'], dtype='str')

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [lat, lng, phone, email]
# Index: []

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [lat, lng, phone, email]
# Index: []
