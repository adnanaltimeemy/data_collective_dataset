# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("house_links.csv")

df.head()
# Out:
#    Unnamed: 0                                               link
# 0           0  b'toronto-on-real-estate/6136914-1303-38-grenv...
# 1           1  b'toronto-on-real-estate/6242813-2-cabot-crt-t...
# 2           2  b'toronto-on-real-estate/6262833-1504-30-roeha...
# 3           3  b'toronto-on-real-estate/6273642-514-65-east-l...
# 4           4  b'toronto-on-real-estate/6281657-61-twelfth-st...

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (17544, 2)
# <class 'pandas.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  17544 non-null  int64
#  1   link        17544 non-null  str
# dtypes: int64(1), str(1)
# memory usage: 1.5 MB
# None
# Unnamed: 0    0
# link          0
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'link']

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#    Unnamed: 0                                               link
# 0           0  b'toronto-on-real-estate/6136914-1303-38-grenv...
# 1           1  b'toronto-on-real-estate/6242813-2-cabot-crt-t...
# 2           2  b'toronto-on-real-estate/6262833-1504-30-roeha...
# 3           3  b'toronto-on-real-estate/6273642-514-65-east-l...
# 4           4  b'toronto-on-real-estate/6281657-61-twelfth-st...
# ['Unnamed: 0', 'link']

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'link']

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'link']

# %%
rf_model = Pipeline(steps=[
    ("model", RandomForestRegressor(
        n_estimators=200,
        random_state=42,
        n_jobs=-1
    ))
])
