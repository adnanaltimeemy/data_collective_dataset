# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Beefeater.csv")

# Preview data
df.head()
# Out:
#         site  ...                                                web
# 0  Beefeater  ...  https://www.beefeater.co.uk/en-gb/locations/wo...
# 1  Beefeater  ...  https://www.beefeater.co.uk/en-gb/locations/po...
# 2  Beefeater  ...  https://www.beefeater.co.uk/en-gb/locations/ha...
# 3  Beefeater  ...  https://www.beefeater.co.uk/en-gb/locations/gl...
# 4  Beefeater  ...  https://www.beefeater.co.uk/en-gb/locations/we...
#
# [5 rows x 9 columns]

# %%
# Check structure
print(df.info())

# Check missing values
print(df.isnull().sum())

# Drop rows with missing values (simple approach)
df = df.dropna()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   site     175 non-null    str
#  1   lat      175 non-null    float64
#  2   lng      175 non-null    float64
#  3   zip      175 non-null    str
#  4   name     175 non-null    str
#  5   address  175 non-null    str
#  6   phone    0 non-null      float64
#  7   email    0 non-null      float64
#  8   web      175 non-null    str
# dtypes: float64(4), str(5)
# memory usage: 37.0 KB
# None
# site         0
# lat          0
# lng          0
# zip          0
# name         0
# address      0
# phone      175
# email      175
# web          0
# dtype: int64

# %%
target_column = "target"

if target_column in df.columns:
    X = df.drop(columns=[target_column])
    y = df[target_column]
else:
    print("Available columns:", df.columns)
# Out:
# Available columns: Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
print(df.columns)
print(type(df))
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')
# <class 'pandas.DataFrame'>

# %%
print(locals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'LabelEncoder', 'DecisionTreeClassifier', 'RandomForestClassifier', 'accuracy_score', 'classification_report', 'confusion_matrix', '_i2', 'df', '_2', '_i3', '_i4', 'target_column', '_i5', '_i6', '_i7', '_i8'])

# %%
"target"
# Out:
# 'target'

# %%
for col in df.columns:
    print(col)
# Out:
# site
# lat
# lng
# zip
# name
# address
# phone
# email
# web

# %%
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')
