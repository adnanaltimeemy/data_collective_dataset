# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Minard_temp.csv")

# Quick look
print(df.head())
print(df.info())
# Out:
#    Unnamed: 0  long  temp  days   date
# 0           1  37.6     0     6  Oct18
# 1           2  36.0     0     6  Oct24
# 2           3  33.2    -9    16  Nov09
# 3           4  32.0   -21     5  Nov14
# 4           5  29.2   -11    10    NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9 non-null      int64
#  1   long        9 non-null      float64
#  2   temp        9 non-null      int64
#  3   days        9 non-null      int64
#  4   date        8 non-null      str
# dtypes: float64(1), int64(3), str(1)
# memory usage: 534.0 bytes
# None

# %%
# Drop missing values (simple approach)
df = df.dropna()

# Check again
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# long          0
# temp          0
# days          0
# date          0
# dtype: int64

# %%
df = df.copy()
df.columns = df.columns.str.strip()

target_column = "Temp"

if target_column in df.columns:
    X = df.drop(columns=[target_column])
    y = df[target_column]
else:
    print("Column not found. Available columns:", df.columns)
# Out:
# Column not found. Available columns: Index(['Unnamed: 0', 'long', 'temp', 'days', 'date'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'long', 'temp', 'days', 'date'], dtype='str')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'long', 'temp', 'days', 'date'], dtype='str')

# %%
print(locals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'DecisionTreeRegressor', 'RandomForestRegressor', 'mean_squared_error', 'r2_score', 'plt', '_i2', 'df', '_i3', '_i4', 'target_column', '_i5', '_i6', '_i7', '_i8', '_i9', '_i10', '_i11', '_11', '_i12', '_i13'])

# %%
'y_test' in globals()
# Out:
# False

# %%
'y_test' in globals()
# Out:
# False
