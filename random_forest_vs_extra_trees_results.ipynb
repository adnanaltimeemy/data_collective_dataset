# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Load CSV
df = pd.read_csv("results.csv")

# View first rows
df.head()
# Out:
#             state state_abbreviation  ... votes  fraction_votes
# 0        Arkansas                 AR  ...  1004           0.298
# 1        Virginia                 VA  ...   232           0.064
# 2       Wisconsin                 WI  ...  2577           0.513
# 3        Illinois                 IL  ...   609           0.501
# 4  North Carolina                 NC  ...  2125           0.084
#
# [5 rows x 8 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (100, 8)
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               100 non-null    str
#  1   state_abbreviation  100 non-null    str
#  2   county              100 non-null    str
#  3   fips                100 non-null    int64
#  4   party               100 non-null    str
#  5   candidate           100 non-null    str
#  6   votes               100 non-null    int64
#  7   fraction_votes      100 non-null    float64
# dtypes: float64(1), int64(2), str(5)
# memory usage: 10.1 KB
# None
#                fips         votes  fraction_votes
# count    100.000000    100.000000      100.000000
# mean   30877.840000   1739.900000        0.352098
# std    14825.431206   2910.995159        0.234958
# min     1027.000000      0.000000        0.000000
# 25%    19088.000000    189.500000        0.110750
# 50%    30035.000000    724.500000        0.346000
# 75%    46033.500000   1929.250000        0.533750
# max    55083.000000  19993.000000        0.877000

# %%
num_fill = df.select_dtypes(include=np.number).median()
cat_cols = df.select_dtypes(include=['object', 'string']).columns

cat_fill = {
    col: df[col].mode(dropna=True)[0] if not df[col].mode(dropna=True).empty else "Missing"
    for col in cat_cols
}

df = df.fillna({**num_fill.to_dict(), **cat_fill})

# %%
for col in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
print(df.columns)
# Out:
# Index(['state', 'state_abbreviation', 'county', 'fips', 'party', 'candidate',
#        'votes', 'fraction_votes'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['state', 'state_abbreviation', 'county', 'fips', 'party', 'candidate',
#        'votes', 'fraction_votes'],
#       dtype='str')

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'LabelEncoder', 'RandomForestClassifier', 'ExtraTreesClassifier', 'accuracy_score', 'classification_report', 'confusion_matrix', '_i2', 'df', '_2', '_i3', '_i4', 'col', '_i5', '_i6', 'num_fill', 'cat_cols', 'cat_fill', '_i7', 'label_encoders', 'le', '_i8', '_i9', '_i10', '_i11', 'rf_model', '_i12', '_i13', '_i14', '_i15', '_15', '_i16', '_i17'])

# %%
print(dir())
# Out:
# ['ExtraTreesClassifier', 'In', 'LabelEncoder', 'Out', 'RandomForestClassifier', '_', '_15', '_2', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'cat_cols', 'cat_fill', 'classification_report', 'col', 'confusion_matrix', 'df', 'exit', 'get_ipython', 'label_encoders', 'le', 'np', 'num_fill', 'open', 'pd', 'quit', 'rf_model', 'train_test_split']

# %%
df.head()
df.columns
# Out:
# Index(['state', 'state_abbreviation', 'county', 'fips', 'party', 'candidate',
#        'votes', 'fraction_votes'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['state', 'state_abbreviation', 'county', 'fips', 'party', 'candidate',
#        'votes', 'fraction_votes'],
#       dtype='str')

# %%
print(dir())
# Out:
# ['ExtraTreesClassifier', 'In', 'LabelEncoder', 'Out', 'RandomForestClassifier', '_', '_15', '_2', '_22', '_27', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'cat_cols', 'cat_fill', 'classification_report', 'col', 'confusion_matrix', 'df', 'et_model', 'exit', 'get_ipython', 'label_encoders', 'le', 'np', 'num_fill', 'open', 'pd', 'quit', 'rf_model', 'train_test_split']

# %%
print('y_test' in globals())
# Out:
# False

# %%
df.columns
# Out:
# Index(['state', 'state_abbreviation', 'county', 'fips', 'party', 'candidate',
#        'votes', 'fraction_votes'],
#       dtype='str')
