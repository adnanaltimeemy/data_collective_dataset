# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Walkabout.csv")

df.head()
# Out:
#         site        lat  ...                                      email web
# 0  Walkabout  51.733174  ...  walkabout.chelmsford@stonegategroup.co.uk NaN
# 1  Walkabout  51.888619  ...  walkabout.colchester@stonegategroup.co.uk NaN
# 2  Walkabout  51.658229  ...     Walkabout.Watford@stonegategroup.co.uk NaN
# 3  Walkabout  51.457283  ...     walkabout.reading@stonegategroup.co.uk NaN
# 4  Walkabout  50.821192  ...    walkabout.brighton@stonegategroup.co.uk NaN
#
# [5 rows x 9 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (21, 9)
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   site     21 non-null     str
#  1   lat      21 non-null     float64
#  2   lng      21 non-null     float64
#  3   zip      21 non-null     str
#  4   name     21 non-null     str
#  5   address  21 non-null     str
#  6   phone    21 non-null     str
#  7   email    21 non-null     str
#  8   web      0 non-null      float64
# dtypes: float64(3), str(6)
# memory usage: 4.2 KB
# None
#              lat        lng  web
# count  21.000000  21.000000  0.0
# mean   52.365507  -1.869447  NaN
# std     1.473308   1.550557  NaN
# min    50.369917  -5.084996  NaN
# 25%    51.454450  -2.930383  NaN
# 50%    51.888619  -1.830019  NaN
# 75%    53.381230  -0.970810  NaN
# max    55.865169   0.896121  NaN

# %%
print(df.isnull().sum())
# Out:
# site        0
# lat         0
# lng         0
# zip         0
# name        0
# address     0
# phone       0
# email       0
# web        21
# dtype: int64

# %%
df[col] = ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for col in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
print(df.head())
# Out:
#    site        lat       lng  zip  name  address  phone  email  web
# 0     0  51.733174  0.476098    6     7       17      0      0  NaN
# 1     0  51.888619  0.896121    7     8        6      8      0  NaN
# 2     0  51.658229 -0.402615   19    20       12     19      0  NaN
# 3     0  51.457283 -0.970810   15    18       20      6      0  NaN
# 4     0  50.821192 -0.144450    2     3       19     11      0  NaN

# %%
# Check your column names
print(df.columns)
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
print(df.head())
print(df.columns)
# Out:
#    site        lat       lng  zip  name  address  phone  email  web
# 0     0  51.733174  0.476098    6     7       17      0      0  NaN
# 1     0  51.888619  0.896121    7     8        6      8      0  NaN
# 2     0  51.658229 -0.402615   19    20       12     19      0  NaN
# 3     0  51.457283 -0.970810   15    18       20      6      0  NaN
# 4     0  50.821192 -0.144450    2     3       19     11      0  NaN
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')

# %%
for col in df.columns:
    print(col)
# Out:
# site
# lat
# lng
# zip
# name
# address
# phone
# email
# web

# %%
df.columns
# Out:
# Index(['site', 'lat', 'lng', 'zip', 'name', 'address', 'phone', 'email',
#        'web'],
#       dtype='str')
