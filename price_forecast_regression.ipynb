# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("price_forecast.csv")

df.head()
# Out:
#          community     building_type   _date  average_price
# 0  Agincourt North  Att/Row/Twnhouse  2022Q1   1.006430e+06
# 1  Agincourt North  Att/Row/Twnhouse  2022Q2   1.149621e+06
# 2  Agincourt North  Att/Row/Twnhouse  2022Q3   1.111985e+06
# 3  Agincourt North  Att/Row/Twnhouse  2022Q4   1.125391e+06
# 4  Agincourt North  Att/Row/Twnhouse  2023Q1   1.189993e+06

# %%
# Check missing values
print(df.isnull().sum())

# Fill missing values (simple strategy)
df = df.fillna(df.median(numeric_only=True))
# Out:
# community        0
# building_type    0
# _date            0
# average_price    0
# dtype: int64

# %%
print("Columns in DataFrame:")
print(df.columns.tolist())

target_column = "price"

if target_column in df.columns:
    X = df.drop(columns=[target_column])
    y = df[target_column]
else:
    print(f"Column '{target_column}' not found.")
# Out:
# Columns in DataFrame:
# ['community', 'building_type', '_date', 'average_price']
# Column 'price' not found.

# %%
print(df.columns.tolist())
# Out:
# ['community', 'building_type', '_date', 'average_price']

# %%
print("X exists:", "X" in globals())
print("X_train exists:", "X_train" in globals())
# Out:
# X exists: False
# X_train exists: False

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['community', 'building_type', '_date', 'average_price']
#          community     building_type   _date  average_price
# 0  Agincourt North  Att/Row/Twnhouse  2022Q1   1.006430e+06
# 1  Agincourt North  Att/Row/Twnhouse  2022Q2   1.149621e+06
# 2  Agincourt North  Att/Row/Twnhouse  2022Q3   1.111985e+06
# 3  Agincourt North  Att/Row/Twnhouse  2022Q4   1.125391e+06
# 4  Agincourt North  Att/Row/Twnhouse  2023Q1   1.189993e+06

# %%
print(rf_model)
print(hasattr(rf_model, "estimators_"))
# Out:
# RandomForestRegressor(random_state=42)
# False

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['community', 'building_type', '_date', 'average_price'], dtype='str')
# (2618, 4)
