# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

import re

# %%
df = pd.read_csv("csvCompanies.csv")

df.head()
# Out:
#   Ticker             Security             GICS Sector  \
# 0    MMM           3M Company             Industrials
# 1    ABT  Abbott Laboratories             Health Care
# 2   ABBV          AbbVie Inc.             Health Care
# 3    ACN        Accenture plc  Information Technology
# 4   ATVI  Activision Blizzard  Information Technology
#
#                 GICS Sub Industry                             TickerInfo  \
# 0        Industrial Conglomerates  https://www.nyse.com/quote/XNYS:MMM
# 1           Health Care Equipment  https://www.nyse.com/quote/XNYS:ABT
# 2                 Pharmaceuticals  https://www.nyse.com/quote/XNYS:ABBV
# 3  IT Consulting & Other Services  https://www.nyse.com/quote/XNYS:ACN
# 4     Home Entertainment Software  http://www.nasdaq.com/symbol/atvi
#
#                                          CompanyInfo  \
# 0  https://en.wikipedia.org/wiki/3M              ...
# 1  https://en.wikipedia.org/wiki/Abbott_Laborator...
# 2  https://en.wikipedia.org/wiki/AbbVie_Inc.     ...
# 3  https://en.wikipedia.org/wiki/Accenture_plc   ...
# 4  https://en.wikipedia.org/wiki/Activision_Blizz...
#
#                           CompanyWeb  \
# 0                 http://www.3m.com/
# 1              http://www.abbott.com
# 2              http://www.abbvie.com
# 3    http://www.accenture.com/ie-en/
# 4  http://www.activisionblizzard.com
#
#                                      CompanyOverview
# 0  3M Company is a technology company. It operate...
# 1  Abbott Laboratories is engaged in the discover...
# 2  AbbVie Inc. (AbbVie) is a research-based bioph...
# 3  Accenture plc is a professional services compa...
# 4  Activision Blizzard, Inc. is a developer and p...

# %%
print(df.shape)
print(df.columns)
df.info()
# Out:
# (505, 8)
# Index(['Ticker', 'Security', 'GICS Sector', 'GICS Sub Industry', 'TickerInfo',
#        'CompanyInfo', 'CompanyWeb', 'CompanyOverview'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ticker             505 non-null    str
#  1   Security           505 non-null    str
#  2   GICS Sector        505 non-null    str
#  3   GICS Sub Industry  505 non-null    str
#  4   TickerInfo         505 non-null    str
#  5   CompanyInfo        505 non-null    str
#  6   CompanyWeb         505 non-null    str
#  7   CompanyOverview    505 non-null    str
# dtypes: str(8)
# memory usage: 612.9 KB

# %%
print(df.columns)
# Out:
# Index(['Ticker', 'Security', 'GICS Sector', 'GICS Sub Industry', 'TickerInfo',
#        'CompanyInfo', 'CompanyWeb', 'CompanyOverview'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['Ticker', 'Security', 'GICS Sector', 'GICS Sub Industry', 'TickerInfo',
#        'CompanyInfo', 'CompanyWeb', 'CompanyOverview'],
#       dtype='str')

# %%
df.to_csv("clustered_companies.csv", index=False)
